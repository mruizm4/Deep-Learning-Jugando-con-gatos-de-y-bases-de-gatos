# %% [markdown]
# Se importar los datos en formato .zip, y se extraen en la maquina virtual

# %%
import os
import zipfile

local_zip = 'Data_T2.zip'

zip_ref = zipfile.ZipFile(local_zip, 'r')

zip_ref.extractall('/tmp')
zip_ref.close()

# %% [markdown]
# Aqui se define, los directorios de donde se sacara la data de la imagen.

# %%
base_dir = '/tmp/Data_T2'


train_leo_dir = os.path.join(base_dir, 'Leopardo2')
train_lince_dir = os.path.join(base_dir, 'Lince iberico')
train_ocelote_dir = os.path.join(base_dir, 'Ocelote')
train_guepardo_dir = os.path.join(base_dir, 'Guepardo')
train_serval_dir = os.path.join(base_dir, 'Serval')

# %% [markdown]
# # Sección nueva

# %% [markdown]
# Aqui no mas se muestran el nombre de los archivos,

# %%
train_leo_fnames = os.listdir( train_leo_dir )
train_lince_fnames = os.listdir( train_lince_dir )
train_ocelote_fnames = os.listdir(train_ocelote_dir)
train_guepardo_fnames = os.listdir(train_guepardo_dir)
train_serval_fnames = os.listdir(train_serval_dir)

print(train_leo_fnames[:10])
print(train_lince_fnames[:10])
print(train_ocelote_fnames[:10])
print(train_guepardo_fnames[:10])
print(train_serval_fnames[:10])
# Out:
# ['leopardo (102).jpg', 'leopardo (18).jpg', 'leopardo (104).jpg', 'leopardo (128).jpg', 'leopardo (158).jpg', 'leopardo (161).jpg', 'leopardo (89).jpg', 'leopardo (79).jpg', 'leopardo (111).jpg', 'leopardo (43).jpg']
# ['lince1 (109).jpg', 'lince1 (70).jpg', 'lince1 (50).jpg', 'lince1 (2).jpg', 'lince1 (16).jpg', 'lince1 (9).jpg', 'lince1 (46).jpg', 'lince1 (77).jpg', 'lince1 (65).jpg', 'lince.jpg']
# ['Ocelote (66).jpg', 'Ocelote (79).jpg', 'Ocelote (155).jpg', 'Ocelote (153).jpg', 'Ocelote (7).jpg', 'Ocelote (73).jpg', 'Ocelote (154).jpg', 'Ocelote (56).jpg', 'Ocelote (147).jpg', 'Ocelote (43).jpg']
# ['Guepardo (172).jpg', 'Guepardo (193).jpg', 'guepardo (104).jpg', 'guepardo (35).jpg', 'guepardo (105).jpg', 'guepardo (82).jpg', 'guepardo (75).jpg', 'Guepardo (167).jpg', 'guepardo (74).jpg', 'Guepardo (189).jpg']
# ['serval (33).jpg', 'serval (127).jpg', 'serval (83).jpg', 'serval (98).jpg', 'serval (29).jpg', 'serval (24).jpg', 'serval (23).jpg', 'serval (117).jpg', 'serval (32).jpg', 'serval (93).jpg']

# %% [markdown]
# Aqui vemos el total de imagenes en que hay en los directorios de leopardos y linces.

# %%
print('total training leo images :', len(os.listdir(train_leo_dir ) ))
print('total training lince images :', len(os.listdir( train_lince_dir ) ))
print('total training ocelote images :', len(os.listdir( train_ocelote_dir ) ))
print('total training guepardo images :', len(os.listdir( train_guepardo_dir ) ))
print('total training serval images :', len(os.listdir( train_serval_dir ) ))
# Out:
# total training leo images : 189
# total training lince images : 188
# total training ocelote images : 192
# total training guepardo images : 194
# total training serval images : 195

# %% [markdown]
# las siguientes lineas de codigo son para enseñar una pequeña muestra de loas imagenes en los directorios.

# %%
# %matplotlib inline

import matplotlib.image as mpimg
import matplotlib.pyplot as plt


nrows = 20
ncols = 4

pic_index = 0

# %%
fig = plt.gcf()
fig.set_size_inches(ncols*4, nrows*4)

pic_index+=8

next_leo_pix = [os.path.join(train_leo_dir, fname) 
                for fname in train_leo_fnames[ pic_index-8:pic_index] 
               ]

next_lince_pix = [os.path.join(train_lince_dir, fname) 
                for fname in train_lince_fnames[ pic_index-8:pic_index]
               ]
next_ocelote_pix = [os.path.join(train_ocelote_dir, fname) 
                for fname in train_ocelote_fnames[ pic_index-8:pic_index]
               ]
next_guepardo_pix = [os.path.join(train_guepardo_dir, fname) 
                for fname in train_guepardo_fnames[ pic_index-8:pic_index]
               ]
next_serval_pix = [os.path.join(train_serval_dir, fname) 
                for fname in train_serval_fnames[ pic_index-8:pic_index]
               ]


for i, img_path in enumerate(next_leo_pix+next_lince_pix+next_ocelote_pix+next_guepardo_pix+next_serval_pix ):

  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') 

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Construyendo el Modelo

# %%
import tensorflow as tf

# %% [markdown]
# La siguiente secuencia de codigo es el "core" de nuestra red nueronal, donde estan definidas, las capas de convulucion, la densidad de la red entre otros parametros.

# %%
data_augmentation =tf.keras.Sequential(
    [
        
        tf.keras.layers.experimental.preprocessing.Resizing(height=400,width=400),
        tf.keras.layers.experimental.preprocessing.RandomFlip(mode='horizontal'),
        tf.keras.layers.experimental.preprocessing.RandomRotation(factor=0.8),
        tf.keras.layers.experimental.preprocessing.RandomContrast(factor=0.4),
        tf.keras.layers.experimental.preprocessing.RandomZoom(height_factor=0.8,width_factor=0.8)
    ]
)
initializer=tf.keras.initializers.RandomNormal(mean=0.3, stddev=1.)
model = tf.keras.models.Sequential([
    tf.keras.Input((400, 400, 3)),
    data_augmentation,
    tf.keras.layers.Conv2D(16, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2), 
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'), 
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(128,(3,3),activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(256,(3,3),activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(512,(3,3),activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(16,kernel_initializer=initializer,activation='relu'),
    tf.keras.layers.Dense(32,activation='relu'),
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(256,activation='relu'),
    tf.keras.layers.Dropout(0.6),
    tf.keras.layers.Dense(1024, activation='relu'), 
    tf.keras.layers.Dense(5, activation='softmax')  
])

# %% [markdown]
# aqui podemos ver la constidad de parametros en cada, "capa de la red",  y tambien se evidenca el decrecimiento de la imagen en cada cada capa

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 400, 400, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 398, 398, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 199, 199, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 197, 197, 32)      4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 98, 98, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 96, 96, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 48, 48, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 46, 46, 128)       73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 23, 23, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 21, 21, 256)       295168
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 10, 10, 256)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 512)         1180160
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 16)                131088
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                544
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               4224
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              263168
# _________________________________________________________________
# dense_5 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 2,009,941
# Trainable params: 2,009,941
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Aqui se va definen las funciones de perdida y el optimizador, que ayudaran al modelo a aprender.

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import RMSprop

model.compile(optimizer=RMSprop(lr=0.0003,rho=0.92),
              loss='categorical_crossentropy',
              metrics = ['accuracy'])

# %% [markdown]
# Aqui se rescalan las imagenes, para que la red trabaje con valores entre 0 y 1, tambien crearemos un "split", que nos servira para la validacion de datos.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

#todas las imagenes sera resscaldad a 1/255
train_datagen = ImageDataGenerator( rescale = 1.0/255. ,validation_split=0.15)
# --------------------
# Imágenes de entrenamiento en lotes de 20 usando el generador train_datagen
# --------------------
train_generator = train_datagen.flow_from_directory(base_dir,
                                                    batch_size=1,
                                                    class_mode='categorical',
                                                    target_size=(400,400),
                                                    subset='training')     

# --------------------
# imagenes de validadcion en lotes de 5 usando el generador test_datagen generator
# --------------------

test_generator = train_datagen.flow_from_directory(base_dir,
                                                    batch_size=5,
                                                    class_mode='categorical',
                                                    target_size=(400, 400),
                                                    subset='validation')
# Out:
# Found 816 images belonging to 5 classes.
# Found 142 images belonging to 5 classes.

# %% [markdown]
# Por ultimo para entrenar la red, se le dieron 5 epocas, y se le especifico cuales era los datos de validacion y de entrenamiento.

# %%
#augmentation=data_augmetntation.compile(train_generator)
history = model.fit(train_generator,
                            validation_data=test_generator,
                            epochs=1000,
                            verbose=1)
# Out:
# Epoch 1/1000
# 11/11 [==============================] - 44s 1s/step - loss: 1.6795 - accuracy: 0.1900 - val_loss: 1.6102 - val_accuracy: 0.2042
# Epoch 2/1000
# 11/11 [==============================] - 8s 707ms/step - loss: 1.6105 - accuracy: 0.1961 - val_loss: 1.6125 - val_accuracy: 0.2042
# Epoch 3/1000
# 11/11 [==============================] - 8s 713ms/step - loss: 1.6110 - accuracy: 0.2096 - val_loss: 1.5841 - val_accuracy: 0.2465
# Epoch 4/1000
# 11/11 [==============================] - 8s 706ms/step - loss: 1.7806 - accuracy: 0.2132 - val_loss: 1.6071 - val_accuracy: 0.2042
# Epoch 5/1000
# 11/11 [==============================] - 8s 710ms/step - loss: 1.6081 - accuracy: 0.2120 - val_loss: 1.6037 - val_accuracy: 0.1972
# Epoch 6/1000
# 11/11 [==============================] - 8s 717ms/step - loss: 1.6056 - accuracy: 0.2034 - val_loss: 1.5908 - val_accuracy: 0.1972
# Epoch 7/1000
# 11/11 [==============================] - 8s 706ms/step - loss: 1.6058 - accuracy: 0.1961 - val_loss: 1.5835 - val_accuracy: 0.2113
# Epoch 8/1000
# 11/11 [==============================] - 8s 710ms/step - loss: 1.6014 - accuracy: 0.2451 - val_loss: 1.5829 - val_accuracy: 0.2394
# Epoch 9/1000
# 11/11 [==============================] - 8s 709ms/step - loss: 1.6596 - accuracy: 0.2892 - val_loss: 1.5694 - val_accuracy: 0.2887
# Epoch 10/1000
# 11/11 [==============================] - 8s 706ms/step - loss: 1.5487 - accuracy: 0.2892 - val_loss: 1.4886 - val_accuracy: 0.3380
# Epoch 11/1000
# 11/11 [==============================] - 8s 721ms/step - loss: 1.5745 - accuracy: 0.2855 - val_loss: 1.5248 - val_accuracy: 0.2394
# Epoch 12/1000
# 11/11 [==============================] - 8s 709ms/step - loss: 1.5879 - accuracy: 0.2855 - val_loss: 1.4665 - val_accuracy: 0.3521
# Epoch 13/1000
# 11/11 [==============================] - 8s 692ms/step - loss: 1.5061 - accuracy: 0.3051 - val_loss: 1.4651 - val_accuracy: 0.3592
# Epoch 14/1000
# 11/11 [==============================] - 8s 696ms/step - loss: 1.5390 - accuracy: 0.2843 - val_loss: 1.5918 - val_accuracy: 0.2746
# Epoch 15/1000
# 11/11 [==============================] - 8s 711ms/step - loss: 1.5508 - accuracy: 0.2929 - val_loss: 1.5426 - val_accuracy: 0.2676
# Epoch 16/1000
# 11/11 [==============================] - 8s 719ms/step - loss: 1.5357 - accuracy: 0.2966 - val_loss: 1.5076 - val_accuracy: 0.2958
# Epoch 17/1000
# 11/11 [==============================] - 8s 713ms/step - loss: 1.5070 - accuracy: 0.3076 - val_loss: 1.4756 - val_accuracy: 0.3380
# Epoch 18/1000
# 11/11 [==============================] - 8s 712ms/step - loss: 1.5145 - accuracy: 0.3027 - val_loss: 1.4872 - val_accuracy: 0.3451
# Epoch 19/1000
# 11/11 [==============================] - 8s 706ms/step - loss: 1.4973 - accuracy: 0.3431 - val_loss: 1.5549 - val_accuracy: 0.2113
# Epoch 20/1000
# 11/11 [==============================] - 8s 779ms/step - loss: 1.4987 - accuracy: 0.3064 - val_loss: 1.4810 - val_accuracy: 0.3592
# Epoch 21/1000
# 11/11 [==============================] - 8s 709ms/step - loss: 1.4739 - accuracy: 0.3468 - val_loss: 1.4611 - val_accuracy: 0.3310
# Epoch 22/1000
# 11/11 [==============================] - 8s 709ms/step - loss: 1.4954 - accuracy: 0.3199 - val_loss: 1.4815 - val_accuracy: 0.3099
# Epoch 23/1000
# 11/11 [==============================] - 8s 773ms/step - loss: 1.4635 - accuracy: 0.3333 - val_loss: 1.4652 - val_accuracy: 0.3239
# Epoch 24/1000
# 11/11 [==============================] - 8s 714ms/step - loss: 1.4675 - accuracy: 0.3223 - val_loss: 1.4729 - val_accuracy: 0.3380
# Epoch 25/1000
# 11/11 [==============================] - 8s 708ms/step - loss: 1.5151 - accuracy: 0.2978 - val_loss: 1.4785 - val_accuracy: 0.3451
# Epoch 26/1000
# 11/11 [==============================] - 8s 715ms/step - loss: 1.4786 - accuracy: 0.3309 - val_loss: 1.5106 - val_accuracy: 0.3028
# Epoch 27/1000
# 11/11 [==============================] - 8s 774ms/step - loss: 1.5086 - accuracy: 0.3370 - val_loss: 1.4627 - val_accuracy: 0.3662
# Epoch 28/1000
# 11/11 [==============================] - 8s 718ms/step - loss: 1.4833 - accuracy: 0.3407 - val_loss: 1.4702 - val_accuracy: 0.3239
# Epoch 29/1000
# 11/11 [==============================] - 8s 723ms/step - loss: 1.4729 - accuracy: 0.3505 - val_loss: 1.4931 - val_accuracy: 0.3239
# Epoch 30/1000
# 11/11 [==============================] - 8s 722ms/step - loss: 1.4672 - accuracy: 0.3713 - val_loss: 1.4492 - val_accuracy: 0.3451
# Epoch 31/1000
# 11/11 [==============================] - 8s 721ms/step - loss: 1.4700 - accuracy: 0.3578 - val_loss: 1.4735 - val_accuracy: 0.3662
# Epoch 32/1000
# 11/11 [==============================] - 8s 720ms/step - loss: 1.4509 - accuracy: 0.3493 - val_loss: 1.4765 - val_accuracy: 0.3451
# Epoch 33/1000
# 11/11 [==============================] - 8s 703ms/step - loss: 1.4889 - accuracy: 0.3529 - val_loss: 1.4925 - val_accuracy: 0.3310
# Epoch 34/1000
# 11/11 [==============================] - 8s 714ms/step - loss: 1.4362 - accuracy: 0.3689 - val_loss: 1.4356 - val_accuracy: 0.3803
# Epoch 35/1000
# 11/11 [==============================] - 8s 707ms/step - loss: 1.4177 - accuracy: 0.3738 - val_loss: 1.4374 - val_accuracy: 0.3803
# Epoch 36/1000
# 11/11 [==============================] - 8s 687ms/step - loss: 1.4324 - accuracy: 0.3958 - val_loss: 1.4941 - val_accuracy: 0.3310
# Epoch 37/1000
# 11/11 [==============================] - 8s 719ms/step - loss: 1.4482 - accuracy: 0.3860 - val_loss: 1.4552 - val_accuracy: 0.3521
# Epoch 38/1000
# 11/11 [==============================] - 8s 705ms/step - loss: 1.4294 - accuracy: 0.3995 - val_loss: 1.5073 - val_accuracy: 0.3592
# Epoch 39/1000
# 11/11 [==============================] - 8s 705ms/step - loss: 1.4056 - accuracy: 0.4154 - val_loss: 1.4490 - val_accuracy: 0.3803
# Epoch 40/1000
# 11/11 [==============================] - 8s 706ms/step - loss: 1.4247 - accuracy: 0.4142 - val_loss: 1.4209 - val_accuracy: 0.3944
# Epoch 41/1000
# 11/11 [==============================] - 8s 723ms/step - loss: 1.4227 - accuracy: 0.3958 - val_loss: 1.4194 - val_accuracy: 0.3873
# Epoch 42/1000
# 11/11 [==============================] - 8s 779ms/step - loss: 1.4108 - accuracy: 0.3971 - val_loss: 1.4284 - val_accuracy: 0.3944
# Epoch 43/1000
# 11/11 [==============================] - 8s 708ms/step - loss: 1.3998 - accuracy: 0.4044 - val_loss: 1.4524 - val_accuracy: 0.3380
# Epoch 44/1000
# 11/11 [==============================] - 8s 709ms/step - loss: 1.4398 - accuracy: 0.3971 - val_loss: 1.4433 - val_accuracy: 0.4014
# Epoch 45/1000
# 11/11 [==============================] - 8s 719ms/step - loss: 1.3803 - accuracy: 0.4191 - val_loss: 1.3977 - val_accuracy: 0.4085
# Epoch 46/1000
# 11/11 [==============================] - 8s 716ms/step - loss: 1.3894 - accuracy: 0.4191 - val_loss: 1.4338 - val_accuracy: 0.3873
# Epoch 47/1000
# 11/11 [==============================] - 8s 774ms/step - loss: 1.3809 - accuracy: 0.4228 - val_loss: 1.4083 - val_accuracy: 0.4437
# Epoch 48/1000
# 11/11 [==============================] - 8s 708ms/step - loss: 1.4038 - accuracy: 0.4118 - val_loss: 1.4071 - val_accuracy: 0.4155
# Epoch 49/1000
# 11/11 [==============================] - 8s 718ms/step - loss: 1.3642 - accuracy: 0.4191 - val_loss: 1.4503 - val_accuracy: 0.3944
# Epoch 50/1000
# 11/11 [==============================] - 8s 714ms/step - loss: 1.4974 - accuracy: 0.3578 - val_loss: 1.4137 - val_accuracy: 0.4366
# Epoch 51/1000
# 11/11 [==============================] - 8s 709ms/step - loss: 1.3541 - accuracy: 0.4277 - val_loss: 1.4242 - val_accuracy: 0.4155
# Epoch 52/1000
# 11/11 [==============================] - 8s 715ms/step - loss: 1.3632 - accuracy: 0.4301 - val_loss: 1.3684 - val_accuracy: 0.4789
# Epoch 53/1000
# 11/11 [==============================] - 8s 716ms/step - loss: 1.3673 - accuracy: 0.4314 - val_loss: 1.3778 - val_accuracy: 0.3873
# Epoch 54/1000
# 11/11 [==============================] - 8s 705ms/step - loss: 1.4045 - accuracy: 0.4130 - val_loss: 1.3781 - val_accuracy: 0.4225
# Epoch 55/1000
# 11/11 [==============================] - 8s 710ms/step - loss: 1.3466 - accuracy: 0.4301 - val_loss: 1.3849 - val_accuracy: 0.4507
# Epoch 56/1000
# 11/11 [==============================] - 8s 718ms/step - loss: 1.3461 - accuracy: 0.4400 - val_loss: 1.4080 - val_accuracy: 0.4296
# Epoch 57/1000
# 11/11 [==============================] - 8s 715ms/step - loss: 1.3488 - accuracy: 0.4387 - val_loss: 1.3586 - val_accuracy: 0.4648
# Epoch 58/1000
# 11/11 [==============================] - 8s 711ms/step - loss: 1.3326 - accuracy: 0.4534 - val_loss: 1.3430 - val_accuracy: 0.4648
# Epoch 59/1000
# 11/11 [==============================] - 8s 713ms/step - loss: 1.3082 - accuracy: 0.4547 - val_loss: 1.4260 - val_accuracy: 0.3310
# Epoch 60/1000
# 11/11 [==============================] - 8s 706ms/step - loss: 1.3508 - accuracy: 0.4326 - val_loss: 1.4964 - val_accuracy: 0.3028
# Epoch 61/1000
# 11/11 [==============================] - 8s 714ms/step - loss: 1.3407 - accuracy: 0.4424 - val_loss: 1.4152 - val_accuracy: 0.4085
# Epoch 62/1000
# 11/11 [==============================] - 8s 714ms/step - loss: 1.3746 - accuracy: 0.4350 - val_loss: 1.4498 - val_accuracy: 0.3169
# Epoch 63/1000
# 11/11 [==============================] - 8s 714ms/step - loss: 1.3409 - accuracy: 0.4559 - val_loss: 1.4125 - val_accuracy: 0.4014
# Epoch 64/1000
# 11/11 [==============================] - 8s 700ms/step - loss: 1.3145 - accuracy: 0.4608 - val_loss: 1.4340 - val_accuracy: 0.4085
# Epoch 65/1000
# 11/11 [==============================] - 8s 708ms/step - loss: 1.3417 - accuracy: 0.4338 - val_loss: 1.4148 - val_accuracy: 0.3732
# Epoch 66/1000
# 11/11 [==============================] - 8s 776ms/step - loss: 1.3414 - accuracy: 0.4473 - val_loss: 1.4133 - val_accuracy: 0.3451
# Epoch 67/1000
# 11/11 [==============================] - 8s 708ms/step - loss: 1.3127 - accuracy: 0.4620 - val_loss: 1.3736 - val_accuracy: 0.4085
# Epoch 68/1000
# 11/11 [==============================] - 8s 712ms/step - loss: 1.4083 - accuracy: 0.4228 - val_loss: 1.3725 - val_accuracy: 0.4437
# Epoch 69/1000
# 11/11 [==============================] - 8s 705ms/step - loss: 1.3342 - accuracy: 0.4498 - val_loss: 1.4039 - val_accuracy: 0.4155
# Epoch 70/1000
# 11/11 [==============================] - 8s 721ms/step - loss: 1.3103 - accuracy: 0.4706 - val_loss: 1.4152 - val_accuracy: 0.3873
# Epoch 71/1000
# 11/11 [==============================] - 8s 705ms/step - loss: 1.3091 - accuracy: 0.4534 - val_loss: 1.3540 - val_accuracy: 0.4507
# Epoch 72/1000
# 11/11 [==============================] - 8s 702ms/step - loss: 1.2855 - accuracy: 0.4596 - val_loss: 1.4671 - val_accuracy: 0.3732
# Epoch 73/1000
# 11/11 [==============================] - 8s 715ms/step - loss: 1.2754 - accuracy: 0.4841 - val_loss: 1.4855 - val_accuracy: 0.3732
# Epoch 74/1000
# 11/11 [==============================] - 8s 692ms/step - loss: 1.2970 - accuracy: 0.4583 - val_loss: 1.6512 - val_accuracy: 0.2746
# Epoch 75/1000
# 11/11 [==============================] - 8s 711ms/step - loss: 1.2783 - accuracy: 0.4694 - val_loss: 1.3962 - val_accuracy: 0.4155
# Epoch 76/1000
# 11/11 [==============================] - 8s 704ms/step - loss: 1.2719 - accuracy: 0.4743 - val_loss: 1.3841 - val_accuracy: 0.3803
# Epoch 77/1000
# 11/11 [==============================] - 8s 707ms/step - loss: 1.2956 - accuracy: 0.4804 - val_loss: 1.4052 - val_accuracy: 0.4296
# Epoch 78/1000
# 11/11 [==============================] - 8s 769ms/step - loss: 1.2505 - accuracy: 0.4706 - val_loss: 1.4136 - val_accuracy: 0.3873
# Epoch 79/1000
# 11/11 [==============================] - 8s 723ms/step - loss: 1.2913 - accuracy: 0.4706 - val_loss: 1.4434 - val_accuracy: 0.3732
# Epoch 80/1000
# 11/11 [==============================] - 8s 721ms/step - loss: 1.2555 - accuracy: 0.4963 - val_loss: 1.6093 - val_accuracy: 0.2958
# Epoch 81/1000
# 11/11 [==============================] - 8s 724ms/step - loss: 1.2997 - accuracy: 0.4718 - val_loss: 1.4480 - val_accuracy: 0.3732
# Epoch 82/1000
# 11/11 [==============================] - 8s 718ms/step - loss: 1.2181 - accuracy: 0.4951 - val_loss: 1.4261 - val_accuracy: 0.3803
# Epoch 83/1000
# 11/11 [==============================] - 8s 713ms/step - loss: 1.3018 - accuracy: 0.4694 - val_loss: 1.4363 - val_accuracy: 0.3380
# Epoch 84/1000
# 11/11 [==============================] - 8s 694ms/step - loss: 1.2424 - accuracy: 0.4914 - val_loss: 1.3454 - val_accuracy: 0.4225
# Epoch 85/1000
# 11/11 [==============================] - 8s 699ms/step - loss: 1.2735 - accuracy: 0.4951 - val_loss: 1.4061 - val_accuracy: 0.3803
# Epoch 86/1000
# 11/11 [==============================] - 8s 713ms/step - loss: 1.2379 - accuracy: 0.5159 - val_loss: 1.3628 - val_accuracy: 0.4437
# Epoch 87/1000
# 11/11 [==============================] - 8s 770ms/step - loss: 1.2579 - accuracy: 0.5025 - val_loss: 1.3483 - val_accuracy: 0.4930
# Epoch 88/1000
# 11/11 [==============================] - 8s 711ms/step - loss: 1.2834 - accuracy: 0.4767 - val_loss: 1.3755 - val_accuracy: 0.4155
# Epoch 89/1000
# 11/11 [==============================] - 8s 710ms/step - loss: 1.2470 - accuracy: 0.5123 - val_loss: 1.5095 - val_accuracy: 0.3592
# Epoch 90/1000
# 11/11 [==============================] - 8s 724ms/step - loss: 1.1965 - accuracy: 0.5208 - val_loss: 1.4528 - val_accuracy: 0.4225
# Epoch 91/1000
# 11/11 [==============================] - 8s 713ms/step - loss: 1.2190 - accuracy: 0.5172 - val_loss: 1.5047 - val_accuracy: 0.3592
# Epoch 92/1000
# 11/11 [==============================] - 8s 710ms/step - loss: 1.2745 - accuracy: 0.4914 - val_loss: 1.5536 - val_accuracy: 0.3732
# Epoch 93/1000
# 11/11 [==============================] - 8s 720ms/step - loss: 1.2611 - accuracy: 0.4804 - val_loss: 1.3981 - val_accuracy: 0.4437
# Epoch 94/1000
# 11/11 [==============================] - 8s 714ms/step - loss: 1.2685 - accuracy: 0.4951 - val_loss: 1.3450 - val_accuracy: 0.5282
# Epoch 95/1000
# 11/11 [==============================] - 8s 697ms/step - loss: 1.2226 - accuracy: 0.5074 - val_loss: 1.4037 - val_accuracy: 0.4366
# Epoch 96/1000
# 11/11 [==============================] - 8s 714ms/step - loss: 1.1905 - accuracy: 0.5343 - val_loss: 1.3038 - val_accuracy: 0.4437
# Epoch 97/1000
# 11/11 [==============================] - 8s 769ms/step - loss: 1.2635 - accuracy: 0.5074 - val_loss: 1.2652 - val_accuracy: 0.5845
# Epoch 98/1000
# 11/11 [==============================] - 8s 714ms/step - loss: 1.2385 - accuracy: 0.5110 - val_loss: 1.5961 - val_accuracy: 0.3451
# Epoch 99/1000
# 11/11 [==============================] - 8s 713ms/step - loss: 1.1830 - accuracy: 0.5196 - val_loss: 1.3988 - val_accuracy: 0.4014
# Epoch 100/1000
# 11/11 [==============================] - 8s 712ms/step - loss: 1.1890 - accuracy: 0.5404 - val_loss: 1.3514 - val_accuracy: 0.4225
# Epoch 101/1000
# 11/11 [==============================] - 8s 715ms/step - loss: 1.2747 - accuracy: 0.4902 - val_loss: 1.3499 - val_accuracy: 0.4296
# Epoch 102/1000
# 11/11 [==============================] - 8s 722ms/step - loss: 1.1591 - accuracy: 0.5196 - val_loss: 1.2810 - val_accuracy: 0.5141
# Epoch 103/1000
# 11/11 [==============================] - 8s 723ms/step - loss: 1.1693 - accuracy: 0.5270 - val_loss: 1.4830 - val_accuracy: 0.3662
# Epoch 104/1000
# 11/11 [==============================] - 8s 716ms/step - loss: 1.1979 - accuracy: 0.5319 - val_loss: 1.3099 - val_accuracy: 0.4718
# Epoch 105/1000
# 11/11 [==============================] - 8s 708ms/step - loss: 1.2411 - accuracy: 0.5135 - val_loss: 1.3558 - val_accuracy: 0.4437
# Epoch 106/1000
# 11/11 [==============================] - 8s 717ms/step - loss: 1.2111 - accuracy: 0.5245 - val_loss: 1.2540 - val_accuracy: 0.5563
# Epoch 107/1000
# 11/11 [==============================] - 8s 708ms/step - loss: 1.2407 - accuracy: 0.5355 - val_loss: 1.3671 - val_accuracy: 0.4225
# Epoch 108/1000
# 11/11 [==============================] - 8s 709ms/step - loss: 1.1559 - accuracy: 0.5319 - val_loss: 1.4733 - val_accuracy: 0.3732
# Epoch 109/1000
# 11/11 [==============================] - 8s 708ms/step - loss: 1.1535 - accuracy: 0.5355 - val_loss: 1.4753 - val_accuracy: 0.3662
# Epoch 110/1000
# 11/11 [==============================] - 8s 706ms/step - loss: 1.1703 - accuracy: 0.5270 - val_loss: 1.4613 - val_accuracy: 0.3803
# Epoch 111/1000
# 11/11 [==============================] - 8s 776ms/step - loss: 1.1860 - accuracy: 0.5294 - val_loss: 1.3236 - val_accuracy: 0.4296
# Epoch 112/1000
# 11/11 [==============================] - 8s 708ms/step - loss: 1.1206 - accuracy: 0.5368 - val_loss: 1.2894 - val_accuracy: 0.4859
# Epoch 113/1000
# 11/11 [==============================] - 8s 725ms/step - loss: 1.2395 - accuracy: 0.5159 - val_loss: 1.2804 - val_accuracy: 0.5211
# Epoch 114/1000
# 11/11 [==============================] - 8s 705ms/step - loss: 1.1470 - accuracy: 0.5674 - val_loss: 1.1974 - val_accuracy: 0.5352
# Epoch 115/1000
# 11/11 [==============================] - 8s 709ms/step - loss: 1.1861 - accuracy: 0.5319 - val_loss: 1.2438 - val_accuracy: 0.5282
# Epoch 116/1000
# 11/11 [==============================] - 8s 715ms/step - loss: 1.1977 - accuracy: 0.5380 - val_loss: 1.3358 - val_accuracy: 0.4859
# Epoch 117/1000
# 11/11 [==============================] - 8s 707ms/step - loss: 1.1856 - accuracy: 0.5257 - val_loss: 1.3700 - val_accuracy: 0.4577
# Epoch 118/1000
# 11/11 [==============================] - 8s 713ms/step - loss: 1.1256 - accuracy: 0.5686 - val_loss: 1.7510 - val_accuracy: 0.2958
# Epoch 119/1000
# 11/11 [==============================] - 8s 718ms/step - loss: 1.1257 - accuracy: 0.5772 - val_loss: 1.4178 - val_accuracy: 0.3803
# Epoch 120/1000
# 11/11 [==============================] - 8s 706ms/step - loss: 1.2137 - accuracy: 0.5368 - val_loss: 1.2345 - val_accuracy: 0.5070
# Epoch 121/1000
# 11/11 [==============================] - 8s 710ms/step - loss: 1.1367 - accuracy: 0.5686 - val_loss: 1.3884 - val_accuracy: 0.4366
# Epoch 122/1000
# 11/11 [==============================] - 8s 705ms/step - loss: 1.1567 - accuracy: 0.5368 - val_loss: 1.3657 - val_accuracy: 0.4366
# Epoch 123/1000
# 11/11 [==============================] - 8s 721ms/step - loss: 1.1989 - accuracy: 0.5319 - val_loss: 1.2311 - val_accuracy: 0.5423
# Epoch 124/1000
# 11/11 [==============================] - 8s 720ms/step - loss: 1.1026 - accuracy: 0.5515 - val_loss: 1.2344 - val_accuracy: 0.5352
# Epoch 125/1000
# 11/11 [==============================] - 8s 714ms/step - loss: 1.1946 - accuracy: 0.5466 - val_loss: 1.3809 - val_accuracy: 0.4296
# Epoch 126/1000
# 11/11 [==============================] - 8s 718ms/step - loss: 1.0506 - accuracy: 0.5870 - val_loss: 1.4416 - val_accuracy: 0.4155
# Epoch 127/1000
# 11/11 [==============================] - 8s 692ms/step - loss: 1.1560 - accuracy: 0.5294 - val_loss: 1.4231 - val_accuracy: 0.3662
# Epoch 128/1000
# 11/11 [==============================] - 8s 719ms/step - loss: 1.1143 - accuracy: 0.5625 - val_loss: 1.1528 - val_accuracy: 0.5915
# Epoch 129/1000
# 11/11 [==============================] - 8s 712ms/step - loss: 1.1140 - accuracy: 0.5576 - val_loss: 1.2522 - val_accuracy: 0.5352
# Epoch 130/1000
# 11/11 [==============================] - 8s 707ms/step - loss: 1.1423 - accuracy: 0.5686 - val_loss: 1.1901 - val_accuracy: 0.5634
# Epoch 131/1000
# 11/11 [==============================] - 8s 710ms/step - loss: 1.1360 - accuracy: 0.5539 - val_loss: 1.1614 - val_accuracy: 0.5704
# Epoch 132/1000
# 11/11 [==============================] - 8s 720ms/step - loss: 1.0626 - accuracy: 0.6029 - val_loss: 1.3484 - val_accuracy: 0.4718
# Epoch 133/1000
# 11/11 [==============================] - 8s 715ms/step - loss: 1.0480 - accuracy: 0.5944 - val_loss: 1.4645 - val_accuracy: 0.4085
# Epoch 134/1000
# 11/11 [==============================] - 8s 708ms/step - loss: 1.1335 - accuracy: 0.5404 - val_loss: 1.2053 - val_accuracy: 0.5563
# Epoch 135/1000
# 11/11 [==============================] - 8s 715ms/step - loss: 1.1613 - accuracy: 0.5686 - val_loss: 1.2055 - val_accuracy: 0.5634
# Epoch 136/1000
# 11/11 [==============================] - 8s 709ms/step - loss: 1.1211 - accuracy: 0.5600 - val_loss: 1.1957 - val_accuracy: 0.5423
# Epoch 137/1000
# 11/11 [==============================] - 8s 775ms/step - loss: 1.0878 - accuracy: 0.5686 - val_loss: 1.2333 - val_accuracy: 0.5000
# Epoch 138/1000
# 11/11 [==============================] - 8s 704ms/step - loss: 1.1060 - accuracy: 0.5748 - val_loss: 1.2686 - val_accuracy: 0.5211
# Epoch 139/1000
# 11/11 [==============================] - 8s 716ms/step - loss: 1.0660 - accuracy: 0.5895 - val_loss: 1.2681 - val_accuracy: 0.5634
# Epoch 140/1000
# 11/11 [==============================] - 8s 694ms/step - loss: 1.0938 - accuracy: 0.5821 - val_loss: 1.0999 - val_accuracy: 0.5704
# Epoch 141/1000
# 11/11 [==============================] - 8s 708ms/step - loss: 1.0853 - accuracy: 0.5797 - val_loss: 1.5980 - val_accuracy: 0.3732
# Epoch 142/1000
# 11/11 [==============================] - 8s 712ms/step - loss: 1.0569 - accuracy: 0.6066 - val_loss: 1.2706 - val_accuracy: 0.5070
# Epoch 143/1000
# 11/11 [==============================] - 8s 719ms/step - loss: 1.0987 - accuracy: 0.5846 - val_loss: 1.2635 - val_accuracy: 0.4930
# Epoch 144/1000
# 11/11 [==============================] - 8s 716ms/step - loss: 1.0389 - accuracy: 0.5931 - val_loss: 1.3891 - val_accuracy: 0.4225
# Epoch 145/1000
# 11/11 [==============================] - 8s 706ms/step - loss: 0.9898 - accuracy: 0.6373 - val_loss: 1.1571 - val_accuracy: 0.5986
# Epoch 146/1000
# 11/11 [==============================] - 8s 722ms/step - loss: 1.1366 - accuracy: 0.5772 - val_loss: 1.3622 - val_accuracy: 0.4577
# Epoch 147/1000
# 11/11 [==============================] - 8s 720ms/step - loss: 1.0603 - accuracy: 0.5735 - val_loss: 1.1908 - val_accuracy: 0.5634
# Epoch 148/1000
# 11/11 [==============================] - 8s 704ms/step - loss: 1.0264 - accuracy: 0.6238 - val_loss: 1.1872 - val_accuracy: 0.5563
# Epoch 149/1000
# 11/11 [==============================] - 8s 700ms/step - loss: 0.9856 - accuracy: 0.6189 - val_loss: 1.6975 - val_accuracy: 0.3662
# Epoch 150/1000
# 11/11 [==============================] - 8s 702ms/step - loss: 1.0844 - accuracy: 0.6054 - val_loss: 1.1743 - val_accuracy: 0.5986
# Epoch 151/1000
# 11/11 [==============================] - 8s 704ms/step - loss: 1.0575 - accuracy: 0.6103 - val_loss: 1.2305 - val_accuracy: 0.5634
# Epoch 152/1000
# 11/11 [==============================] - 8s 715ms/step - loss: 1.0193 - accuracy: 0.6152 - val_loss: 1.1849 - val_accuracy: 0.5563
# Epoch 153/1000
# 11/11 [==============================] - 8s 713ms/step - loss: 1.0053 - accuracy: 0.6238 - val_loss: 1.1188 - val_accuracy: 0.5986
# Epoch 154/1000
# 11/11 [==============================] - 8s 723ms/step - loss: 1.0954 - accuracy: 0.5711 - val_loss: 1.2162 - val_accuracy: 0.5634
# Epoch 155/1000
# 11/11 [==============================] - 8s 774ms/step - loss: 1.0134 - accuracy: 0.5993 - val_loss: 1.3836 - val_accuracy: 0.4930
# Epoch 156/1000
# 11/11 [==============================] - 8s 711ms/step - loss: 1.0667 - accuracy: 0.5931 - val_loss: 1.2492 - val_accuracy: 0.5141
# Epoch 157/1000
# 11/11 [==============================] - 8s 708ms/step - loss: 1.0762 - accuracy: 0.5956 - val_loss: 1.1062 - val_accuracy: 0.6127
# Epoch 158/1000
# 11/11 [==============================] - 8s 702ms/step - loss: 1.0239 - accuracy: 0.6103 - val_loss: 1.0388 - val_accuracy: 0.5986
# Epoch 159/1000
# 11/11 [==============================] - 8s 704ms/step - loss: 1.0626 - accuracy: 0.5944 - val_loss: 1.3194 - val_accuracy: 0.4718
# Epoch 160/1000
# 11/11 [==============================] - 8s 712ms/step - loss: 1.0088 - accuracy: 0.6164 - val_loss: 1.0982 - val_accuracy: 0.6268
# Epoch 161/1000
# 11/11 [==============================] - 8s 712ms/step - loss: 1.0071 - accuracy: 0.6152 - val_loss: 1.1568 - val_accuracy: 0.5915
# Epoch 162/1000
# 11/11 [==============================] - 8s 771ms/step - loss: 1.0571 - accuracy: 0.5931 - val_loss: 1.0874 - val_accuracy: 0.5845
# Epoch 163/1000
# 11/11 [==============================] - 8s 714ms/step - loss: 0.9800 - accuracy: 0.6287 - val_loss: 1.3201 - val_accuracy: 0.4859
# Epoch 164/1000
# 11/11 [==============================] - 8s 716ms/step - loss: 1.0790 - accuracy: 0.5968 - val_loss: 1.2671 - val_accuracy: 0.5493
# Epoch 165/1000
# 11/11 [==============================] - 8s 711ms/step - loss: 0.9435 - accuracy: 0.6373 - val_loss: 1.0927 - val_accuracy: 0.6127
# Epoch 166/1000
# 11/11 [==============================] - 8s 708ms/step - loss: 0.8900 - accuracy: 0.6752 - val_loss: 1.0270 - val_accuracy: 0.6338
# Epoch 167/1000
# 11/11 [==============================] - 8s 695ms/step - loss: 1.0364 - accuracy: 0.6066 - val_loss: 1.2350 - val_accuracy: 0.5775
# Epoch 168/1000
# 11/11 [==============================] - 8s 694ms/step - loss: 0.9516 - accuracy: 0.6495 - val_loss: 1.1691 - val_accuracy: 0.5775
# Epoch 169/1000
# 11/11 [==============================] - 8s 710ms/step - loss: 0.9381 - accuracy: 0.6654 - val_loss: 1.1936 - val_accuracy: 0.5493
# Epoch 170/1000
# 11/11 [==============================] - 8s 708ms/step - loss: 0.9687 - accuracy: 0.6287 - val_loss: 1.0205 - val_accuracy: 0.6408
# Epoch 171/1000
# 11/11 [==============================] - 8s 769ms/step - loss: 1.1261 - accuracy: 0.5711 - val_loss: 1.2168 - val_accuracy: 0.5493
# Epoch 172/1000
# 11/11 [==============================] - 8s 715ms/step - loss: 0.9427 - accuracy: 0.6483 - val_loss: 1.1926 - val_accuracy: 0.5493
# Epoch 173/1000
# 11/11 [==============================] - 8s 707ms/step - loss: 0.9905 - accuracy: 0.6213 - val_loss: 1.2100 - val_accuracy: 0.5352
# Epoch 174/1000
# 11/11 [==============================] - 8s 717ms/step - loss: 0.9792 - accuracy: 0.6348 - val_loss: 1.1706 - val_accuracy: 0.5423
# Epoch 175/1000
# 11/11 [==============================] - 8s 713ms/step - loss: 0.8750 - accuracy: 0.6618 - val_loss: 1.2436 - val_accuracy: 0.4718
# Epoch 176/1000
# 11/11 [==============================] - 8s 699ms/step - loss: 0.9228 - accuracy: 0.6458 - val_loss: 1.1417 - val_accuracy: 0.5352
# Epoch 177/1000
# 11/11 [==============================] - 8s 711ms/step - loss: 0.9882 - accuracy: 0.6336 - val_loss: 1.1330 - val_accuracy: 0.5915
# Epoch 178/1000
# 11/11 [==============================] - 8s 713ms/step - loss: 0.8961 - accuracy: 0.6569 - val_loss: 1.4155 - val_accuracy: 0.5000
# Epoch 179/1000
# 11/11 [==============================] - 8s 710ms/step - loss: 0.9917 - accuracy: 0.6434 - val_loss: 1.0066 - val_accuracy: 0.6408
# Epoch 180/1000
# 11/11 [==============================] - 8s 695ms/step - loss: 0.9189 - accuracy: 0.6422 - val_loss: 1.5596 - val_accuracy: 0.4789
# Epoch 181/1000
# 11/11 [==============================] - 8s 703ms/step - loss: 1.0266 - accuracy: 0.6213 - val_loss: 1.1070 - val_accuracy: 0.5775
# Epoch 182/1000
# 11/11 [==============================] - 8s 711ms/step - loss: 0.9531 - accuracy: 0.6262 - val_loss: 1.2385 - val_accuracy: 0.5493
# Epoch 183/1000
# 11/11 [==============================] - 8s 718ms/step - loss: 0.9921 - accuracy: 0.6373 - val_loss: 1.1243 - val_accuracy: 0.5704
# Epoch 184/1000
# 11/11 [==============================] - 8s 714ms/step - loss: 0.9332 - accuracy: 0.6569 - val_loss: 1.1948 - val_accuracy: 0.5563
# Epoch 185/1000
# 11/11 [==============================] - 8s 718ms/step - loss: 0.8442 - accuracy: 0.6691 - val_loss: 1.0680 - val_accuracy: 0.6127
# Epoch 186/1000
# 11/11 [==============================] - 8s 713ms/step - loss: 0.9350 - accuracy: 0.6422 - val_loss: 1.0368 - val_accuracy: 0.6197
# Epoch 187/1000
# 11/11 [==============================] - 8s 709ms/step - loss: 1.0382 - accuracy: 0.6385 - val_loss: 1.2119 - val_accuracy: 0.5423
# Epoch 188/1000
# 11/11 [==============================] - 8s 705ms/step - loss: 0.8218 - accuracy: 0.6887 - val_loss: 1.0441 - val_accuracy: 0.5845
# Epoch 189/1000
# 11/11 [==============================] - 8s 723ms/step - loss: 0.9320 - accuracy: 0.6765 - val_loss: 0.9844 - val_accuracy: 0.6408
# Epoch 190/1000
# 11/11 [==============================] - 8s 722ms/step - loss: 0.8664 - accuracy: 0.6814 - val_loss: 1.1309 - val_accuracy: 0.6056
# Epoch 191/1000
# 11/11 [==============================] - 8s 716ms/step - loss: 0.8391 - accuracy: 0.6985 - val_loss: 1.1593 - val_accuracy: 0.5563
# Epoch 192/1000
# 11/11 [==============================] - 8s 726ms/step - loss: 0.9332 - accuracy: 0.6495 - val_loss: 0.9097 - val_accuracy: 0.6901
# Epoch 193/1000
# 11/11 [==============================] - 8s 723ms/step - loss: 0.9897 - accuracy: 0.6250 - val_loss: 1.1583 - val_accuracy: 0.5211
# Epoch 194/1000
# 11/11 [==============================] - 8s 723ms/step - loss: 0.8788 - accuracy: 0.6777 - val_loss: 0.9913 - val_accuracy: 0.6549
# Epoch 195/1000
# 11/11 [==============================] - 8s 717ms/step - loss: 1.1212 - accuracy: 0.5772 - val_loss: 1.0819 - val_accuracy: 0.6056
# Epoch 196/1000
# 11/11 [==============================] - 8s 717ms/step - loss: 0.8850 - accuracy: 0.6838 - val_loss: 0.9471 - val_accuracy: 0.6408
# Epoch 197/1000
# 11/11 [==============================] - 8s 710ms/step - loss: 0.8684 - accuracy: 0.6654 - val_loss: 1.1120 - val_accuracy: 0.5986
# Epoch 198/1000
# 11/11 [==============================] - 8s 721ms/step - loss: 0.8646 - accuracy: 0.6728 - val_loss: 1.2309 - val_accuracy: 0.5563
# Epoch 199/1000
# 11/11 [==============================] - 8s 722ms/step - loss: 0.8604 - accuracy: 0.6838 - val_loss: 1.0820 - val_accuracy: 0.5845
# Epoch 200/1000
# 11/11 [==============================] - 8s 722ms/step - loss: 0.7991 - accuracy: 0.7059 - val_loss: 1.0737 - val_accuracy: 0.5845
# Epoch 201/1000
# 11/11 [==============================] - 8s 720ms/step - loss: 0.8842 - accuracy: 0.6814 - val_loss: 1.1456 - val_accuracy: 0.5845
# Epoch 202/1000
# 11/11 [==============================] - 8s 727ms/step - loss: 0.9400 - accuracy: 0.6630 - val_loss: 1.1017 - val_accuracy: 0.5986
# Epoch 203/1000
# 11/11 [==============================] - 8s 720ms/step - loss: 0.8321 - accuracy: 0.6985 - val_loss: 1.0690 - val_accuracy: 0.6479
# Epoch 204/1000
# 11/11 [==============================] - 8s 721ms/step - loss: 0.8938 - accuracy: 0.6838 - val_loss: 0.9961 - val_accuracy: 0.6408
# Epoch 205/1000
# 11/11 [==============================] - 8s 720ms/step - loss: 0.9130 - accuracy: 0.6581 - val_loss: 1.0536 - val_accuracy: 0.6127
# Epoch 206/1000
# 11/11 [==============================] - 8s 722ms/step - loss: 0.8055 - accuracy: 0.7120 - val_loss: 1.0368 - val_accuracy: 0.6056
# Epoch 207/1000
# 11/11 [==============================] - 8s 718ms/step - loss: 0.8396 - accuracy: 0.6765 - val_loss: 1.3781 - val_accuracy: 0.4930
# Epoch 208/1000
# 11/11 [==============================] - 8s 710ms/step - loss: 0.9103 - accuracy: 0.6581 - val_loss: 1.1419 - val_accuracy: 0.5775
# Epoch 209/1000
# 11/11 [==============================] - 8s 708ms/step - loss: 0.8409 - accuracy: 0.6924 - val_loss: 1.2056 - val_accuracy: 0.5915
# Epoch 210/1000
# 11/11 [==============================] - 8s 723ms/step - loss: 0.8944 - accuracy: 0.6765 - val_loss: 1.0662 - val_accuracy: 0.6127
# Epoch 211/1000
# 11/11 [==============================] - 8s 716ms/step - loss: 0.9108 - accuracy: 0.6581 - val_loss: 1.1061 - val_accuracy: 0.5915
# Epoch 212/1000
# 11/11 [==============================] - 8s 782ms/step - loss: 0.9415 - accuracy: 0.6532 - val_loss: 1.2825 - val_accuracy: 0.5352
# Epoch 213/1000
# 11/11 [==============================] - 8s 722ms/step - loss: 0.8417 - accuracy: 0.6887 - val_loss: 1.0282 - val_accuracy: 0.6197
# Epoch 214/1000
# 11/11 [==============================] - 8s 717ms/step - loss: 0.9408 - accuracy: 0.6593 - val_loss: 1.2297 - val_accuracy: 0.5141
# Epoch 215/1000
# 11/11 [==============================] - 8s 729ms/step - loss: 0.8195 - accuracy: 0.6912 - val_loss: 0.9844 - val_accuracy: 0.6549
# Epoch 216/1000
# 11/11 [==============================] - 8s 718ms/step - loss: 0.8313 - accuracy: 0.6887 - val_loss: 0.9056 - val_accuracy: 0.6690
# Epoch 217/1000
# 11/11 [==============================] - 8s 718ms/step - loss: 0.8790 - accuracy: 0.6691 - val_loss: 1.0592 - val_accuracy: 0.6127
# Epoch 218/1000
# 11/11 [==============================] - 8s 709ms/step - loss: 0.8907 - accuracy: 0.6667 - val_loss: 1.0980 - val_accuracy: 0.5775
# Epoch 219/1000
# 11/11 [==============================] - 8s 715ms/step - loss: 0.8316 - accuracy: 0.6863 - val_loss: 1.0234 - val_accuracy: 0.6127
# Epoch 220/1000
# 11/11 [==============================] - 8s 778ms/step - loss: 0.9177 - accuracy: 0.6409 - val_loss: 1.1028 - val_accuracy: 0.5634
# Epoch 221/1000
# 11/11 [==============================] - 8s 725ms/step - loss: 0.8182 - accuracy: 0.6900 - val_loss: 0.9291 - val_accuracy: 0.6620
# Epoch 222/1000
# 11/11 [==============================] - 8s 716ms/step - loss: 0.7411 - accuracy: 0.7243 - val_loss: 1.0131 - val_accuracy: 0.5845
# Epoch 223/1000
# 11/11 [==============================] - 8s 716ms/step - loss: 0.7926 - accuracy: 0.6973 - val_loss: 1.0947 - val_accuracy: 0.6127
# Epoch 224/1000
# 11/11 [==============================] - 8s 713ms/step - loss: 0.8747 - accuracy: 0.6924 - val_loss: 0.9381 - val_accuracy: 0.6408
# Epoch 225/1000
# 11/11 [==============================] - 8s 716ms/step - loss: 0.7849 - accuracy: 0.7108 - val_loss: 1.1184 - val_accuracy: 0.5775
# Epoch 226/1000
# 11/11 [==============================] - 8s 724ms/step - loss: 0.7667 - accuracy: 0.7132 - val_loss: 1.2244 - val_accuracy: 0.5775
# Epoch 227/1000
# 11/11 [==============================] - 8s 719ms/step - loss: 0.8249 - accuracy: 0.6985 - val_loss: 1.2899 - val_accuracy: 0.5634
# Epoch 228/1000
# 11/11 [==============================] - 8s 701ms/step - loss: 0.7629 - accuracy: 0.7206 - val_loss: 1.0231 - val_accuracy: 0.6479
# Epoch 229/1000
# 11/11 [==============================] - 8s 720ms/step - loss: 0.8705 - accuracy: 0.6912 - val_loss: 1.0329 - val_accuracy: 0.6268
# Epoch 230/1000
# 11/11 [==============================] - 8s 717ms/step - loss: 0.7570 - accuracy: 0.7292 - val_loss: 1.0672 - val_accuracy: 0.5986
# Epoch 231/1000
# 11/11 [==============================] - 8s 713ms/step - loss: 0.7899 - accuracy: 0.6936 - val_loss: 1.2118 - val_accuracy: 0.5704
# Epoch 232/1000
# 11/11 [==============================] - 8s 718ms/step - loss: 0.8322 - accuracy: 0.6998 - val_loss: 1.0482 - val_accuracy: 0.6268
# Epoch 233/1000
# 11/11 [==============================] - 8s 775ms/step - loss: 0.7254 - accuracy: 0.7500 - val_loss: 1.2586 - val_accuracy: 0.5282
# Epoch 234/1000
# 11/11 [==============================] - 8s 716ms/step - loss: 0.8605 - accuracy: 0.6814 - val_loss: 0.9742 - val_accuracy: 0.6408
# Epoch 235/1000
# 11/11 [==============================] - 8s 713ms/step - loss: 0.7524 - accuracy: 0.7426 - val_loss: 0.9531 - val_accuracy: 0.6620
# Epoch 236/1000
# 11/11 [==============================] - 8s 719ms/step - loss: 0.8255 - accuracy: 0.7071 - val_loss: 0.9855 - val_accuracy: 0.6549
# Epoch 237/1000
# 11/11 [==============================] - 8s 697ms/step - loss: 0.8287 - accuracy: 0.6949 - val_loss: 1.0034 - val_accuracy: 0.6197
# Epoch 238/1000
# 11/11 [==============================] - 8s 722ms/step - loss: 0.7665 - accuracy: 0.7022 - val_loss: 1.2487 - val_accuracy: 0.5352
# Epoch 239/1000
# 11/11 [==============================] - 8s 730ms/step - loss: 0.8182 - accuracy: 0.6973 - val_loss: 1.2267 - val_accuracy: 0.5775
# Epoch 240/1000
# 11/11 [==============================] - 8s 707ms/step - loss: 0.7240 - accuracy: 0.7451 - val_loss: 1.4546 - val_accuracy: 0.5423
# Epoch 241/1000
# 11/11 [==============================] - 8s 709ms/step - loss: 0.9847 - accuracy: 0.6495 - val_loss: 1.0888 - val_accuracy: 0.6479
# Epoch 242/1000
# 11/11 [==============================] - 8s 710ms/step - loss: 0.7855 - accuracy: 0.7010 - val_loss: 0.9971 - val_accuracy: 0.6197
# Epoch 243/1000
# 11/11 [==============================] - 8s 782ms/step - loss: 0.6727 - accuracy: 0.7586 - val_loss: 1.0425 - val_accuracy: 0.6408
# Epoch 244/1000
# 11/11 [==============================] - 8s 706ms/step - loss: 0.8873 - accuracy: 0.6593 - val_loss: 0.9978 - val_accuracy: 0.6690
# Epoch 245/1000
# 11/11 [==============================] - 8s 722ms/step - loss: 0.7348 - accuracy: 0.7463 - val_loss: 1.1937 - val_accuracy: 0.5915
# Epoch 246/1000
# 11/11 [==============================] - 8s 720ms/step - loss: 0.8550 - accuracy: 0.6900 - val_loss: 1.1572 - val_accuracy: 0.5704
# Epoch 247/1000
# 11/11 [==============================] - 8s 710ms/step - loss: 0.7341 - accuracy: 0.7145 - val_loss: 0.9973 - val_accuracy: 0.6690
# Epoch 248/1000
# 11/11 [==============================] - 8s 717ms/step - loss: 0.8078 - accuracy: 0.7279 - val_loss: 1.0531 - val_accuracy: 0.6408
# Epoch 249/1000
# 11/11 [==============================] - 8s 709ms/step - loss: 0.6879 - accuracy: 0.7598 - val_loss: 1.4227 - val_accuracy: 0.5563
# Epoch 250/1000
# 11/11 [==============================] - 8s 717ms/step - loss: 0.8000 - accuracy: 0.7034 - val_loss: 1.1555 - val_accuracy: 0.5634
# Epoch 251/1000
# 11/11 [==============================] - 8s 712ms/step - loss: 0.7937 - accuracy: 0.7034 - val_loss: 1.2290 - val_accuracy: 0.5775
# Epoch 252/1000
# 11/11 [==============================] - 8s 787ms/step - loss: 0.8127 - accuracy: 0.7218 - val_loss: 1.0341 - val_accuracy: 0.6338
# Epoch 253/1000
# 11/11 [==============================] - 8s 703ms/step - loss: 0.6572 - accuracy: 0.7672 - val_loss: 1.2420 - val_accuracy: 0.5423
# Epoch 254/1000
# 11/11 [==============================] - 8s 721ms/step - loss: 0.8233 - accuracy: 0.7022 - val_loss: 1.0375 - val_accuracy: 0.6268
# Epoch 255/1000
# 11/11 [==============================] - 8s 804ms/step - loss: 0.7587 - accuracy: 0.7353 - val_loss: 1.0058 - val_accuracy: 0.6549
# Epoch 256/1000
# 11/11 [==============================] - 8s 755ms/step - loss: 0.7817 - accuracy: 0.7071 - val_loss: 1.0996 - val_accuracy: 0.6197
# Epoch 257/1000
# 11/11 [==============================] - 8s 736ms/step - loss: 0.6898 - accuracy: 0.7696 - val_loss: 0.9212 - val_accuracy: 0.6549
# Epoch 258/1000
# 11/11 [==============================] - 8s 743ms/step - loss: 0.7962 - accuracy: 0.7169 - val_loss: 0.9070 - val_accuracy: 0.6972
# Epoch 259/1000
# 11/11 [==============================] - 8s 748ms/step - loss: 0.7231 - accuracy: 0.7475 - val_loss: 1.3143 - val_accuracy: 0.5493
# Epoch 260/1000
# 11/11 [==============================] - 8s 757ms/step - loss: 0.6285 - accuracy: 0.7880 - val_loss: 1.0089 - val_accuracy: 0.6690
# Epoch 261/1000
# 11/11 [==============================] - 8s 799ms/step - loss: 0.7797 - accuracy: 0.7243 - val_loss: 0.9853 - val_accuracy: 0.6268
# Epoch 262/1000
# 11/11 [==============================] - 8s 725ms/step - loss: 0.7198 - accuracy: 0.7292 - val_loss: 0.9216 - val_accuracy: 0.6479
# Epoch 263/1000
# 11/11 [==============================] - 8s 726ms/step - loss: 0.7538 - accuracy: 0.7353 - val_loss: 0.9734 - val_accuracy: 0.6620
# Epoch 264/1000
# 11/11 [==============================] - 8s 714ms/step - loss: 0.7289 - accuracy: 0.7377 - val_loss: 1.1923 - val_accuracy: 0.5915
# Epoch 265/1000
# 11/11 [==============================] - 8s 723ms/step - loss: 0.7659 - accuracy: 0.7206 - val_loss: 0.8936 - val_accuracy: 0.7183
# Epoch 266/1000
# 11/11 [==============================] - 8s 791ms/step - loss: 0.7038 - accuracy: 0.7414 - val_loss: 1.1296 - val_accuracy: 0.5423
# Epoch 267/1000
# 11/11 [==============================] - 8s 720ms/step - loss: 0.6608 - accuracy: 0.7623 - val_loss: 0.9891 - val_accuracy: 0.6620
# Epoch 268/1000
# 11/11 [==============================] - 8s 715ms/step - loss: 0.8135 - accuracy: 0.7157 - val_loss: 1.3922 - val_accuracy: 0.5493
# Epoch 269/1000
# 11/11 [==============================] - 8s 724ms/step - loss: 0.8299 - accuracy: 0.7034 - val_loss: 1.1066 - val_accuracy: 0.6197
# Epoch 270/1000
# 11/11 [==============================] - 8s 721ms/step - loss: 0.7664 - accuracy: 0.7292 - val_loss: 0.9391 - val_accuracy: 0.6690
# Epoch 271/1000
# 11/11 [==============================] - 8s 714ms/step - loss: 0.6527 - accuracy: 0.7463 - val_loss: 0.9830 - val_accuracy: 0.6408
# Epoch 272/1000
# 11/11 [==============================] - 8s 718ms/step - loss: 0.6737 - accuracy: 0.7586 - val_loss: 0.9938 - val_accuracy: 0.6620
# Epoch 273/1000
# 11/11 [==============================] - 8s 718ms/step - loss: 0.7125 - accuracy: 0.7365 - val_loss: 0.9789 - val_accuracy: 0.6620
# Epoch 274/1000
# 11/11 [==============================] - 8s 719ms/step - loss: 0.7349 - accuracy: 0.7414 - val_loss: 0.9373 - val_accuracy: 0.6901
# Epoch 275/1000
# 11/11 [==============================] - 8s 718ms/step - loss: 0.6820 - accuracy: 0.7463 - val_loss: 1.0942 - val_accuracy: 0.6197
# Epoch 276/1000
# 11/11 [==============================] - 8s 713ms/step - loss: 0.7513 - accuracy: 0.7255 - val_loss: 0.9107 - val_accuracy: 0.7183
# Epoch 277/1000
# 11/11 [==============================] - 8s 724ms/step - loss: 0.7616 - accuracy: 0.7181 - val_loss: 1.0279 - val_accuracy: 0.6620
# Epoch 278/1000
# 11/11 [==============================] - 8s 707ms/step - loss: 0.6533 - accuracy: 0.7500 - val_loss: 1.1493 - val_accuracy: 0.6338
# Epoch 279/1000
# 11/11 [==============================] - 8s 724ms/step - loss: 0.7379 - accuracy: 0.7243 - val_loss: 0.8431 - val_accuracy: 0.7042
# Epoch 280/1000
# 11/11 [==============================] - 8s 704ms/step - loss: 0.7099 - accuracy: 0.7500 - val_loss: 1.4670 - val_accuracy: 0.4789
# Epoch 281/1000
# 11/11 [==============================] - 8s 715ms/step - loss: 0.7151 - accuracy: 0.7659 - val_loss: 1.1399 - val_accuracy: 0.6268
# Epoch 282/1000
# 11/11 [==============================] - 8s 782ms/step - loss: 0.6540 - accuracy: 0.7659 - val_loss: 0.9198 - val_accuracy: 0.6972
# Epoch 283/1000
# 11/11 [==============================] - 8s 715ms/step - loss: 0.7120 - accuracy: 0.7463 - val_loss: 1.0052 - val_accuracy: 0.6197
# Epoch 284/1000
# 11/11 [==============================] - 8s 717ms/step - loss: 0.6173 - accuracy: 0.7831 - val_loss: 0.9805 - val_accuracy: 0.6620
# Epoch 285/1000
# 11/11 [==============================] - 8s 722ms/step - loss: 0.7952 - accuracy: 0.7255 - val_loss: 1.2285 - val_accuracy: 0.5775
# Epoch 286/1000
# 11/11 [==============================] - 8s 722ms/step - loss: 0.7082 - accuracy: 0.7537 - val_loss: 0.9478 - val_accuracy: 0.6972
# Epoch 287/1000
# 11/11 [==============================] - 8s 713ms/step - loss: 0.7815 - accuracy: 0.7230 - val_loss: 0.9294 - val_accuracy: 0.6690
# Epoch 288/1000
# 11/11 [==============================] - 8s 712ms/step - loss: 0.6606 - accuracy: 0.7610 - val_loss: 0.9939 - val_accuracy: 0.6408
# Epoch 289/1000
# 11/11 [==============================] - 8s 715ms/step - loss: 0.6923 - accuracy: 0.7574 - val_loss: 1.0758 - val_accuracy: 0.6056
# Epoch 290/1000
# 11/11 [==============================] - 8s 714ms/step - loss: 0.6308 - accuracy: 0.7929 - val_loss: 1.1145 - val_accuracy: 0.6127
# Epoch 291/1000
# 11/11 [==============================] - 8s 717ms/step - loss: 0.6245 - accuracy: 0.7708 - val_loss: 1.2842 - val_accuracy: 0.5704
# Epoch 292/1000
# 11/11 [==============================] - 8s 729ms/step - loss: 0.7553 - accuracy: 0.7328 - val_loss: 0.9949 - val_accuracy: 0.6901
# Epoch 293/1000
# 11/11 [==============================] - 8s 717ms/step - loss: 0.7449 - accuracy: 0.7243 - val_loss: 1.1950 - val_accuracy: 0.5704
# Epoch 294/1000
# 11/11 [==============================] - 8s 734ms/step - loss: 0.6260 - accuracy: 0.7819 - val_loss: 1.2014 - val_accuracy: 0.5845
# Epoch 295/1000
# 11/11 [==============================] - 8s 740ms/step - loss: 0.5766 - accuracy: 0.7880 - val_loss: 0.9701 - val_accuracy: 0.6690
# Epoch 296/1000
# 11/11 [==============================] - 8s 725ms/step - loss: 0.6630 - accuracy: 0.7794 - val_loss: 0.9762 - val_accuracy: 0.6620
# Epoch 297/1000
# 11/11 [==============================] - 8s 741ms/step - loss: 0.5659 - accuracy: 0.8088 - val_loss: 1.9831 - val_accuracy: 0.4225
# Epoch 298/1000
# 11/11 [==============================] - 8s 717ms/step - loss: 0.8234 - accuracy: 0.7426 - val_loss: 1.2497 - val_accuracy: 0.5634
# Epoch 299/1000
# 11/11 [==============================] - 8s 804ms/step - loss: 0.6091 - accuracy: 0.7941 - val_loss: 0.9660 - val_accuracy: 0.6620
# Epoch 300/1000
# 11/11 [==============================] - 8s 733ms/step - loss: 0.6265 - accuracy: 0.7917 - val_loss: 0.9070 - val_accuracy: 0.7042
# Epoch 301/1000
# 11/11 [==============================] - 8s 727ms/step - loss: 0.6004 - accuracy: 0.7782 - val_loss: 0.9432 - val_accuracy: 0.6901
# Epoch 302/1000
# 11/11 [==============================] - 8s 733ms/step - loss: 0.7472 - accuracy: 0.7292 - val_loss: 1.1112 - val_accuracy: 0.6479
# Epoch 303/1000
# 11/11 [==============================] - 8s 730ms/step - loss: 0.5943 - accuracy: 0.7868 - val_loss: 0.9998 - val_accuracy: 0.6197
# Epoch 304/1000
# 11/11 [==============================] - 8s 732ms/step - loss: 0.5551 - accuracy: 0.7917 - val_loss: 1.0191 - val_accuracy: 0.6549
# Epoch 305/1000
# 11/11 [==============================] - 8s 725ms/step - loss: 0.6499 - accuracy: 0.7696 - val_loss: 1.0574 - val_accuracy: 0.6408
# Epoch 306/1000
# 11/11 [==============================] - 8s 727ms/step - loss: 0.7131 - accuracy: 0.7610 - val_loss: 1.0424 - val_accuracy: 0.6268
# Epoch 307/1000
# 11/11 [==============================] - 8s 815ms/step - loss: 0.6485 - accuracy: 0.7733 - val_loss: 1.1200 - val_accuracy: 0.6268
# Epoch 308/1000
# 11/11 [==============================] - 8s 744ms/step - loss: 0.5682 - accuracy: 0.8027 - val_loss: 1.1789 - val_accuracy: 0.6338
# Epoch 309/1000
# 11/11 [==============================] - 8s 739ms/step - loss: 0.7809 - accuracy: 0.7316 - val_loss: 0.9429 - val_accuracy: 0.6761
# Epoch 310/1000
# 11/11 [==============================] - 8s 728ms/step - loss: 0.5926 - accuracy: 0.7978 - val_loss: 1.8234 - val_accuracy: 0.4437
# Epoch 311/1000
# 11/11 [==============================] - 8s 722ms/step - loss: 0.6585 - accuracy: 0.7463 - val_loss: 0.9627 - val_accuracy: 0.6901
# Epoch 312/1000
# 11/11 [==============================] - 8s 719ms/step - loss: 0.6522 - accuracy: 0.7770 - val_loss: 0.9703 - val_accuracy: 0.6620
# Epoch 313/1000
# 11/11 [==============================] - 8s 741ms/step - loss: 0.5677 - accuracy: 0.7990 - val_loss: 0.9180 - val_accuracy: 0.6972
# Epoch 314/1000
# 11/11 [==============================] - 8s 721ms/step - loss: 0.6300 - accuracy: 0.7806 - val_loss: 1.2884 - val_accuracy: 0.6197
# Epoch 315/1000
# 11/11 [==============================] - 8s 726ms/step - loss: 0.6564 - accuracy: 0.7684 - val_loss: 1.5206 - val_accuracy: 0.5211
# Epoch 316/1000
# 11/11 [==============================] - 8s 711ms/step - loss: 0.7450 - accuracy: 0.7426 - val_loss: 1.1699 - val_accuracy: 0.6127
# Epoch 317/1000
# 11/11 [==============================] - 8s 724ms/step - loss: 0.6748 - accuracy: 0.7635 - val_loss: 1.2464 - val_accuracy: 0.5986
# Epoch 318/1000
# 11/11 [==============================] - 8s 721ms/step - loss: 0.5945 - accuracy: 0.7782 - val_loss: 1.1744 - val_accuracy: 0.6338
# Epoch 319/1000
# 11/11 [==============================] - 8s 718ms/step - loss: 0.6568 - accuracy: 0.7598 - val_loss: 1.0293 - val_accuracy: 0.6831
# Epoch 320/1000
# 11/11 [==============================] - 8s 716ms/step - loss: 0.5872 - accuracy: 0.7880 - val_loss: 1.0856 - val_accuracy: 0.6479
# Epoch 321/1000
# 11/11 [==============================] - 8s 715ms/step - loss: 0.7040 - accuracy: 0.7512 - val_loss: 0.9564 - val_accuracy: 0.6690
# Epoch 322/1000
# 11/11 [==============================] - 8s 722ms/step - loss: 0.7050 - accuracy: 0.7549 - val_loss: 1.0051 - val_accuracy: 0.6620
# Epoch 323/1000
# 11/11 [==============================] - 8s 720ms/step - loss: 0.6346 - accuracy: 0.7806 - val_loss: 0.9509 - val_accuracy: 0.6972
# Epoch 324/1000
# 11/11 [==============================] - 8s 723ms/step - loss: 0.6090 - accuracy: 0.7990 - val_loss: 1.1283 - val_accuracy: 0.6620
# Epoch 325/1000
# 11/11 [==============================] - 8s 722ms/step - loss: 0.5688 - accuracy: 0.8039 - val_loss: 1.0179 - val_accuracy: 0.6690
# Epoch 326/1000
# 11/11 [==============================] - 8s 720ms/step - loss: 0.8551 - accuracy: 0.7047 - val_loss: 0.9710 - val_accuracy: 0.6620
# Epoch 327/1000
# 11/11 [==============================] - 8s 710ms/step - loss: 0.5865 - accuracy: 0.8002 - val_loss: 0.9434 - val_accuracy: 0.6831
# Epoch 328/1000
# 11/11 [==============================] - 8s 724ms/step - loss: 0.5091 - accuracy: 0.8260 - val_loss: 0.9706 - val_accuracy: 0.6972
# Epoch 329/1000
# 11/11 [==============================] - 8s 716ms/step - loss: 0.5181 - accuracy: 0.8235 - val_loss: 1.4423 - val_accuracy: 0.5352
# Epoch 330/1000
# ...
# Epoch 892/1000
# 11/11 [==============================] - 8s 731ms/step - loss: 0.2602 - accuracy: 0.9179 - val_loss: 1.2167 - val_accuracy: 0.6901
# Epoch 893/1000
# 11/11 [==============================] - 8s 790ms/step - loss: 0.1927 - accuracy: 0.9289 - val_loss: 1.0052 - val_accuracy: 0.7254
# Epoch 894/1000
# 11/11 [==============================] - 8s 715ms/step - loss: 0.1845 - accuracy: 0.9326 - val_loss: 1.1392 - val_accuracy: 0.7254
# Epoch 895/1000
# 11/11 [==============================] - 8s 721ms/step - loss: 0.2346 - accuracy: 0.9301 - val_loss: 1.1889 - val_accuracy: 0.6831
# Epoch 896/1000
# 11/11 [==============================] - 8s 727ms/step - loss: 0.2441 - accuracy: 0.9314 - val_loss: 1.2028 - val_accuracy: 0.7042
# Epoch 897/1000
# 11/11 [==============================] - 8s 727ms/step - loss: 0.2157 - accuracy: 0.9387 - val_loss: 1.1247 - val_accuracy: 0.7535
# Epoch 898/1000
# 11/11 [==============================] - 8s 776ms/step - loss: 0.1814 - accuracy: 0.9473 - val_loss: 1.1429 - val_accuracy: 0.7676
# Epoch 899/1000
# 11/11 [==============================] - 8s 719ms/step - loss: 0.2952 - accuracy: 0.9105 - val_loss: 1.1400 - val_accuracy: 0.7254
# Epoch 900/1000
# 11/11 [==============================] - 8s 715ms/step - loss: 0.1723 - accuracy: 0.9510 - val_loss: 0.9333 - val_accuracy: 0.7887
# Epoch 901/1000
# 11/11 [==============================] - 8s 730ms/step - loss: 0.1418 - accuracy: 0.9571 - val_loss: 1.2889 - val_accuracy: 0.7254
# Epoch 902/1000
# 11/11 [==============================] - 8s 726ms/step - loss: 0.3477 - accuracy: 0.9020 - val_loss: 1.0373 - val_accuracy: 0.7183
# Epoch 903/1000
# 11/11 [==============================] - 8s 733ms/step - loss: 0.1565 - accuracy: 0.9583 - val_loss: 1.1056 - val_accuracy: 0.7746
# Epoch 904/1000
# 11/11 [==============================] - 8s 723ms/step - loss: 0.1651 - accuracy: 0.9400 - val_loss: 1.1217 - val_accuracy: 0.7606
# Epoch 905/1000
# 11/11 [==============================] - 8s 711ms/step - loss: 0.2809 - accuracy: 0.9216 - val_loss: 1.2200 - val_accuracy: 0.7113
# Epoch 906/1000
# 11/11 [==============================] - 8s 726ms/step - loss: 0.1475 - accuracy: 0.9498 - val_loss: 1.4265 - val_accuracy: 0.7042
# Epoch 907/1000
# 11/11 [==============================] - 8s 724ms/step - loss: 0.1570 - accuracy: 0.9473 - val_loss: 1.1330 - val_accuracy: 0.7465
# Epoch 908/1000
# 11/11 [==============================] - 8s 715ms/step - loss: 0.2596 - accuracy: 0.9179 - val_loss: 1.2765 - val_accuracy: 0.7535
# Epoch 909/1000
# 11/11 [==============================] - 8s 721ms/step - loss: 0.2573 - accuracy: 0.9326 - val_loss: 1.2710 - val_accuracy: 0.7535
# Epoch 910/1000
# 11/11 [==============================] - 8s 714ms/step - loss: 0.2044 - accuracy: 0.9424 - val_loss: 1.1851 - val_accuracy: 0.7746
# Epoch 911/1000
# 11/11 [==============================] - 8s 716ms/step - loss: 0.2242 - accuracy: 0.9216 - val_loss: 1.5565 - val_accuracy: 0.7042
# Epoch 912/1000
# 11/11 [==============================] - 8s 726ms/step - loss: 0.3180 - accuracy: 0.8995 - val_loss: 1.1295 - val_accuracy: 0.7465
# Epoch 913/1000
# 11/11 [==============================] - 8s 727ms/step - loss: 0.2756 - accuracy: 0.9154 - val_loss: 1.0520 - val_accuracy: 0.7676
# Epoch 914/1000
# 11/11 [==============================] - 8s 725ms/step - loss: 0.2039 - accuracy: 0.9387 - val_loss: 1.4284 - val_accuracy: 0.6761
# Epoch 915/1000
# 11/11 [==============================] - 8s 720ms/step - loss: 0.2141 - accuracy: 0.9277 - val_loss: 1.1932 - val_accuracy: 0.7113
# Epoch 916/1000
# 11/11 [==============================] - 8s 719ms/step - loss: 0.2440 - accuracy: 0.9228 - val_loss: 1.3044 - val_accuracy: 0.7042
# Epoch 917/1000
# 11/11 [==============================] - 8s 786ms/step - loss: 0.2200 - accuracy: 0.9350 - val_loss: 1.2187 - val_accuracy: 0.7394
# Epoch 918/1000
# 11/11 [==============================] - 8s 708ms/step - loss: 0.2371 - accuracy: 0.9240 - val_loss: 1.2838 - val_accuracy: 0.7042
# Epoch 919/1000
# 11/11 [==============================] - 8s 726ms/step - loss: 0.5156 - accuracy: 0.8799 - val_loss: 0.9836 - val_accuracy: 0.7465
# Epoch 920/1000
# 11/11 [==============================] - 8s 725ms/step - loss: 0.1895 - accuracy: 0.9412 - val_loss: 1.1174 - val_accuracy: 0.7183
# Epoch 921/1000
# 11/11 [==============================] - 8s 719ms/step - loss: 0.2039 - accuracy: 0.9289 - val_loss: 1.1529 - val_accuracy: 0.7324
# Epoch 922/1000
# 11/11 [==============================] - 8s 726ms/step - loss: 0.2797 - accuracy: 0.9191 - val_loss: 1.0599 - val_accuracy: 0.7394
# Epoch 923/1000
# 11/11 [==============================] - 8s 726ms/step - loss: 0.2331 - accuracy: 0.9277 - val_loss: 1.0412 - val_accuracy: 0.7465
# Epoch 924/1000
# 11/11 [==============================] - 8s 711ms/step - loss: 0.2408 - accuracy: 0.9326 - val_loss: 1.1812 - val_accuracy: 0.7042
# Epoch 925/1000
# 11/11 [==============================] - 8s 729ms/step - loss: 0.1811 - accuracy: 0.9412 - val_loss: 1.2548 - val_accuracy: 0.7746
# Epoch 926/1000
# 11/11 [==============================] - 8s 729ms/step - loss: 0.2541 - accuracy: 0.9179 - val_loss: 1.0862 - val_accuracy: 0.7817
# Epoch 927/1000
# 11/11 [==============================] - 8s 730ms/step - loss: 0.2798 - accuracy: 0.9240 - val_loss: 1.1860 - val_accuracy: 0.7042
# Epoch 928/1000
# 11/11 [==============================] - 8s 726ms/step - loss: 0.1997 - accuracy: 0.9387 - val_loss: 1.2870 - val_accuracy: 0.7113
# Epoch 929/1000
# 11/11 [==============================] - 8s 726ms/step - loss: 0.1626 - accuracy: 0.9400 - val_loss: 1.2079 - val_accuracy: 0.7535
# Epoch 930/1000
# 11/11 [==============================] - 8s 728ms/step - loss: 0.2357 - accuracy: 0.9265 - val_loss: 1.3155 - val_accuracy: 0.6972
# Epoch 931/1000
# 11/11 [==============================] - 8s 713ms/step - loss: 0.2825 - accuracy: 0.9130 - val_loss: 0.9620 - val_accuracy: 0.7676
# Epoch 932/1000
# 11/11 [==============================] - 8s 720ms/step - loss: 0.1289 - accuracy: 0.9559 - val_loss: 1.4534 - val_accuracy: 0.7042
# Epoch 933/1000
# 11/11 [==============================] - 8s 729ms/step - loss: 0.1801 - accuracy: 0.9485 - val_loss: 1.2864 - val_accuracy: 0.7324
# Epoch 934/1000
# 11/11 [==============================] - 8s 727ms/step - loss: 0.1969 - accuracy: 0.9461 - val_loss: 2.2619 - val_accuracy: 0.6197
# Epoch 935/1000
# 11/11 [==============================] - 8s 715ms/step - loss: 0.4309 - accuracy: 0.9020 - val_loss: 1.0977 - val_accuracy: 0.7394
# Epoch 936/1000
# 11/11 [==============================] - 8s 722ms/step - loss: 0.2029 - accuracy: 0.9289 - val_loss: 1.4719 - val_accuracy: 0.6901
# Epoch 937/1000
# 11/11 [==============================] - 8s 717ms/step - loss: 0.2282 - accuracy: 0.9301 - val_loss: 1.0338 - val_accuracy: 0.7465
# Epoch 938/1000
# 11/11 [==============================] - 8s 719ms/step - loss: 0.1811 - accuracy: 0.9436 - val_loss: 1.1728 - val_accuracy: 0.7183
# Epoch 939/1000
# 11/11 [==============================] - 8s 723ms/step - loss: 0.2893 - accuracy: 0.9179 - val_loss: 1.2725 - val_accuracy: 0.7254
# Epoch 940/1000
# 11/11 [==============================] - 8s 723ms/step - loss: 0.2135 - accuracy: 0.9265 - val_loss: 1.0935 - val_accuracy: 0.7394
# Epoch 941/1000
# 11/11 [==============================] - 8s 708ms/step - loss: 0.2207 - accuracy: 0.9314 - val_loss: 1.1763 - val_accuracy: 0.7183
# Epoch 942/1000
# 11/11 [==============================] - 8s 723ms/step - loss: 0.1757 - accuracy: 0.9436 - val_loss: 1.5523 - val_accuracy: 0.6479
# Epoch 943/1000
# 11/11 [==============================] - 8s 724ms/step - loss: 0.2521 - accuracy: 0.9069 - val_loss: 1.1132 - val_accuracy: 0.7465
# Epoch 944/1000
# 11/11 [==============================] - 8s 719ms/step - loss: 0.2213 - accuracy: 0.9203 - val_loss: 1.1539 - val_accuracy: 0.7042
# Epoch 945/1000
# 11/11 [==============================] - 8s 721ms/step - loss: 0.1849 - accuracy: 0.9363 - val_loss: 1.3736 - val_accuracy: 0.6972
# Epoch 946/1000
# 11/11 [==============================] - 8s 723ms/step - loss: 0.2069 - accuracy: 0.9400 - val_loss: 1.3054 - val_accuracy: 0.6901
# Epoch 947/1000
# 11/11 [==============================] - 8s 723ms/step - loss: 0.1677 - accuracy: 0.9424 - val_loss: 1.1133 - val_accuracy: 0.7746
# Epoch 948/1000
# 11/11 [==============================] - 8s 717ms/step - loss: 0.1581 - accuracy: 0.9485 - val_loss: 1.5926 - val_accuracy: 0.6761
# Epoch 949/1000
# 11/11 [==============================] - 8s 723ms/step - loss: 0.2034 - accuracy: 0.9424 - val_loss: 1.3955 - val_accuracy: 0.7394
# Epoch 950/1000
# 11/11 [==============================] - 8s 783ms/step - loss: 0.2435 - accuracy: 0.9289 - val_loss: 1.1221 - val_accuracy: 0.7606
# Epoch 951/1000
# 11/11 [==============================] - 8s 710ms/step - loss: 0.1665 - accuracy: 0.9571 - val_loss: 1.3344 - val_accuracy: 0.6901
# Epoch 952/1000
# 11/11 [==============================] - 8s 777ms/step - loss: 0.3210 - accuracy: 0.8934 - val_loss: 1.2242 - val_accuracy: 0.7465
# Epoch 953/1000
# 11/11 [==============================] - 8s 717ms/step - loss: 0.2710 - accuracy: 0.9191 - val_loss: 1.9547 - val_accuracy: 0.6408
# Epoch 954/1000
# 11/11 [==============================] - 8s 723ms/step - loss: 0.2016 - accuracy: 0.9350 - val_loss: 1.0667 - val_accuracy: 0.7676
# Epoch 955/1000
# 11/11 [==============================] - 8s 718ms/step - loss: 0.1340 - accuracy: 0.9608 - val_loss: 1.2383 - val_accuracy: 0.7465
# Epoch 956/1000
# 11/11 [==============================] - 8s 731ms/step - loss: 0.1976 - accuracy: 0.9265 - val_loss: 1.3749 - val_accuracy: 0.7042
# Epoch 957/1000
# 11/11 [==============================] - 8s 718ms/step - loss: 0.2044 - accuracy: 0.9338 - val_loss: 1.0625 - val_accuracy: 0.7465
# Epoch 958/1000
# 11/11 [==============================] - 8s 716ms/step - loss: 0.1720 - accuracy: 0.9534 - val_loss: 1.4139 - val_accuracy: 0.7183
# Epoch 959/1000
# 11/11 [==============================] - 8s 722ms/step - loss: 0.3561 - accuracy: 0.8946 - val_loss: 0.9619 - val_accuracy: 0.7465
# Epoch 960/1000
# 11/11 [==============================] - 8s 702ms/step - loss: 0.1409 - accuracy: 0.9461 - val_loss: 1.4005 - val_accuracy: 0.6972
# Epoch 961/1000
# 11/11 [==============================] - 8s 721ms/step - loss: 0.4749 - accuracy: 0.8897 - val_loss: 0.8612 - val_accuracy: 0.7746
# Epoch 962/1000
# 11/11 [==============================] - 8s 721ms/step - loss: 0.1288 - accuracy: 0.9559 - val_loss: 0.9730 - val_accuracy: 0.7676
# Epoch 963/1000
# 11/11 [==============================] - 8s 733ms/step - loss: 0.1705 - accuracy: 0.9461 - val_loss: 1.2844 - val_accuracy: 0.7042
# Epoch 964/1000
# 11/11 [==============================] - 8s 724ms/step - loss: 0.1360 - accuracy: 0.9547 - val_loss: 1.3488 - val_accuracy: 0.7183
# Epoch 965/1000
# 11/11 [==============================] - 8s 714ms/step - loss: 0.2107 - accuracy: 0.9363 - val_loss: 1.4291 - val_accuracy: 0.6972
# Epoch 966/1000
# 11/11 [==============================] - 8s 715ms/step - loss: 0.3251 - accuracy: 0.8971 - val_loss: 1.1689 - val_accuracy: 0.7113
# Epoch 967/1000
# 11/11 [==============================] - 8s 724ms/step - loss: 0.1742 - accuracy: 0.9424 - val_loss: 1.0510 - val_accuracy: 0.7535
# Epoch 968/1000
# 11/11 [==============================] - 8s 784ms/step - loss: 0.2124 - accuracy: 0.9400 - val_loss: 1.0829 - val_accuracy: 0.7535
# Epoch 969/1000
# 11/11 [==============================] - 8s 718ms/step - loss: 0.3777 - accuracy: 0.9032 - val_loss: 1.0990 - val_accuracy: 0.7324
# Epoch 970/1000
# 11/11 [==============================] - 8s 787ms/step - loss: 0.1419 - accuracy: 0.9571 - val_loss: 1.3418 - val_accuracy: 0.7042
# Epoch 971/1000
# 11/11 [==============================] - 8s 716ms/step - loss: 0.2245 - accuracy: 0.9400 - val_loss: 0.9802 - val_accuracy: 0.7535
# Epoch 972/1000
# 11/11 [==============================] - 8s 716ms/step - loss: 0.2255 - accuracy: 0.9203 - val_loss: 1.1192 - val_accuracy: 0.7183
# Epoch 973/1000
# 11/11 [==============================] - 8s 739ms/step - loss: 0.2688 - accuracy: 0.9056 - val_loss: 1.0896 - val_accuracy: 0.7254
# Epoch 974/1000
# 11/11 [==============================] - 8s 724ms/step - loss: 0.1278 - accuracy: 0.9559 - val_loss: 1.2997 - val_accuracy: 0.7324
# Epoch 975/1000
# 11/11 [==============================] - 8s 711ms/step - loss: 0.2266 - accuracy: 0.9412 - val_loss: 1.0463 - val_accuracy: 0.7394
# Epoch 976/1000
# 11/11 [==============================] - 8s 736ms/step - loss: 0.1628 - accuracy: 0.9485 - val_loss: 1.3606 - val_accuracy: 0.6831
# Epoch 977/1000
# 11/11 [==============================] - 8s 733ms/step - loss: 0.1238 - accuracy: 0.9608 - val_loss: 1.2236 - val_accuracy: 0.7183
# Epoch 978/1000
# 11/11 [==============================] - 8s 713ms/step - loss: 0.2250 - accuracy: 0.9326 - val_loss: 1.4924 - val_accuracy: 0.6690
# Epoch 979/1000
# 11/11 [==============================] - 8s 722ms/step - loss: 0.2170 - accuracy: 0.9338 - val_loss: 1.0256 - val_accuracy: 0.7324
# Epoch 980/1000
# 11/11 [==============================] - 8s 730ms/step - loss: 0.1630 - accuracy: 0.9571 - val_loss: 1.1442 - val_accuracy: 0.7465
# Epoch 981/1000
# 11/11 [==============================] - 8s 714ms/step - loss: 0.2476 - accuracy: 0.9350 - val_loss: 1.1850 - val_accuracy: 0.7183
# Epoch 982/1000
# 11/11 [==============================] - 8s 724ms/step - loss: 0.2159 - accuracy: 0.9240 - val_loss: 1.1740 - val_accuracy: 0.7324
# Epoch 983/1000
# 11/11 [==============================] - 8s 731ms/step - loss: 0.3321 - accuracy: 0.9020 - val_loss: 0.9721 - val_accuracy: 0.7465
# Epoch 984/1000
# 11/11 [==============================] - 8s 731ms/step - loss: 0.1454 - accuracy: 0.9534 - val_loss: 1.7088 - val_accuracy: 0.6197
# Epoch 985/1000
# 11/11 [==============================] - 8s 722ms/step - loss: 0.1314 - accuracy: 0.9473 - val_loss: 1.3897 - val_accuracy: 0.7042
# Epoch 986/1000
# 11/11 [==============================] - 8s 726ms/step - loss: 0.2625 - accuracy: 0.9240 - val_loss: 1.6392 - val_accuracy: 0.6831
# Epoch 987/1000
# 11/11 [==============================] - 8s 719ms/step - loss: 0.2144 - accuracy: 0.9252 - val_loss: 1.1515 - val_accuracy: 0.7465
# Epoch 988/1000
# 11/11 [==============================] - 8s 716ms/step - loss: 0.2442 - accuracy: 0.9412 - val_loss: 1.2714 - val_accuracy: 0.7113
# Epoch 989/1000
# 11/11 [==============================] - 8s 715ms/step - loss: 0.2316 - accuracy: 0.9424 - val_loss: 1.4352 - val_accuracy: 0.6831
# Epoch 990/1000
# 11/11 [==============================] - 8s 718ms/step - loss: 0.2282 - accuracy: 0.9338 - val_loss: 1.1972 - val_accuracy: 0.7324
# Epoch 991/1000
# 11/11 [==============================] - 8s 732ms/step - loss: 0.1988 - accuracy: 0.9375 - val_loss: 0.9893 - val_accuracy: 0.7535
# Epoch 992/1000
# 11/11 [==============================] - 8s 724ms/step - loss: 0.2851 - accuracy: 0.9167 - val_loss: 0.9785 - val_accuracy: 0.7324
# Epoch 993/1000
# 11/11 [==============================] - 8s 733ms/step - loss: 0.1403 - accuracy: 0.9645 - val_loss: 1.0246 - val_accuracy: 0.7465
# Epoch 994/1000
# 11/11 [==============================] - 8s 719ms/step - loss: 0.2656 - accuracy: 0.9252 - val_loss: 1.0576 - val_accuracy: 0.7535
# Epoch 995/1000
# 11/11 [==============================] - 8s 728ms/step - loss: 0.1643 - accuracy: 0.9412 - val_loss: 1.1485 - val_accuracy: 0.7394
# Epoch 996/1000
# 11/11 [==============================] - 8s 784ms/step - loss: 0.1643 - accuracy: 0.9473 - val_loss: 1.2045 - val_accuracy: 0.7746
# Epoch 997/1000
# 11/11 [==============================] - 8s 710ms/step - loss: 0.2122 - accuracy: 0.9449 - val_loss: 1.2703 - val_accuracy: 0.6972
# Epoch 998/1000
# 11/11 [==============================] - 8s 722ms/step - loss: 0.2237 - accuracy: 0.9314 - val_loss: 1.2832 - val_accuracy: 0.7324
# Epoch 999/1000
# 11/11 [==============================] - 8s 724ms/step - loss: 0.2750 - accuracy: 0.9081 - val_loss: 1.7973 - val_accuracy: 0.6127
# Epoch 1000/1000
# 11/11 [==============================] - 8s 722ms/step - loss: 0.2486 - accuracy: 0.9191 - val_loss: 1.4144 - val_accuracy: 0.6761

# %%
train_datagen.flow_from_directory?

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import random
import tensorflow_datasets as tfds
import matplotlib.image as img
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist
import numpy as np
num_classes = 5 #metadata.features['label'].num_classes
print(num_classes)

#get_label_name = metadata.features['label'].int2str

image  =img.imread( '/tmp/Data_T2/Serval/serval (138).jpg')
#print(label[0])
image=image[:, :,: ]
_ = plt.imshow(image)
#_ = plt.title(get_label_name(label))
#print(image)

#IMG_SIZE = 180

#resize_and_rescale = tf.keras.Sequential([
#  layers.experimental.preprocessing.Resizing(IMG_SIZE, IMG_SIZE),
#  layers.experimental.preprocessing.Rescaling(1./255)

#])
#guepardo, leo2, lince,ocelote, serval
#result = resize_and_rescale(image)
#_ = plt.imshow(result))
# Out:
# 5

# %%
#_ = plt.title(get_label_name(label))
#print(image)

IMG_SIZE = 400
resize_and_rescale = tf.keras.Sequential([
  layers.experimental.preprocessing.Resizing(IMG_SIZE, IMG_SIZE),
  layers.experimental.preprocessing.Rescaling(1./255)

])

result = resize_and_rescale(image)
_ = plt.imshow(result)

# %%
data_augmentation =tf.keras.Sequential(
    [
        #tf.keras.Input((400, 400, 3)),
        tf.keras.layers.experimental.preprocessing.Resizing(height=400,width=400),
        #tf.keras.layers.experimental.preprocessing.Rescaling(1./255),
        #tf.keras.layers.experimental.preprocessing.RandomFlip(mode='horizontal'),
        #tf.keras.layers.experimental.preprocessing.RandomRotation(factor=0.8),
        tf.keras.layers.experimental.preprocessing.RandomContrast(factor=0.8),
        #tf.keras.layers.experimental.preprocessing.RandomZoom(height_factor=0.8,width_factor=0.8)
    ]
)
#image  =img.imread( '/tmp/Data_T2/Serval/serval (103).jpg')
#image=image[:, :,: ]
plt.imshow(result)


#get_label_name = metadata.features['label'].int2str


#print(label[0])

# Add the image to a batch
image = tf.expand_dims(result,0)

plt.figure(figsize=(10, 10))
for i in range(1):
  augmented_image = data_augmentation(image)
  ax = plt.subplot(1, 2, i + 1)
  plt.imshow(augmented_image[0])
  plt.axis("off")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
model.layers
# Out:
# [<tensorflow.python.keras.layers.preprocessing.image_preprocessing.Resizing at 0x7f3e908fd950>,
#  <tensorflow.python.keras.layers.preprocessing.image_preprocessing.RandomFlip at 0x7f3e80714e10>,
#  <tensorflow.python.keras.layers.preprocessing.image_preprocessing.RandomRotation at 0x7f3e8073c0d0>,
#  <tensorflow.python.keras.layers.preprocessing.image_preprocessing.RandomContrast at 0x7f3e8073c5d0>,
#  <tensorflow.python.keras.layers.preprocessing.image_preprocessing.RandomZoom at 0x7f3e8073c650>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3e8073cf10>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7f3e80745750>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3e80745c90>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7f3e806e82d0>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3e806e8710>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7f3e806e8cd0>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3e806eb190>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7f3e806eb790>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3e806ebc10>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7f3e806ef250>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3e806ef6d0>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7f3e806efcd0>,
#  <tensorflow.python.keras.layers.core.Flatten at 0x7f3e80748190>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f3e80748450>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f3e80748810>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f3e80748bd0>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f3e80748fd0>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f3e806f8410>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f3e806f8810>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f3e806f8c10>]

# %%
# Guardar el Modelo
#model.save('path_to_my_modelv1.h5')
model = tf.keras.models.load_model('path_to_my_modelv1.h5')
# Recrea exactamente el mismo modelo solo desde el archivo
#new_model = keras.models.load_model('path_to_my_model.h5')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-127-241b5ea67d60> in <module>()
#       1 # Guardar el Modelo
#       2 #model.save('path_to_my_modelv1.h5')
# ----> 3 model = tf.keras.models.load_model('path_to_my_modelv1.h5')
#       4 # Recrea exactamente el mismo modelo solo desde el archivo
#       5 #new_model = keras.models.load_model('path_to_my_model.h5')
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     209       filepath = path_to_string(filepath)
#     210       if isinstance(filepath, six.string_types):
# --> 211         loader_impl.parse_saved_model(filepath)
#     212         return saved_model_load.load(filepath, compile, options)
#     213
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/saved_model/loader_impl.py in parse_saved_model(export_dir)
#     112                   (export_dir,
#     113                    constants.SAVED_MODEL_FILENAME_PBTXT,
# --> 114                    constants.SAVED_MODEL_FILENAME_PB))
#     115
#     116
#
# OSError: SavedModel file does not exist at: path_to_my_modelv1.h5/{saved_model.pbtxt|saved_model.pb}

# %% [markdown]
# El siguiente codigo, nos permitira ingresar imagenes de nuestro computador para mostraselas a nuestra red nueronal y las clasifique entre linces y leopardos

# %%
import numpy as np
from google.colab import files
import random
from keras.preprocessing import image

uploaded = files.upload()

for fn in uploaded.keys():
 
  # predicting images
  path = fn
  img = image.load_img(path, target_size=(400, 400))
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size=10)
  print(fn)
  print(classes)
# Out:
#      <input type="file" id="files-c592e79a-e03e-4a3a-939d-a6c29c6f517c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c592e79a-e03e-4a3a-939d-a6c29c6f517c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving guepardo (1).jpg to guepardo (1).jpg
# Saving guepardo (2).jpg to guepardo (2).jpg
# Saving guepardo (19).jpg to guepardo (19).jpg
# Saving leopardo (1).jpg to leopardo (1).jpg
# Saving leopardo (2).jpg to leopardo (2).jpg
# Saving leopardo.jpg to leopardo.jpg
# Saving lincei (1).jpg to lincei (1).jpg
# Saving lincei (2).jpg to lincei (2).jpg
# Saving lincei (3).jpg to lincei (3).jpg
# Saving linci.jpg to linci.jpg
# Saving Ocelote (4).jpg to Ocelote (4).jpg
# Saving Ocelote (19).jpg to Ocelote (19).jpg
# Saving Ocelote (121).jpg to Ocelote (121).jpg
# Saving Serval (1).jpg to Serval (1).jpg
# Saving Serval (2).jpg to Serval (2).jpg
# Saving Serval (3).jpg to Serval (3).jpg
# guepardo (1).jpg
# [[0. 0. 0. 0. 1.]]
# guepardo (2).jpg
# [[1. 0. 0. 0. 0.]]
# guepardo (19).jpg
# [[0. 1. 0. 0. 0.]]
# leopardo (1).jpg
# [[1. 0. 0. 0. 0.]]
# leopardo (2).jpg
# [[1. 0. 0. 0. 0.]]
# leopardo.jpg
# [[9.9999905e-01 9.4342431e-07 0.0000000e+00 0.0000000e+00 0.0000000e+00]]
# lincei (1).jpg
# [[0. 0. 0. 0. 1.]]
# lincei (2).jpg
# [[0. 1. 0. 0. 0.]]
# lincei (3).jpg
# [[1. 0. 0. 0. 0.]]
# linci.jpg
# [[0. 1. 0. 0. 0.]]
# Ocelote (4).jpg
# [[0. 0. 0. 0. 1.]]
# Ocelote (19).jpg
# [[0. 0. 0. 1. 0.]]
# Ocelote (121).jpg
# [[1. 0. 0. 0. 0.]]
# Serval (1).jpg
# [[1. 0. 0. 0. 0.]]
# Serval (2).jpg
# [[1. 0. 0. 0. 0.]]
# Serval (3).jpg
# [[1. 0. 0. 0. 0.]]

# %%
import numpy as np

from google.colab import files
from keras.preprocessing import image

uploaded=files.upload()

for fn in uploaded.keys():
 
  # predicting images
  path='/content/' + fn
  img=image.load_img(path, target_size=(100, 100))
  
  x=image.img_to_array(img)
  x=np.expand_dims(x, axis=0)
  images = np.vstack([x])
  
  classes = model.predict(images, batch_size=10)
  
  print(classes[0])
  
  if classes[0]>0:
    print(fn + " es un Lince")
    
  else:
    print(fn + " es un leopardo")
# Out:
#      <input type="file" id="files-56591e83-b621-4766-bafd-660116d1bfa0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-56591e83-b621-4766-bafd-660116d1bfa0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving lince i.jpg to lince i (5).jpg
# Saving Lince-Ibérico-».jpg to Lince-Ibérico-» (5).jpg
# Saving LEo.jpg to LEo (6).jpg
# Saving leopardo.jpg to leopardo (6).jpg
# WARNING:tensorflow:11 out of the last 15 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fd2ddecac80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [0.]
# lince i.jpg es un leopardo
# [0.]
# Lince-Ibérico-».jpg es un leopardo
# [0.]
# LEo.jpg es un leopardo
# [0.]
# leopardo.jpg es un leopardo

# %% [markdown]
# Podmeos observar el recorrido de una imagen en nuestra red neuronal

# %%
import numpy as np
import random
from   tensorflow.keras.preprocessing.image import img_to_array, load_img

# Definamos un nuevo modelo que tomará una imagen como entrada y generará
# representaciones intermedias para todas las capas en el modelo anterior después de la primera.
successive_outputs = [layer.output for layer in model.layers[1:]]

#visualization_model = Model(img_input, successive_outputs)
visualization_model = tf.keras.models.Model(inputs = model.input, outputs = successive_outputs)

# Preparemos una imagen de entrada aleatoria de un leopardo o un lince del conjunto de entrenamiento.
leo_img_files = [os.path.join(train_leo_dir, f) for f in train_leo_fnames]
lince_img_files = [os.path.join(train_lince_dir, f) for f in train_lince_fnames]
ocelote_img_files = [os.path.join(train_ocelote_dir, f) for f in train_ocelote_fnames]
guepardo_img_files = [os.path.join(train_guepardo_dir, f) for f in train_guepardo_fnames]
serval_img_files = [os.path.join(train_serval_dir, f) for f in train_serval_fnames]

img_path1 = random.choice(leo_img_files + lince_img_files+ocelote_img_files+guepardo_img_files+serval_img_files)
img_path2 = random.choice(leo_img_files + lince_img_files+ocelote_img_files+guepardo_img_files+serval_img_files)
img_path3 = random.choice(leo_img_files + lince_img_files+ocelote_img_files+guepardo_img_files+serval_img_files)

img1 = load_img(img_path1, target_size=(400, 150))  # esta es uan imagen de tipo PIL
img2 = load_img(img_path2, target_size=(150, 150))
img3 = load_img(img_path3, target_size=(150, 150))

x1   = img_to_array(img1)
x2   = img_to_array(img2)
x3   = img_to_array(img3)                           # Numpy array con la forma (150, 150, 3)

x1   = x1.reshape((1,) + x1.shape)                   # Numpy array con la forma (1, 150, 150, 3)
x2   = x2.reshape((1,) + x2.shape)                   # Numpy array con la forma (1, 150, 150, 3)
x3   = x3.reshape((1,) + x3.shape)                   # Numpy array con la forma (1, 150, 150, 3)

# Rescale by 1/255
#x /= 255.0

# Ejecutamos nuestra imagen a través de nuestra red, obteniendo así todas las representaciones intermedias para esta imagen.
successive_feature_maps = visualization_model.predict(x1+x2+x3,batch_size=10)

# Estos son los nombres de las capas, por lo que podemos tenerlos como parte de nuestra trama.
layer_names = [layer.name for layer in model.layers]

# -----------------------------------------------------------------------
# ahora vamos a mostrar nuestras representaciones 
# -----------------------------------------------------------------------
for layer_name, feature_map in zip(layer_names, successive_feature_maps):
  
  if len(feature_map.shape) == 4:
    
    #-------------------------------------------
    n_features = feature_map.shape[-1]  # numero caracteristicas en el mapa de caracteristicas
    size       = feature_map.shape[ 1]  # forma del mapa de caracteristicas (1, tamaño, tmaño, n_caracteristicas)
    
    # se colaca las imágenes en mosaico en esta matriz.
    display_grid = np.zeros((size, size * n_features))
    
    #-------------------------------------------------
    # Procesamiento de la funcion
    #-------------------------------------------------
    for i in range(n_features):
      x  = feature_map[0, :, :, i]
      x -= x.mean()
      x /= x.std ()
      x *=  64
      x += 128
      x  = np.clip(x, 0, 255).astype('uint8')
      display_grid[:, i * size : (i + 1) * size] = x # Coloca en mosaico cada filtro en una cuadrícula horizontal

    #-----------------
    # mostrar la figura
    #-----------------

    scale = 20. / n_features
    plt.figure( figsize=(scale * n_features, scale) )
    plt.axis( 'off' )
    plt.title ( layer_name )
    plt.grid  ( False )
    plt.imshow( display_grid, aspect='auto',cmap='viridis')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-131-eac396309866> in <module>()
#      37
#      38 # Ejecutamos nuestra imagen a través de nuestra red, obteniendo así todas las representaciones intermedias para esta imagen.
# ---> 39 successive_feature_maps = visualization_model.predict(x1+x2+x3,batch_size=10)
#      40
#      41 # Estos son los nombres de las capas, por lo que podemos tenerlos como parte de nuestra trama.
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1627           for step in data_handler.steps():
#    1628             callbacks.on_predict_batch_begin(step)
# -> 1629             tmp_batch_outputs = self.predict_function(iterator)
#    1630             if data_handler.should_sync:
#    1631               context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     869       # This is the first call of __call__, so we have to initialize.
#     870       initializers = []
# --> 871       self._initialize(args, kwds, add_initializers_to=initializers)
#     872     finally:
#     873       # At this point we know that the initialization is complete (or less
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     724     self._concrete_stateful_fn = (
#     725         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
# --> 726             *args, **kwds))
#     727
#     728     def invalid_creator_scope(*unused_args, **unused_kwds):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    2967       args, kwargs = None, None
#    2968     with self._lock:
# -> 2969       graph_function, _ = self._maybe_define_function(args, kwargs)
#    2970     return graph_function
#    2971
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3359
#    3360           self._function_cache.missed.add(call_context_key)
# -> 3361           graph_function = self._create_graph_function(args, kwargs)
#    3362           self._function_cache.primary[cache_key] = graph_function
#    3363
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3204             arg_names=arg_names,
#    3205             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3206             capture_by_value=self._capture_by_value),
#    3207         self._function_attributes,
#    3208         function_spec=self.function_spec,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     988         _, original_func = tf_decorator.unwrap(python_func)
#     989
# --> 990       func_outputs = python_func(*func_args, **func_kwargs)
#     991
#     992       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     632             xla_context.Exit()
#     633         else:
# --> 634           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     635         return out
#     636
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     975           except Exception as e:  # pylint:disable=broad-except
#     976             if hasattr(e, "ag_error_metadata"):
# --> 977               raise e.ag_error_metadata.to_exception(e)
#     978             else:
#     979               raise
#
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1478 predict_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1468 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/distribute/distribute_lib.py:1259 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/distribute/distribute_lib.py:2730 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/distribute/distribute_lib.py:3417 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1461 run_step  **
#         outputs = model.predict_step(data)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1434 predict_step
#         return self(x, training=False)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/base_layer.py:998 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/input_spec.py:274 assert_input_compatibility
#         ', found shape=' + display_shape(x.shape))
#
#     ValueError: Input 0 is incompatible with layer model: expected shape=(None, 400, 400, 3), found shape=(None, 150, 150, 3)

# %% [markdown]
# Se puede observa la perdida y la exactitud, tanto en los datos de entreanmiento y los de perdida.

# %%
acc      = history.history[     'accuracy' ]
val_acc  = history.history[ 'val_accuracy' ]
loss     = history.history[    'loss' ]
val_loss = history.history['val_loss' ]

epochs   = range(len(acc)) # Get number of epochs

#------------------------------------------------
# Pplotear precicios del entranamiento y al valuidacion por epoca
#------------------------------------------------
parameters = {'xtick.labelsize': 23,
          'ytick.labelsize': 23}
plt.rcParams.update(parameters)
plt.figure(figsize=(13,7))
plt.plot  ( epochs,     acc, label='entrenamiento')
plt.plot  ( epochs, val_acc, label='Validacion' )
plt.title ('Training and validation accuracy (sin tecnicas)',fontsize=20)
plt.xlabel("Epoca",fontsize=16)                       # Configuramos la etiqueta del eje X
plt.ylabel("Exactitud",fontsize=16) 
plt.grid()
plt.legend(loc=2,fontsize=13)
plt.show()
#------------------------------------------------
# plotear perdida en el entranamiento y la validacion por epoca 
#------------------------------------------------
fig2=plt.figure(figsize=(13,7))
plt.plot  ( epochs,     loss, label='Entrenamiento' )
plt.plot  ( epochs, val_loss,label=  'validacion')
plt.title ('Training and validation loss '  ,fontsize=30 )
plt.title ('Training and validation loss '  ,fontsize=30 )
plt.xlabel("Epoca", fontsize=16)                       # Configuramos la etiqueta del eje X
plt.ylabel("Perdida",fontsize=16) 
plt.grid()
plt.legend(loc=2,fontsize=13)

# %%
acc      = history.history[     'accuracy' ]
val_acc  = history.history[ 'val_accuracy' ]
loss     = history.history[    'loss' ]
val_loss = history.history['val_loss' ]

epochs   = range(len(acc)) # Get number of epochs

#------------------------------------------------
# Pplotear precicios del entranamiento y al valuidacion por epoca
#------------------------------------------------
parameters = {'xtick.labelsize': 23,
          'ytick.labelsize': 23}
plt.rcParams.update(parameters)
plt.figure(figsize=(13,7))
plt.plot  ( epochs,     acc, label='entrenamiento')
plt.plot  ( epochs, val_acc, label='Validacion' )
plt.title ('Training and validation accuracy (sin tecnicas)',fontsize=20)
plt.xlabel("Epoca",fontsize=16)                       # Configuramos la etiqueta del eje X
plt.ylabel("Exactitud",fontsize=16) 
plt.grid()
plt.legend(loc=2,fontsize=13)
plt.show()
#------------------------------------------------
# plotear perdida en el entranamiento y la validacion por epoca 
#------------------------------------------------
fig2=plt.figure(figsize=(13,7))
plt.plot  ( epochs,     loss, label='Entrenamiento' )
plt.plot  ( epochs, val_loss,label=  'validacion')
plt.title ('Training and validation loss '  ,fontsize=30 )
plt.title ('Training and validation loss '  ,fontsize=30 )
plt.xlabel("Epoca", fontsize=16)                       # Configuramos la etiqueta del eje X
plt.ylabel("Perdida",fontsize=16) 
plt.grid()
plt.legend(loc=2,fontsize=13)

# %%
acc      = history.history[     'accuracy' ]
val_acc  = history.history[ 'val_accuracy' ]
loss     = history.history[    'loss' ]
val_loss = history.history['val_loss' ]

epochs   = range(len(acc)) # Get number of epochs

#------------------------------------------------
# Pplotear precicios del entranamiento y al valuidacion por epoca
#------------------------------------------------
parameters = {'xtick.labelsize': 23,
          'ytick.labelsize': 23}
plt.rcParams.update(parameters)
plt.figure(figsize=(13,7))
plt.plot  ( epochs,     acc, label='entrenamiento')
plt.plot  ( epochs, val_acc, label='Validacion' )
plt.title ('Training and validation accuracy (sin tecnicas)',fontsize=20)
plt.xlabel("Epoca",fontsize=16)                       # Configuramos la etiqueta del eje X
plt.ylabel("Exactitud",fontsize=16) 
plt.grid()
plt.legend(loc=2,fontsize=13)
plt.show()
#------------------------------------------------
# plotear perdida en el entranamiento y la validacion por epoca 
#------------------------------------------------
fig2=plt.figure(figsize=(13,7))
plt.plot  ( epochs,     loss, label='Entrenamiento' )
plt.plot  ( epochs, val_loss,label=  'validacion')
plt.title ('Training and validation loss '  ,fontsize=30 )
plt.title ('Training and validation loss '  ,fontsize=30 )
plt.xlabel("Epoca", fontsize=16)                       # Configuramos la etiqueta del eje X
plt.ylabel("Perdida",fontsize=16) 
plt.grid()
plt.legend(loc=2,fontsize=13)

# %%
acc      = history.history[     'accuracy' ]
val_acc  = history.history[ 'val_accuracy' ]
loss     = history.history[    'loss' ]
val_loss = history.history['val_loss' ]

epochs   = range(len(acc)) # Get number of epochs

#------------------------------------------------
# Pplotear precicios del entranamiento y al valuidacion por epoca
#------------------------------------------------
parameters = {'xtick.labelsize': 23,
          'ytick.labelsize': 23}
plt.rcParams.update(parameters)
plt.figure(figsize=(13,7))
plt.plot  ( epochs,     acc, label='entrenamiento')
plt.plot  ( epochs, val_acc, label='Validacion' )
plt.title ('Training and validation accuracy (sin tecnicas)',fontsize=20)
plt.xlabel("Epoca",fontsize=16)                       # Configuramos la etiqueta del eje X
plt.ylabel("Exactitud",fontsize=16) 
plt.grid()
plt.legend(loc=2,fontsize=13)
plt.show()
#------------------------------------------------
# plotear perdida en el entranamiento y la validacion por epoca 
#------------------------------------------------
fig2=plt.figure(figsize=(13,7))
plt.plot  ( epochs,     loss, label='Entrenamiento' )
plt.plot  ( epochs, val_loss,label=  'validacion')
plt.title ('Training and validation loss '  ,fontsize=30 )
plt.title ('Training and validation loss '  ,fontsize=30 )
plt.xlabel("Epoca", fontsize=16)                       # Configuramos la etiqueta del eje X
plt.ylabel("Perdida",fontsize=16) 
plt.grid()
plt.legend(loc=2,fontsize=13)

# %%
from numpy import exp
 
# softmax activation function
def softmax(x):
	return exp(x) / exp(x).sum()
 
# define input data
inputs = [1.0, 3.0, 2.0]
print(exp(inputs))
print(exp(inputs).sum())
# calculate outputs
outputs = softmax(inputs)
# report the probabilities
print(outputs)
# report the sum of the probabilities
print(outputs.sum())
# Out:
# [ 2.71828183 20.08553692  7.3890561 ]
# 30.19287485057736
# [0.09003057 0.66524096 0.24472847]
# 1.0

# %% [markdown]
# Referencia:
#
# Auotores de Tensorflow: Course_2_Part_2_Lesson_2_Notebook
