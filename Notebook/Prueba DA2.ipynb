# %% [markdown]
# Se importar los datos en formato .zip, y se extraen en la maquina virtual

# %%
import os
import zipfile

local_zip = 'Data_T2.zip'

zip_ref = zipfile.ZipFile(local_zip, 'r')

zip_ref.extractall('/tmp')
zip_ref.close()

# %% [markdown]
# Aqui se define, los directorios de donde se sacara la data de la imagen.

# %%
base_dir = '/tmp/Data_T2'


train_leo_dir = os.path.join(base_dir, 'Leopardo2')
train_lince_dir = os.path.join(base_dir, 'Lince iberico')
train_ocelote_dir = os.path.join(base_dir, 'Ocelote')
train_guepardo_dir = os.path.join(base_dir, 'Guepardo')
train_serval_dir = os.path.join(base_dir, 'Serval')

# %% [markdown]
# # Sección nueva

# %% [markdown]
# Aqui no mas se muestran el nombre de los archivos,

# %%
train_leo_fnames = os.listdir( train_leo_dir )
train_lince_fnames = os.listdir( train_lince_dir )
train_ocelote_fnames = os.listdir(train_ocelote_dir)
train_guepardo_fnames = os.listdir(train_guepardo_dir)
train_serval_fnames = os.listdir(train_serval_dir)

print(train_leo_fnames[:10])
print(train_lince_fnames[:10])
print(train_ocelote_fnames[:10])
print(train_guepardo_fnames[:10])
print(train_serval_fnames[:10])
# Out:
# ['leopardo (149).jpg', 'leopardo (130).jpg', 'leopardo (31).jpg', 'leopardo (65).jpg', 'leopardo (140).jpg', 'leopardo (142).jpg', 'leopardo (8).jpg', 'leopardo (92).jpg', 'leopardo (35).jpg', 'leopardo (25).jpg']
# ['lince1 (140).jpg', 'lince1 (127).jpg', 'lince1 (44).jpg', 'lince1 (172).jpg', 'lince1 (51).jpg', 'lince1 (14).jpg', 'lince1 (82).jpg', 'lince1 (24).jpg', 'lince1 (147).jpg', 'lince1 (146).jpg']
# ['Ocelote (145).jpg', 'Ocelote (132).jpg', 'Ocelote (119).jpg', 'Ocelote (97).jpg', 'Ocelote (150).jpg', 'Ocelote (61).jpg', 'Ocelote (138).jpg', 'Ocelote (10).jpg', 'Ocelote (184).jpg', 'Ocelote (185).jpg']
# ['guepardo (9).jpg', 'guepardo (12).jpg', 'guepardo (43).jpg', 'guepardo (98).jpg', 'guepardo (79).jpg', 'guepardo (62).jpg', 'guepardo (11).jpg', 'guepardo (48).jpg', 'guepardo (40).jpg', 'guepardo (22).jpg']
# ['serval (135).jpg', 'Serval (157).jpg', 'Serval (180).jpg', 'serval (67).jpg', 'serval (13).jpg', 'Serval (171).jpg', 'serval (40).jpg', 'serval (106).jpg', 'serval (83).jpg', 'Serval (165).jpg']

# %% [markdown]
# Aqui vemos el total de imagenes en que hay en los directorios de leopardos y linces.

# %%
print('total training leo images :', len(os.listdir(train_leo_dir ) ))
print('total training lince images :', len(os.listdir( train_lince_dir ) ))
print('total training ocelote images :', len(os.listdir( train_ocelote_dir ) ))
print('total training guepardo images :', len(os.listdir( train_guepardo_dir ) ))
print('total training serval images :', len(os.listdir( train_serval_dir ) ))
# Out:
# total training leo images : 189
# total training lince images : 188
# total training ocelote images : 192
# total training guepardo images : 194
# total training serval images : 195

# %% [markdown]
# las siguientes lineas de codigo son para enseñar una pequeña muestra de loas imagenes en los directorios.

# %%
# %matplotlib inline

import matplotlib.image as mpimg
import matplotlib.pyplot as plt


nrows = 20
ncols = 4

pic_index = 0

# %%
fig = plt.gcf()
fig.set_size_inches(ncols*4, nrows*4)

pic_index+=8

next_leo_pix = [os.path.join(train_leo_dir, fname) 
                for fname in train_leo_fnames[ pic_index-8:pic_index] 
               ]

next_lince_pix = [os.path.join(train_lince_dir, fname) 
                for fname in train_lince_fnames[ pic_index-8:pic_index]
               ]
next_ocelote_pix = [os.path.join(train_ocelote_dir, fname) 
                for fname in train_ocelote_fnames[ pic_index-8:pic_index]
               ]
next_guepardo_pix = [os.path.join(train_guepardo_dir, fname) 
                for fname in train_guepardo_fnames[ pic_index-8:pic_index]
               ]
next_serval_pix = [os.path.join(train_serval_dir, fname) 
                for fname in train_serval_fnames[ pic_index-8:pic_index]
               ]


for i, img_path in enumerate(next_leo_pix+next_lince_pix+next_ocelote_pix+next_guepardo_pix+next_serval_pix ):

  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') 

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Construyendo el Modelo

# %%
import tensorflow as tf

# %% [markdown]
# La siguiente secuencia de codigo es el "core" de nuestra red nueronal, donde estan definidas, las capas de convulucion, la densidad de la red entre otros parametros.

# %%
data_augmentation =tf.keras.Sequential(
    [
        
        tf.keras.layers.experimental.preprocessing.Resizing(height=400,width=400),
        tf.keras.layers.experimental.preprocessing.RandomFlip(mode='horizontal'),
        tf.keras.layers.experimental.preprocessing.RandomRotation(factor=0.2),
        tf.keras.layers.experimental.preprocessing.RandomContrast(factor=0.4),
        tf.keras.layers.experimental.preprocessing.RandomZoom(height_factor=0.2,width_factor=0.2)
    ]
)
initializer=tf.keras.initializers.RandomNormal(mean=0.3, stddev=1.)
model = tf.keras.models.Sequential([
    tf.keras.Input((400, 400, 3)),
    data_augmentation,
    tf.keras.layers.Conv2D(16, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2), 
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'), 
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(128,(3,3),activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(256,(3,3),activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(512,(3,3),activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(16,kernel_initializer=initializer,activation='relu'),
    tf.keras.layers.Dense(32,activation='relu'),
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(256,activation='relu'),
    tf.keras.layers.Dropout(0.6),
    tf.keras.layers.Dense(1024, activation='relu'), 
    tf.keras.layers.Dense(5, activation='softmax')  
])

# %% [markdown]
# aqui podemos ver la constidad de parametros en cada, "capa de la red",  y tambien se evidenca el decrecimiento de la imagen en cada cada capa

# %%
model.summary()
# Out:
# Model: "sequential_63"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_62 (Sequential)   (None, 400, 400, 3)       0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 398, 398, 16)      448
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 199, 199, 16)      0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 197, 197, 32)      4640
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 98, 98, 32)        0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 96, 96, 64)        18496
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 48, 48, 64)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 46, 46, 128)       73856
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 23, 23, 128)       0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 21, 21, 256)       295168
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 10, 10, 256)       0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 8, 8, 512)         1180160
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_19 (Dense)             (None, 16)                131088
# _________________________________________________________________
# dense_20 (Dense)             (None, 32)                544
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_21 (Dense)             (None, 128)               4224
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 256)               33024
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_23 (Dense)             (None, 1024)              263168
# _________________________________________________________________
# dense_24 (Dense)             (None, 5)                 5125
# =================================================================
# Total params: 2,009,941
# Trainable params: 2,009,941
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Aqui se va definen las funciones de perdida y el optimizador, que ayudaran al modelo a aprender.

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import RMSprop

model.compile(optimizer=RMSprop(lr=0.0003,rho=0.92),
              loss='categorical_crossentropy',
              metrics = ['accuracy'])

# %% [markdown]
# Aqui se rescalan las imagenes, para que la red trabaje con valores entre 0 y 1, tambien crearemos un "split", que nos servira para la validacion de datos.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

#todas las imagenes sera resscaldad a 1/255
train_datagen = ImageDataGenerator( rescale = 1.0/255. ,validation_split=0.15)
# --------------------
# Imágenes de entrenamiento en lotes de 20 usando el generador train_datagen
# --------------------
train_generator = train_datagen.flow_from_directory(base_dir,
                                                    batch_size=80,
                                                    class_mode='categorical',
                                                    target_size=(400,400),
                                                    subset='training')     

# --------------------
# imagenes de validadcion en lotes de 5 usando el generador test_datagen generator
# --------------------

test_generator = train_datagen.flow_from_directory(base_dir,
                                                    batch_size=5,
                                                    class_mode='categorical',
                                                    target_size=(400, 400),
                                                    subset='validation')
# Out:
# Found 816 images belonging to 5 classes.
# Found 142 images belonging to 5 classes.

# %% [markdown]
# Por ultimo para entrenar la red, se le dieron 5 epocas, y se le especifico cuales era los datos de validacion y de entrenamiento.

# %%
#augmentation=data_augmetntation.compile(train_generator)


history = model.fit(train_generator,
                            validation_data=test_generator,
                            epochs=500,
                            verbose=1)
# Out:
# Epoch 1/500
# 11/11 [==============================] - 10s 755ms/step - loss: 2.7805 - accuracy: 0.1826 - val_loss: 1.6164 - val_accuracy: 0.1972
# Epoch 2/500
# 11/11 [==============================] - 8s 720ms/step - loss: 1.6120 - accuracy: 0.2132 - val_loss: 1.5846 - val_accuracy: 0.1972
# Epoch 3/500
# 11/11 [==============================] - 8s 722ms/step - loss: 1.5976 - accuracy: 0.2243 - val_loss: 1.6100 - val_accuracy: 0.1972
# Epoch 4/500
# 11/11 [==============================] - 8s 788ms/step - loss: 1.6080 - accuracy: 0.2448 - val_loss: 1.6243 - val_accuracy: 0.1972
# Epoch 5/500
# 11/11 [==============================] - 8s 727ms/step - loss: 1.6029 - accuracy: 0.2269 - val_loss: 1.5869 - val_accuracy: 0.2465
# Epoch 6/500
# 11/11 [==============================] - 8s 728ms/step - loss: 1.5989 - accuracy: 0.2567 - val_loss: 1.6053 - val_accuracy: 0.1972
# Epoch 7/500
# 11/11 [==============================] - 8s 723ms/step - loss: 1.6016 - accuracy: 0.2397 - val_loss: 1.5877 - val_accuracy: 0.2394
# Epoch 8/500
# 11/11 [==============================] - 8s 734ms/step - loss: 1.5659 - accuracy: 0.2304 - val_loss: 1.5541 - val_accuracy: 0.2606
# Epoch 9/500
# 11/11 [==============================] - 8s 739ms/step - loss: 1.5575 - accuracy: 0.2647 - val_loss: 1.5516 - val_accuracy: 0.2817
# Epoch 10/500
# 11/11 [==============================] - 8s 724ms/step - loss: 1.5435 - accuracy: 0.2874 - val_loss: 1.5466 - val_accuracy: 0.2676
# Epoch 11/500
# 11/11 [==============================] - 8s 726ms/step - loss: 1.5228 - accuracy: 0.2916 - val_loss: 1.5711 - val_accuracy: 0.2535
# Epoch 12/500
# 11/11 [==============================] - 8s 734ms/step - loss: 1.5704 - accuracy: 0.2604 - val_loss: 1.5824 - val_accuracy: 0.2535
# Epoch 13/500
# 11/11 [==============================] - 8s 726ms/step - loss: 1.5373 - accuracy: 0.2533 - val_loss: 1.5626 - val_accuracy: 0.3028
# Epoch 14/500
# 11/11 [==============================] - 8s 712ms/step - loss: 1.5375 - accuracy: 0.2971 - val_loss: 1.5456 - val_accuracy: 0.2746
# Epoch 15/500
# 11/11 [==============================] - 8s 785ms/step - loss: 1.5440 - accuracy: 0.3121 - val_loss: 1.5424 - val_accuracy: 0.2958
# Epoch 16/500
# 11/11 [==============================] - 8s 715ms/step - loss: 1.5353 - accuracy: 0.2716 - val_loss: 1.5443 - val_accuracy: 0.2606
# Epoch 17/500
# 11/11 [==============================] - 8s 708ms/step - loss: 1.5004 - accuracy: 0.2957 - val_loss: 1.5560 - val_accuracy: 0.2817
# Epoch 18/500
# 11/11 [==============================] - 8s 730ms/step - loss: 1.5302 - accuracy: 0.2837 - val_loss: 1.5203 - val_accuracy: 0.2887
# Epoch 19/500
# 11/11 [==============================] - 8s 731ms/step - loss: 1.5493 - accuracy: 0.3107 - val_loss: 1.5746 - val_accuracy: 0.2676
# Epoch 20/500
# 11/11 [==============================] - 8s 726ms/step - loss: 1.5623 - accuracy: 0.2502 - val_loss: 1.5192 - val_accuracy: 0.3310
# Epoch 21/500
# 11/11 [==============================] - 8s 736ms/step - loss: 1.5151 - accuracy: 0.3329 - val_loss: 1.5541 - val_accuracy: 0.2676
# Epoch 22/500
# 11/11 [==============================] - 8s 730ms/step - loss: 1.5429 - accuracy: 0.2644 - val_loss: 1.5251 - val_accuracy: 0.3239
# Epoch 23/500
# 11/11 [==============================] - 8s 737ms/step - loss: 1.4865 - accuracy: 0.3207 - val_loss: 1.5225 - val_accuracy: 0.3169
# Epoch 24/500
# 11/11 [==============================] - 8s 726ms/step - loss: 1.4953 - accuracy: 0.3199 - val_loss: 1.5374 - val_accuracy: 0.2887
# Epoch 25/500
# 11/11 [==============================] - 8s 751ms/step - loss: 1.4987 - accuracy: 0.3093 - val_loss: 1.5786 - val_accuracy: 0.2394
# Epoch 26/500
# 11/11 [==============================] - 8s 747ms/step - loss: 1.5268 - accuracy: 0.2569 - val_loss: 1.5208 - val_accuracy: 0.2817
# Epoch 27/500
# 11/11 [==============================] - 8s 727ms/step - loss: 1.4908 - accuracy: 0.3140 - val_loss: 1.5214 - val_accuracy: 0.3169
# Epoch 28/500
# 11/11 [==============================] - 8s 720ms/step - loss: 1.4827 - accuracy: 0.3385 - val_loss: 1.5218 - val_accuracy: 0.3028
# Epoch 29/500
# 11/11 [==============================] - 8s 724ms/step - loss: 1.5137 - accuracy: 0.3066 - val_loss: 1.5332 - val_accuracy: 0.3239
# Epoch 30/500
# 11/11 [==============================] - 8s 784ms/step - loss: 1.4757 - accuracy: 0.3384 - val_loss: 1.5296 - val_accuracy: 0.3169
# Epoch 31/500
# 11/11 [==============================] - 8s 756ms/step - loss: 1.4705 - accuracy: 0.3191 - val_loss: 1.4994 - val_accuracy: 0.3239
# Epoch 32/500
# 11/11 [==============================] - 8s 749ms/step - loss: 1.4436 - accuracy: 0.3435 - val_loss: 1.5427 - val_accuracy: 0.3028
# Epoch 33/500
# 11/11 [==============================] - 8s 739ms/step - loss: 1.4753 - accuracy: 0.3269 - val_loss: 1.5576 - val_accuracy: 0.2676
# Epoch 34/500
# 11/11 [==============================] - 8s 746ms/step - loss: 1.4830 - accuracy: 0.3079 - val_loss: 1.5220 - val_accuracy: 0.3521
# Epoch 35/500
# 11/11 [==============================] - 8s 731ms/step - loss: 1.4877 - accuracy: 0.3526 - val_loss: 1.4620 - val_accuracy: 0.3521
# Epoch 36/500
# 11/11 [==============================] - 8s 727ms/step - loss: 1.4921 - accuracy: 0.3296 - val_loss: 1.9353 - val_accuracy: 0.2042
# Epoch 37/500
# 11/11 [==============================] - 8s 718ms/step - loss: 1.8842 - accuracy: 0.2599 - val_loss: 1.5007 - val_accuracy: 0.3592
# Epoch 38/500
# 11/11 [==============================] - 8s 719ms/step - loss: 1.4783 - accuracy: 0.3459 - val_loss: 1.4662 - val_accuracy: 0.3592
# Epoch 39/500
# 11/11 [==============================] - 8s 723ms/step - loss: 1.4427 - accuracy: 0.3700 - val_loss: 1.8833 - val_accuracy: 0.2113
# Epoch 40/500
# 11/11 [==============================] - 8s 713ms/step - loss: 1.7074 - accuracy: 0.2841 - val_loss: 1.4692 - val_accuracy: 0.3451
# Epoch 41/500
# 11/11 [==============================] - 8s 721ms/step - loss: 1.4318 - accuracy: 0.3761 - val_loss: 1.4591 - val_accuracy: 0.3944
# Epoch 42/500
# 11/11 [==============================] - 8s 724ms/step - loss: 1.4563 - accuracy: 0.3353 - val_loss: 1.4505 - val_accuracy: 0.4225
# Epoch 43/500
# 11/11 [==============================] - 8s 724ms/step - loss: 1.4737 - accuracy: 0.3329 - val_loss: 1.4570 - val_accuracy: 0.3662
# Epoch 44/500
# 11/11 [==============================] - 8s 735ms/step - loss: 1.4048 - accuracy: 0.3807 - val_loss: 1.5016 - val_accuracy: 0.3028
# Epoch 45/500
# 11/11 [==============================] - 8s 723ms/step - loss: 1.4482 - accuracy: 0.3541 - val_loss: 1.4424 - val_accuracy: 0.3662
# Epoch 46/500
# 11/11 [==============================] - 8s 730ms/step - loss: 1.4041 - accuracy: 0.3852 - val_loss: 1.4370 - val_accuracy: 0.3662
# Epoch 47/500
# 11/11 [==============================] - 8s 721ms/step - loss: 1.4595 - accuracy: 0.3323 - val_loss: 1.4324 - val_accuracy: 0.4225
# Epoch 48/500
# 11/11 [==============================] - 8s 732ms/step - loss: 1.4428 - accuracy: 0.3393 - val_loss: 1.4304 - val_accuracy: 0.4577
# Epoch 49/500
# 11/11 [==============================] - 8s 759ms/step - loss: 1.4605 - accuracy: 0.3482 - val_loss: 1.4083 - val_accuracy: 0.4014
# Epoch 50/500
# 11/11 [==============================] - 8s 733ms/step - loss: 1.4241 - accuracy: 0.3664 - val_loss: 1.4406 - val_accuracy: 0.3662
# Epoch 51/500
# 11/11 [==============================] - 8s 727ms/step - loss: 1.4537 - accuracy: 0.3887 - val_loss: 1.4961 - val_accuracy: 0.3944
# Epoch 52/500
# 11/11 [==============================] - 8s 718ms/step - loss: 1.3988 - accuracy: 0.3856 - val_loss: 1.5788 - val_accuracy: 0.2676
# Epoch 53/500
# 11/11 [==============================] - 8s 787ms/step - loss: 1.5006 - accuracy: 0.3536 - val_loss: 1.4057 - val_accuracy: 0.3944
# Epoch 54/500
# 11/11 [==============================] - 8s 728ms/step - loss: 1.4516 - accuracy: 0.3897 - val_loss: 1.4381 - val_accuracy: 0.3944
# Epoch 55/500
# 11/11 [==============================] - 8s 740ms/step - loss: 1.3708 - accuracy: 0.4258 - val_loss: 1.4852 - val_accuracy: 0.3169
# Epoch 56/500
# 11/11 [==============================] - 8s 798ms/step - loss: 1.3730 - accuracy: 0.4325 - val_loss: 1.4733 - val_accuracy: 0.3592
# Epoch 57/500
# 11/11 [==============================] - 8s 725ms/step - loss: 1.4518 - accuracy: 0.3559 - val_loss: 1.3984 - val_accuracy: 0.5000
# Epoch 58/500
# 11/11 [==============================] - 8s 726ms/step - loss: 1.3850 - accuracy: 0.3985 - val_loss: 1.5363 - val_accuracy: 0.2887
# Epoch 59/500
# 11/11 [==============================] - 8s 718ms/step - loss: 1.3891 - accuracy: 0.3987 - val_loss: 1.4438 - val_accuracy: 0.3873
# Epoch 60/500
# 11/11 [==============================] - 8s 723ms/step - loss: 1.3851 - accuracy: 0.3859 - val_loss: 1.4162 - val_accuracy: 0.3873
# Epoch 61/500
# 11/11 [==============================] - 8s 729ms/step - loss: 1.3194 - accuracy: 0.4677 - val_loss: 1.4049 - val_accuracy: 0.4366
# Epoch 62/500
# 11/11 [==============================] - 8s 779ms/step - loss: 1.3183 - accuracy: 0.4409 - val_loss: 1.5374 - val_accuracy: 0.3099
# Epoch 63/500
# 11/11 [==============================] - 8s 732ms/step - loss: 1.3494 - accuracy: 0.4150 - val_loss: 1.5205 - val_accuracy: 0.3521
# Epoch 64/500
# 11/11 [==============================] - 8s 735ms/step - loss: 1.4131 - accuracy: 0.4161 - val_loss: 1.3826 - val_accuracy: 0.4366
# Epoch 65/500
# 11/11 [==============================] - 8s 716ms/step - loss: 1.2384 - accuracy: 0.4777 - val_loss: 1.4604 - val_accuracy: 0.3592
# Epoch 66/500
# 11/11 [==============================] - 8s 723ms/step - loss: 1.3651 - accuracy: 0.4153 - val_loss: 1.3462 - val_accuracy: 0.5211
# Epoch 67/500
# 11/11 [==============================] - 8s 723ms/step - loss: 1.3029 - accuracy: 0.4753 - val_loss: 1.3636 - val_accuracy: 0.4648
# Epoch 68/500
# 11/11 [==============================] - 8s 739ms/step - loss: 1.3043 - accuracy: 0.4959 - val_loss: 1.4391 - val_accuracy: 0.3873
# Epoch 69/500
# 11/11 [==============================] - 8s 737ms/step - loss: 1.2720 - accuracy: 0.4895 - val_loss: 1.3974 - val_accuracy: 0.4437
# Epoch 70/500
# 11/11 [==============================] - 8s 730ms/step - loss: 1.2986 - accuracy: 0.4519 - val_loss: 1.4027 - val_accuracy: 0.4225
# Epoch 71/500
# 11/11 [==============================] - 8s 720ms/step - loss: 1.2173 - accuracy: 0.5059 - val_loss: 1.6923 - val_accuracy: 0.3239
# Epoch 72/500
# 11/11 [==============================] - 8s 723ms/step - loss: 1.3728 - accuracy: 0.3949 - val_loss: 1.5099 - val_accuracy: 0.3662
# Epoch 73/500
# 11/11 [==============================] - 8s 724ms/step - loss: 1.1880 - accuracy: 0.4984 - val_loss: 2.5189 - val_accuracy: 0.2254
# Epoch 74/500
# 11/11 [==============================] - 8s 729ms/step - loss: 1.2540 - accuracy: 0.4602 - val_loss: 2.0994 - val_accuracy: 0.2887
# Epoch 75/500
# 11/11 [==============================] - 8s 742ms/step - loss: 1.3603 - accuracy: 0.4684 - val_loss: 1.4797 - val_accuracy: 0.3662
# Epoch 76/500
# 11/11 [==============================] - 8s 724ms/step - loss: 1.2493 - accuracy: 0.4801 - val_loss: 1.4417 - val_accuracy: 0.3944
# Epoch 77/500
# 11/11 [==============================] - 8s 737ms/step - loss: 1.2688 - accuracy: 0.4948 - val_loss: 1.4520 - val_accuracy: 0.3944
# Epoch 78/500
# 11/11 [==============================] - 8s 739ms/step - loss: 1.2035 - accuracy: 0.5431 - val_loss: 1.3622 - val_accuracy: 0.4507
# Epoch 79/500
# 11/11 [==============================] - 8s 720ms/step - loss: 1.2054 - accuracy: 0.5126 - val_loss: 1.3081 - val_accuracy: 0.5282
# Epoch 80/500
# 11/11 [==============================] - 8s 729ms/step - loss: 1.2127 - accuracy: 0.4961 - val_loss: 1.7249 - val_accuracy: 0.3451
# Epoch 81/500
# 11/11 [==============================] - 8s 720ms/step - loss: 1.2331 - accuracy: 0.5204 - val_loss: 1.3067 - val_accuracy: 0.5000
# Epoch 82/500
# 11/11 [==============================] - 8s 725ms/step - loss: 1.2233 - accuracy: 0.5001 - val_loss: 2.2691 - val_accuracy: 0.3380
# Epoch 83/500
# 11/11 [==============================] - 8s 729ms/step - loss: 1.1926 - accuracy: 0.4989 - val_loss: 1.3272 - val_accuracy: 0.4859
# Epoch 84/500
# 11/11 [==============================] - 8s 745ms/step - loss: 1.1813 - accuracy: 0.5497 - val_loss: 1.3706 - val_accuracy: 0.4437
# Epoch 85/500
# 11/11 [==============================] - 8s 733ms/step - loss: 1.2286 - accuracy: 0.4879 - val_loss: 1.4226 - val_accuracy: 0.4225
# Epoch 86/500
# 11/11 [==============================] - 8s 725ms/step - loss: 1.2239 - accuracy: 0.4844 - val_loss: 1.3143 - val_accuracy: 0.5000
# Epoch 87/500
# 11/11 [==============================] - 8s 731ms/step - loss: 1.1415 - accuracy: 0.5393 - val_loss: 1.2706 - val_accuracy: 0.5563
# Epoch 88/500
# 11/11 [==============================] - 8s 727ms/step - loss: 1.1144 - accuracy: 0.5607 - val_loss: 1.3860 - val_accuracy: 0.4085
# Epoch 89/500
# 11/11 [==============================] - 8s 727ms/step - loss: 1.1671 - accuracy: 0.5117 - val_loss: 1.2441 - val_accuracy: 0.5493
# Epoch 90/500
# 11/11 [==============================] - 8s 727ms/step - loss: 1.1928 - accuracy: 0.5076 - val_loss: 1.3307 - val_accuracy: 0.4648
# Epoch 91/500
# 11/11 [==============================] - 8s 720ms/step - loss: 1.1929 - accuracy: 0.5114 - val_loss: 1.5609 - val_accuracy: 0.3239
# Epoch 92/500
# 11/11 [==============================] - 8s 721ms/step - loss: 1.1077 - accuracy: 0.5722 - val_loss: 1.4022 - val_accuracy: 0.4225
# Epoch 93/500
# 11/11 [==============================] - 8s 727ms/step - loss: 1.2534 - accuracy: 0.4960 - val_loss: 1.4735 - val_accuracy: 0.4085
# Epoch 94/500
# 11/11 [==============================] - 8s 789ms/step - loss: 1.1665 - accuracy: 0.5260 - val_loss: 1.7688 - val_accuracy: 0.3380
# Epoch 95/500
# 11/11 [==============================] - 8s 738ms/step - loss: 1.1092 - accuracy: 0.5487 - val_loss: 1.2623 - val_accuracy: 0.4789
# Epoch 96/500
# 11/11 [==============================] - 8s 748ms/step - loss: 1.0396 - accuracy: 0.5814 - val_loss: 1.2804 - val_accuracy: 0.5141
# Epoch 97/500
# 11/11 [==============================] - 8s 733ms/step - loss: 1.0867 - accuracy: 0.5704 - val_loss: 1.4638 - val_accuracy: 0.4225
# Epoch 98/500
# 11/11 [==============================] - 8s 731ms/step - loss: 1.1016 - accuracy: 0.5765 - val_loss: 1.3077 - val_accuracy: 0.5141
# Epoch 99/500
# 11/11 [==============================] - 8s 733ms/step - loss: 1.1162 - accuracy: 0.5763 - val_loss: 1.2611 - val_accuracy: 0.5704
# Epoch 100/500
# 11/11 [==============================] - 8s 737ms/step - loss: 1.2062 - accuracy: 0.5251 - val_loss: 1.2643 - val_accuracy: 0.5211
# Epoch 101/500
# 11/11 [==============================] - 8s 751ms/step - loss: 1.0580 - accuracy: 0.6012 - val_loss: 1.3735 - val_accuracy: 0.5070
# Epoch 102/500
# 11/11 [==============================] - 8s 736ms/step - loss: 1.1486 - accuracy: 0.5492 - val_loss: 1.3511 - val_accuracy: 0.5141
# Epoch 103/500
# 11/11 [==============================] - 8s 722ms/step - loss: 1.0753 - accuracy: 0.5735 - val_loss: 1.5328 - val_accuracy: 0.3732
# Epoch 104/500
# 11/11 [==============================] - 8s 728ms/step - loss: 1.1154 - accuracy: 0.5578 - val_loss: 1.3263 - val_accuracy: 0.5141
# Epoch 105/500
# 11/11 [==============================] - 8s 729ms/step - loss: 1.0657 - accuracy: 0.5915 - val_loss: 1.2625 - val_accuracy: 0.5282
# Epoch 106/500
# 11/11 [==============================] - 8s 744ms/step - loss: 1.0987 - accuracy: 0.5284 - val_loss: 1.2523 - val_accuracy: 0.5634
# Epoch 107/500
# 11/11 [==============================] - 8s 739ms/step - loss: 1.0428 - accuracy: 0.5998 - val_loss: 1.1868 - val_accuracy: 0.5423
# Epoch 108/500
# 11/11 [==============================] - 8s 732ms/step - loss: 1.1046 - accuracy: 0.5702 - val_loss: 1.3513 - val_accuracy: 0.5000
# Epoch 109/500
# 11/11 [==============================] - 8s 721ms/step - loss: 1.2103 - accuracy: 0.4976 - val_loss: 1.2001 - val_accuracy: 0.5634
# Epoch 110/500
# 11/11 [==============================] - 8s 721ms/step - loss: 0.9580 - accuracy: 0.6244 - val_loss: 1.2397 - val_accuracy: 0.5845
# Epoch 111/500
# 11/11 [==============================] - 8s 730ms/step - loss: 1.1746 - accuracy: 0.5647 - val_loss: 1.4668 - val_accuracy: 0.4437
# Epoch 112/500
# 11/11 [==============================] - 8s 725ms/step - loss: 0.9994 - accuracy: 0.6220 - val_loss: 1.2162 - val_accuracy: 0.5563
# Epoch 113/500
# 11/11 [==============================] - 8s 719ms/step - loss: 1.2118 - accuracy: 0.5408 - val_loss: 1.1383 - val_accuracy: 0.6268
# Epoch 114/500
# 11/11 [==============================] - 8s 729ms/step - loss: 0.8993 - accuracy: 0.6484 - val_loss: 1.6460 - val_accuracy: 0.3521
# Epoch 115/500
# 11/11 [==============================] - 8s 803ms/step - loss: 1.1661 - accuracy: 0.5573 - val_loss: 1.5004 - val_accuracy: 0.4155
# Epoch 116/500
# 11/11 [==============================] - 8s 733ms/step - loss: 0.9825 - accuracy: 0.6406 - val_loss: 1.1122 - val_accuracy: 0.6408
# Epoch 117/500
# 11/11 [==============================] - 8s 721ms/step - loss: 1.0406 - accuracy: 0.5796 - val_loss: 1.2955 - val_accuracy: 0.5634
# Epoch 118/500
# 11/11 [==============================] - 8s 724ms/step - loss: 1.0377 - accuracy: 0.6218 - val_loss: 1.1880 - val_accuracy: 0.6408
# Epoch 119/500
# 11/11 [==============================] - 8s 724ms/step - loss: 0.9009 - accuracy: 0.6668 - val_loss: 1.1827 - val_accuracy: 0.5634
# Epoch 120/500
# 11/11 [==============================] - 8s 737ms/step - loss: 0.9480 - accuracy: 0.6229 - val_loss: 1.2206 - val_accuracy: 0.5845
# Epoch 121/500
# 11/11 [==============================] - 8s 733ms/step - loss: 1.0926 - accuracy: 0.5846 - val_loss: 1.2183 - val_accuracy: 0.5493
# Epoch 122/500
# 11/11 [==============================] - 8s 726ms/step - loss: 0.9393 - accuracy: 0.6163 - val_loss: 1.1413 - val_accuracy: 0.5915
# Epoch 123/500
# 11/11 [==============================] - 8s 706ms/step - loss: 0.8747 - accuracy: 0.6689 - val_loss: 1.3811 - val_accuracy: 0.4507
# Epoch 124/500
# 11/11 [==============================] - 8s 731ms/step - loss: 1.1211 - accuracy: 0.5593 - val_loss: 1.1875 - val_accuracy: 0.5563
# Epoch 125/500
# 11/11 [==============================] - 8s 738ms/step - loss: 0.9600 - accuracy: 0.6056 - val_loss: 1.1382 - val_accuracy: 0.5704
# Epoch 126/500
# 11/11 [==============================] - 8s 790ms/step - loss: 0.9490 - accuracy: 0.6354 - val_loss: 1.3452 - val_accuracy: 0.5070
# Epoch 127/500
# 11/11 [==============================] - 8s 714ms/step - loss: 0.9389 - accuracy: 0.6235 - val_loss: 1.6574 - val_accuracy: 0.4930
# Epoch 128/500
# 11/11 [==============================] - 8s 725ms/step - loss: 1.0580 - accuracy: 0.5936 - val_loss: 1.2094 - val_accuracy: 0.5915
# Epoch 129/500
# 11/11 [==============================] - 8s 730ms/step - loss: 1.2188 - accuracy: 0.5649 - val_loss: 1.1518 - val_accuracy: 0.5634
# Epoch 130/500
# 11/11 [==============================] - 8s 720ms/step - loss: 0.8368 - accuracy: 0.6885 - val_loss: 1.1917 - val_accuracy: 0.5915
# Epoch 131/500
# 11/11 [==============================] - 8s 729ms/step - loss: 0.8895 - accuracy: 0.6810 - val_loss: 1.1754 - val_accuracy: 0.6127
# Epoch 132/500
# 11/11 [==============================] - 8s 784ms/step - loss: 0.8778 - accuracy: 0.6926 - val_loss: 1.0879 - val_accuracy: 0.6620
# Epoch 133/500
# 11/11 [==============================] - 8s 726ms/step - loss: 1.0404 - accuracy: 0.6020 - val_loss: 1.1193 - val_accuracy: 0.6197
# Epoch 134/500
# 11/11 [==============================] - 8s 719ms/step - loss: 0.8305 - accuracy: 0.6564 - val_loss: 1.1413 - val_accuracy: 0.5986
# Epoch 135/500
# 11/11 [==============================] - 8s 784ms/step - loss: 0.8966 - accuracy: 0.6684 - val_loss: 1.0436 - val_accuracy: 0.6197
# Epoch 136/500
# 11/11 [==============================] - 8s 725ms/step - loss: 0.8256 - accuracy: 0.7017 - val_loss: 1.0604 - val_accuracy: 0.6268
# Epoch 137/500
# 11/11 [==============================] - 8s 725ms/step - loss: 0.9625 - accuracy: 0.6374 - val_loss: 1.0943 - val_accuracy: 0.5634
# Epoch 138/500
# 11/11 [==============================] - 8s 727ms/step - loss: 0.7831 - accuracy: 0.7025 - val_loss: 1.2342 - val_accuracy: 0.5845
# Epoch 139/500
# 11/11 [==============================] - 8s 722ms/step - loss: 0.9338 - accuracy: 0.6374 - val_loss: 1.0652 - val_accuracy: 0.6690
# Epoch 140/500
# 11/11 [==============================] - 8s 728ms/step - loss: 0.8125 - accuracy: 0.6744 - val_loss: 1.3427 - val_accuracy: 0.5141
# Epoch 141/500
# 11/11 [==============================] - 8s 720ms/step - loss: 0.8586 - accuracy: 0.6617 - val_loss: 1.5220 - val_accuracy: 0.4577
# Epoch 142/500
# 11/11 [==============================] - 8s 788ms/step - loss: 0.9122 - accuracy: 0.6745 - val_loss: 1.1062 - val_accuracy: 0.6127
# Epoch 143/500
# 11/11 [==============================] - 8s 712ms/step - loss: 0.7510 - accuracy: 0.6931 - val_loss: 1.3303 - val_accuracy: 0.5493
# Epoch 144/500
# 11/11 [==============================] - 8s 728ms/step - loss: 0.7892 - accuracy: 0.6907 - val_loss: 1.0756 - val_accuracy: 0.6408
# Epoch 145/500
# 11/11 [==============================] - 8s 728ms/step - loss: 1.0623 - accuracy: 0.6036 - val_loss: 1.0799 - val_accuracy: 0.6408
# Epoch 146/500
# 11/11 [==============================] - 8s 710ms/step - loss: 0.8684 - accuracy: 0.6784 - val_loss: 2.7442 - val_accuracy: 0.3732
# Epoch 147/500
# 11/11 [==============================] - 8s 788ms/step - loss: 1.1356 - accuracy: 0.6106 - val_loss: 1.2003 - val_accuracy: 0.6127
# Epoch 148/500
# 11/11 [==============================] - 8s 728ms/step - loss: 0.7379 - accuracy: 0.7346 - val_loss: 1.2518 - val_accuracy: 0.5352
# Epoch 149/500
# 11/11 [==============================] - 8s 712ms/step - loss: 0.6465 - accuracy: 0.7745 - val_loss: 1.3273 - val_accuracy: 0.6408
# Epoch 150/500
# 11/11 [==============================] - 8s 735ms/step - loss: 0.7788 - accuracy: 0.6779 - val_loss: 1.2117 - val_accuracy: 0.5634
# Epoch 151/500
# 11/11 [==============================] - 8s 732ms/step - loss: 0.8207 - accuracy: 0.6778 - val_loss: 1.2642 - val_accuracy: 0.5704
# Epoch 152/500
# 11/11 [==============================] - 8s 736ms/step - loss: 0.7696 - accuracy: 0.7235 - val_loss: 1.4539 - val_accuracy: 0.4789
# Epoch 153/500
# 11/11 [==============================] - 8s 742ms/step - loss: 0.7682 - accuracy: 0.7215 - val_loss: 1.7701 - val_accuracy: 0.4859
# Epoch 154/500
# 11/11 [==============================] - 8s 717ms/step - loss: 0.8764 - accuracy: 0.6772 - val_loss: 1.2073 - val_accuracy: 0.6197
# Epoch 155/500
# 11/11 [==============================] - 8s 728ms/step - loss: 0.6706 - accuracy: 0.7465 - val_loss: 1.0620 - val_accuracy: 0.6056
# Epoch 156/500
# 11/11 [==============================] - 8s 731ms/step - loss: 0.5869 - accuracy: 0.7852 - val_loss: 1.4999 - val_accuracy: 0.5141
# Epoch 157/500
# 11/11 [==============================] - 8s 787ms/step - loss: 0.8652 - accuracy: 0.6434 - val_loss: 1.1086 - val_accuracy: 0.6479
# Epoch 158/500
# 11/11 [==============================] - 8s 727ms/step - loss: 0.7046 - accuracy: 0.7405 - val_loss: 2.1169 - val_accuracy: 0.4648
# Epoch 159/500
# 11/11 [==============================] - 8s 727ms/step - loss: 0.8819 - accuracy: 0.6811 - val_loss: 1.2546 - val_accuracy: 0.5563
# Epoch 160/500
# 11/11 [==============================] - 8s 734ms/step - loss: 0.8067 - accuracy: 0.7269 - val_loss: 1.0911 - val_accuracy: 0.6197
# Epoch 161/500
# 11/11 [==============================] - 8s 723ms/step - loss: 0.6222 - accuracy: 0.7669 - val_loss: 1.2671 - val_accuracy: 0.5915
# Epoch 162/500
# 11/11 [==============================] - 8s 722ms/step - loss: 0.7023 - accuracy: 0.7428 - val_loss: 1.2991 - val_accuracy: 0.5563
# Epoch 163/500
# 11/11 [==============================] - 8s 715ms/step - loss: 0.7203 - accuracy: 0.7034 - val_loss: 1.2463 - val_accuracy: 0.5282
# Epoch 164/500
# 11/11 [==============================] - 8s 732ms/step - loss: 0.9076 - accuracy: 0.6685 - val_loss: 1.1872 - val_accuracy: 0.5634
# Epoch 165/500
# 11/11 [==============================] - 8s 726ms/step - loss: 0.6083 - accuracy: 0.7933 - val_loss: 1.0775 - val_accuracy: 0.6479
# Epoch 166/500
# 11/11 [==============================] - 8s 730ms/step - loss: 0.6854 - accuracy: 0.7479 - val_loss: 1.0741 - val_accuracy: 0.6268
# Epoch 167/500
# 11/11 [==============================] - 8s 721ms/step - loss: 0.6735 - accuracy: 0.7617 - val_loss: 1.1386 - val_accuracy: 0.5704
# Epoch 168/500
# 11/11 [==============================] - 8s 725ms/step - loss: 0.7655 - accuracy: 0.7179 - val_loss: 1.2075 - val_accuracy: 0.5775
# Epoch 169/500
# 11/11 [==============================] - 8s 726ms/step - loss: 0.5993 - accuracy: 0.7820 - val_loss: 1.3748 - val_accuracy: 0.5493
# Epoch 170/500
# 11/11 [==============================] - 8s 714ms/step - loss: 0.7466 - accuracy: 0.7513 - val_loss: 1.1185 - val_accuracy: 0.5915
# Epoch 171/500
# 11/11 [==============================] - 8s 727ms/step - loss: 0.5303 - accuracy: 0.8130 - val_loss: 1.6616 - val_accuracy: 0.4577
# Epoch 172/500
# 11/11 [==============================] - 8s 728ms/step - loss: 1.0493 - accuracy: 0.6621 - val_loss: 1.0646 - val_accuracy: 0.6268
# Epoch 173/500
# 11/11 [==============================] - 8s 721ms/step - loss: 0.6786 - accuracy: 0.7607 - val_loss: 1.2490 - val_accuracy: 0.5986
# Epoch 174/500
# 11/11 [==============================] - 8s 727ms/step - loss: 0.6915 - accuracy: 0.7389 - val_loss: 1.0172 - val_accuracy: 0.6408
# Epoch 175/500
# 11/11 [==============================] - 8s 720ms/step - loss: 0.6595 - accuracy: 0.7659 - val_loss: 0.9778 - val_accuracy: 0.6338
# Epoch 176/500
# 11/11 [==============================] - 8s 725ms/step - loss: 0.5640 - accuracy: 0.7846 - val_loss: 1.4359 - val_accuracy: 0.5845
# Epoch 177/500
# 11/11 [==============================] - 8s 734ms/step - loss: 0.7704 - accuracy: 0.7240 - val_loss: 1.2194 - val_accuracy: 0.5563
# Epoch 178/500
# 11/11 [==============================] - 8s 793ms/step - loss: 0.7375 - accuracy: 0.7059 - val_loss: 1.1618 - val_accuracy: 0.5915
# Epoch 179/500
# 11/11 [==============================] - 8s 724ms/step - loss: 0.5599 - accuracy: 0.7957 - val_loss: 1.2409 - val_accuracy: 0.5986
# Epoch 180/500
# 11/11 [==============================] - 8s 703ms/step - loss: 0.6046 - accuracy: 0.7847 - val_loss: 1.4743 - val_accuracy: 0.5070
# Epoch 181/500
# 11/11 [==============================] - 8s 720ms/step - loss: 0.7442 - accuracy: 0.7171 - val_loss: 1.0913 - val_accuracy: 0.6408
# Epoch 182/500
# 11/11 [==============================] - 8s 714ms/step - loss: 0.5294 - accuracy: 0.8083 - val_loss: 1.2660 - val_accuracy: 0.6479
# Epoch 183/500
# 11/11 [==============================] - 8s 715ms/step - loss: 0.6608 - accuracy: 0.7604 - val_loss: 1.5772 - val_accuracy: 0.5563
# Epoch 184/500
# 11/11 [==============================] - 8s 790ms/step - loss: 0.6207 - accuracy: 0.7794 - val_loss: 1.5399 - val_accuracy: 0.5141
# Epoch 185/500
# 11/11 [==============================] - 8s 728ms/step - loss: 0.5940 - accuracy: 0.7984 - val_loss: 1.3366 - val_accuracy: 0.5775
# Epoch 186/500
# 11/11 [==============================] - 8s 715ms/step - loss: 0.7263 - accuracy: 0.7532 - val_loss: 1.1576 - val_accuracy: 0.6056
# Epoch 187/500
# 11/11 [==============================] - 8s 721ms/step - loss: 0.5464 - accuracy: 0.8116 - val_loss: 1.7141 - val_accuracy: 0.5845
# Epoch 188/500
# 11/11 [==============================] - 8s 732ms/step - loss: 0.7193 - accuracy: 0.7463 - val_loss: 1.0475 - val_accuracy: 0.6549
# Epoch 189/500
# 11/11 [==============================] - 8s 718ms/step - loss: 0.5814 - accuracy: 0.7921 - val_loss: 1.0831 - val_accuracy: 0.6408
# Epoch 190/500
# 11/11 [==============================] - 8s 726ms/step - loss: 0.6892 - accuracy: 0.7597 - val_loss: 1.8771 - val_accuracy: 0.4718
# Epoch 191/500
# 11/11 [==============================] - 8s 794ms/step - loss: 0.6133 - accuracy: 0.7781 - val_loss: 1.8997 - val_accuracy: 0.5634
# Epoch 192/500
# 11/11 [==============================] - 8s 718ms/step - loss: 0.6366 - accuracy: 0.7686 - val_loss: 1.3278 - val_accuracy: 0.6690
# Epoch 193/500
# 11/11 [==============================] - 8s 729ms/step - loss: 0.5814 - accuracy: 0.8102 - val_loss: 1.4059 - val_accuracy: 0.6197
# Epoch 194/500
# 11/11 [==============================] - 8s 730ms/step - loss: 0.6358 - accuracy: 0.7689 - val_loss: 1.1940 - val_accuracy: 0.6338
# Epoch 195/500
# 11/11 [==============================] - 8s 722ms/step - loss: 0.5011 - accuracy: 0.8134 - val_loss: 1.3629 - val_accuracy: 0.6127
# Epoch 196/500
# 11/11 [==============================] - 8s 725ms/step - loss: 0.6603 - accuracy: 0.7560 - val_loss: 1.2720 - val_accuracy: 0.6338
# Epoch 197/500
# 11/11 [==============================] - 8s 734ms/step - loss: 0.5099 - accuracy: 0.8200 - val_loss: 1.2773 - val_accuracy: 0.6197
# Epoch 198/500
# 11/11 [==============================] - 8s 721ms/step - loss: 0.5560 - accuracy: 0.8012 - val_loss: 1.5451 - val_accuracy: 0.5070
# Epoch 199/500
# 11/11 [==============================] - 8s 719ms/step - loss: 0.5439 - accuracy: 0.8030 - val_loss: 1.9525 - val_accuracy: 0.4437
# Epoch 200/500
# 11/11 [==============================] - 8s 708ms/step - loss: 0.7639 - accuracy: 0.7250 - val_loss: 1.3874 - val_accuracy: 0.6197
# Epoch 201/500
# 11/11 [==============================] - 8s 780ms/step - loss: 0.4712 - accuracy: 0.8287 - val_loss: 1.5891 - val_accuracy: 0.5423
# Epoch 202/500
# 11/11 [==============================] - 8s 721ms/step - loss: 0.4443 - accuracy: 0.8587 - val_loss: 1.3379 - val_accuracy: 0.5563
# Epoch 203/500
# 11/11 [==============================] - 8s 722ms/step - loss: 0.5974 - accuracy: 0.7711 - val_loss: 1.3504 - val_accuracy: 0.6338
# Epoch 204/500
# 11/11 [==============================] - 8s 730ms/step - loss: 0.6751 - accuracy: 0.7524 - val_loss: 1.2310 - val_accuracy: 0.6479
# Epoch 205/500
# 11/11 [==============================] - 8s 724ms/step - loss: 0.4543 - accuracy: 0.8494 - val_loss: 1.3053 - val_accuracy: 0.5915
# Epoch 206/500
# 11/11 [==============================] - 8s 791ms/step - loss: 0.5196 - accuracy: 0.8263 - val_loss: 1.1285 - val_accuracy: 0.6056
# Epoch 207/500
# 11/11 [==============================] - 8s 732ms/step - loss: 0.4266 - accuracy: 0.8324 - val_loss: 1.3273 - val_accuracy: 0.6268
# Epoch 208/500
# 11/11 [==============================] - 8s 728ms/step - loss: 0.4598 - accuracy: 0.8400 - val_loss: 1.3569 - val_accuracy: 0.6197
# Epoch 209/500
# 11/11 [==============================] - 8s 723ms/step - loss: 0.3573 - accuracy: 0.8659 - val_loss: 1.5520 - val_accuracy: 0.5634
# Epoch 210/500
# 11/11 [==============================] - 8s 727ms/step - loss: 0.5309 - accuracy: 0.8133 - val_loss: 1.7898 - val_accuracy: 0.6056
# Epoch 211/500
# 11/11 [==============================] - 8s 725ms/step - loss: 0.5650 - accuracy: 0.7965 - val_loss: 1.4527 - val_accuracy: 0.6127
# Epoch 212/500
# 11/11 [==============================] - 8s 732ms/step - loss: 0.7148 - accuracy: 0.7680 - val_loss: 1.1470 - val_accuracy: 0.6338
# Epoch 213/500
# 11/11 [==============================] - 8s 731ms/step - loss: 0.5035 - accuracy: 0.8408 - val_loss: 1.5907 - val_accuracy: 0.5423
# Epoch 214/500
# 11/11 [==============================] - 8s 721ms/step - loss: 0.4154 - accuracy: 0.8529 - val_loss: 1.5744 - val_accuracy: 0.5845
# Epoch 215/500
# 11/11 [==============================] - 8s 709ms/step - loss: 0.5307 - accuracy: 0.8109 - val_loss: 1.4702 - val_accuracy: 0.5634
# Epoch 216/500
# 11/11 [==============================] - 8s 735ms/step - loss: 0.4251 - accuracy: 0.8402 - val_loss: 1.2891 - val_accuracy: 0.6549
# Epoch 217/500
# 11/11 [==============================] - 8s 717ms/step - loss: 0.4639 - accuracy: 0.8322 - val_loss: 1.2686 - val_accuracy: 0.6408
# Epoch 218/500
# 11/11 [==============================] - 8s 787ms/step - loss: 0.4475 - accuracy: 0.8448 - val_loss: 1.5954 - val_accuracy: 0.5986
# Epoch 219/500
# 11/11 [==============================] - 8s 723ms/step - loss: 0.3946 - accuracy: 0.8537 - val_loss: 1.3246 - val_accuracy: 0.6197
# Epoch 220/500
# 11/11 [==============================] - 8s 715ms/step - loss: 0.3914 - accuracy: 0.8630 - val_loss: 1.3383 - val_accuracy: 0.6408
# Epoch 221/500
# 11/11 [==============================] - 8s 715ms/step - loss: 0.4060 - accuracy: 0.8635 - val_loss: 1.5098 - val_accuracy: 0.5352
# Epoch 222/500
# 11/11 [==============================] - 8s 711ms/step - loss: 0.4725 - accuracy: 0.8443 - val_loss: 2.1731 - val_accuracy: 0.5704
# Epoch 223/500
# 11/11 [==============================] - 8s 723ms/step - loss: 0.5383 - accuracy: 0.8211 - val_loss: 1.5625 - val_accuracy: 0.6056
# Epoch 224/500
# 11/11 [==============================] - 8s 722ms/step - loss: 0.5075 - accuracy: 0.8228 - val_loss: 1.5014 - val_accuracy: 0.6338
# Epoch 225/500
# 11/11 [==============================] - 8s 718ms/step - loss: 0.4482 - accuracy: 0.8179 - val_loss: 1.5587 - val_accuracy: 0.6408
# Epoch 226/500
# 11/11 [==============================] - 8s 722ms/step - loss: 0.4456 - accuracy: 0.8520 - val_loss: 1.6799 - val_accuracy: 0.6056
# Epoch 227/500
# 11/11 [==============================] - 8s 717ms/step - loss: 0.4405 - accuracy: 0.8491 - val_loss: 1.8435 - val_accuracy: 0.5634
# Epoch 228/500
# 11/11 [==============================] - 8s 710ms/step - loss: 0.5046 - accuracy: 0.8215 - val_loss: 1.3126 - val_accuracy: 0.6268
# Epoch 229/500
# 11/11 [==============================] - 8s 722ms/step - loss: 0.3749 - accuracy: 0.8430 - val_loss: 1.2242 - val_accuracy: 0.6479
# Epoch 230/500
# 11/11 [==============================] - 8s 723ms/step - loss: 0.3719 - accuracy: 0.8720 - val_loss: 1.4490 - val_accuracy: 0.6690
# Epoch 231/500
# 11/11 [==============================] - 8s 729ms/step - loss: 0.6498 - accuracy: 0.7935 - val_loss: 1.1654 - val_accuracy: 0.6479
# Epoch 232/500
# 11/11 [==============================] - 8s 729ms/step - loss: 0.3442 - accuracy: 0.8863 - val_loss: 1.2499 - val_accuracy: 0.6831
# Epoch 233/500
# 11/11 [==============================] - 8s 726ms/step - loss: 0.4383 - accuracy: 0.8576 - val_loss: 1.2521 - val_accuracy: 0.6479
# Epoch 234/500
# 11/11 [==============================] - 8s 718ms/step - loss: 0.3604 - accuracy: 0.8628 - val_loss: 1.5422 - val_accuracy: 0.6056
# Epoch 235/500
# 11/11 [==============================] - 8s 716ms/step - loss: 0.4380 - accuracy: 0.8357 - val_loss: 1.3017 - val_accuracy: 0.6620
# Epoch 236/500
# 11/11 [==============================] - 8s 731ms/step - loss: 0.3927 - accuracy: 0.8640 - val_loss: 1.4205 - val_accuracy: 0.6901
# Epoch 237/500
# 11/11 [==============================] - 8s 730ms/step - loss: 0.3218 - accuracy: 0.8781 - val_loss: 1.6030 - val_accuracy: 0.6338
# Epoch 238/500
# 11/11 [==============================] - 8s 722ms/step - loss: 0.2924 - accuracy: 0.8887 - val_loss: 2.2845 - val_accuracy: 0.4789
# Epoch 239/500
# 11/11 [==============================] - 8s 713ms/step - loss: 0.6421 - accuracy: 0.7982 - val_loss: 1.2803 - val_accuracy: 0.6620
# Epoch 240/500
# 11/11 [==============================] - 8s 717ms/step - loss: 0.3234 - accuracy: 0.9017 - val_loss: 1.5333 - val_accuracy: 0.6268
# Epoch 241/500
# 11/11 [==============================] - 8s 729ms/step - loss: 0.2221 - accuracy: 0.9149 - val_loss: 1.8351 - val_accuracy: 0.6549
# Epoch 242/500
# 11/11 [==============================] - 8s 720ms/step - loss: 0.4509 - accuracy: 0.8521 - val_loss: 1.4546 - val_accuracy: 0.6479
# Epoch 243/500
# 11/11 [==============================] - 8s 729ms/step - loss: 0.4049 - accuracy: 0.8744 - val_loss: 1.3228 - val_accuracy: 0.6620
# Epoch 244/500
# 11/11 [==============================] - 8s 727ms/step - loss: 0.4574 - accuracy: 0.8266 - val_loss: 1.6667 - val_accuracy: 0.5986
# Epoch 245/500
# 11/11 [==============================] - 8s 721ms/step - loss: 0.3653 - accuracy: 0.8595 - val_loss: 2.0362 - val_accuracy: 0.5986
# Epoch 246/500
# 11/11 [==============================] - 8s 727ms/step - loss: 0.3693 - accuracy: 0.8630 - val_loss: 2.8914 - val_accuracy: 0.4789
# Epoch 247/500
# 11/11 [==============================] - 8s 732ms/step - loss: 0.4751 - accuracy: 0.8566 - val_loss: 1.8625 - val_accuracy: 0.6197
# Epoch 248/500
# 11/11 [==============================] - 8s 732ms/step - loss: 0.4598 - accuracy: 0.8228 - val_loss: 1.6961 - val_accuracy: 0.5915
# Epoch 249/500
# 11/11 [==============================] - 8s 780ms/step - loss: 0.3697 - accuracy: 0.8679 - val_loss: 1.3283 - val_accuracy: 0.6549
# Epoch 250/500
# 11/11 [==============================] - 8s 715ms/step - loss: 0.2241 - accuracy: 0.9357 - val_loss: 1.3908 - val_accuracy: 0.6761
# Epoch 251/500
# 11/11 [==============================] - 8s 718ms/step - loss: 0.4292 - accuracy: 0.8696 - val_loss: 1.4757 - val_accuracy: 0.6127
# Epoch 252/500
# 11/11 [==============================] - 8s 718ms/step - loss: 0.2595 - accuracy: 0.9181 - val_loss: 1.2604 - val_accuracy: 0.6972
# Epoch 253/500
# 11/11 [==============================] - 8s 787ms/step - loss: 0.2828 - accuracy: 0.8995 - val_loss: 1.4977 - val_accuracy: 0.5986
# Epoch 254/500
# 11/11 [==============================] - 8s 727ms/step - loss: 0.3529 - accuracy: 0.8934 - val_loss: 1.3001 - val_accuracy: 0.6690
# Epoch 255/500
# 11/11 [==============================] - 8s 724ms/step - loss: 0.2735 - accuracy: 0.9204 - val_loss: 1.6594 - val_accuracy: 0.6479
# Epoch 256/500
# 11/11 [==============================] - 8s 739ms/step - loss: 0.4033 - accuracy: 0.8774 - val_loss: 1.1888 - val_accuracy: 0.6620
# Epoch 257/500
# 11/11 [==============================] - 8s 717ms/step - loss: 0.2200 - accuracy: 0.9259 - val_loss: 1.7647 - val_accuracy: 0.5634
# Epoch 258/500
# 11/11 [==============================] - 8s 721ms/step - loss: 0.5520 - accuracy: 0.8118 - val_loss: 1.2902 - val_accuracy: 0.6479
# Epoch 259/500
# 11/11 [==============================] - 8s 720ms/step - loss: 0.2262 - accuracy: 0.9315 - val_loss: 1.5263 - val_accuracy: 0.6408
# Epoch 260/500
# 11/11 [==============================] - 8s 719ms/step - loss: 0.3999 - accuracy: 0.8687 - val_loss: 1.4729 - val_accuracy: 0.5634
# Epoch 261/500
# 11/11 [==============================] - 8s 715ms/step - loss: 0.2433 - accuracy: 0.9177 - val_loss: 1.6525 - val_accuracy: 0.5704
# Epoch 262/500
# 11/11 [==============================] - 8s 785ms/step - loss: 0.2864 - accuracy: 0.9099 - val_loss: 1.5862 - val_accuracy: 0.6620
# Epoch 263/500
# 11/11 [==============================] - 8s 711ms/step - loss: 0.3261 - accuracy: 0.9000 - val_loss: 1.4697 - val_accuracy: 0.6268
# Epoch 264/500
# 11/11 [==============================] - 8s 715ms/step - loss: 0.4298 - accuracy: 0.8559 - val_loss: 1.1451 - val_accuracy: 0.6901
# Epoch 265/500
# 11/11 [==============================] - 8s 720ms/step - loss: 0.2726 - accuracy: 0.9023 - val_loss: 1.5034 - val_accuracy: 0.6690
# Epoch 266/500
# 11/11 [==============================] - 8s 732ms/step - loss: 0.3569 - accuracy: 0.8642 - val_loss: 1.5410 - val_accuracy: 0.6197
# Epoch 267/500
# 11/11 [==============================] - 8s 722ms/step - loss: 0.2859 - accuracy: 0.9041 - val_loss: 1.9178 - val_accuracy: 0.5775
# Epoch 268/500
# 11/11 [==============================] - 8s 726ms/step - loss: 0.3876 - accuracy: 0.8701 - val_loss: 1.8132 - val_accuracy: 0.6338
# Epoch 269/500
# 11/11 [==============================] - 8s 781ms/step - loss: 0.5217 - accuracy: 0.8306 - val_loss: 1.7456 - val_accuracy: 0.5915
# Epoch 270/500
# 11/11 [==============================] - 8s 722ms/step - loss: 0.2757 - accuracy: 0.9063 - val_loss: 1.6102 - val_accuracy: 0.5563
# Epoch 271/500
# 11/11 [==============================] - 8s 726ms/step - loss: 0.3236 - accuracy: 0.8930 - val_loss: 1.4311 - val_accuracy: 0.5915
# Epoch 272/500
# 11/11 [==============================] - 8s 719ms/step - loss: 0.2760 - accuracy: 0.8996 - val_loss: 2.1147 - val_accuracy: 0.5000
# Epoch 273/500
# 11/11 [==============================] - 8s 716ms/step - loss: 0.3991 - accuracy: 0.8543 - val_loss: 1.5757 - val_accuracy: 0.6479
# Epoch 274/500
# 11/11 [==============================] - 8s 716ms/step - loss: 0.4506 - accuracy: 0.8522 - val_loss: 1.4812 - val_accuracy: 0.6338
# Epoch 275/500
# 11/11 [==============================] - 8s 723ms/step - loss: 0.2305 - accuracy: 0.9243 - val_loss: 1.5271 - val_accuracy: 0.6408
# Epoch 276/500
# 11/11 [==============================] - 8s 723ms/step - loss: 0.2227 - accuracy: 0.9265 - val_loss: 1.7744 - val_accuracy: 0.6056
# Epoch 277/500
# 11/11 [==============================] - 8s 717ms/step - loss: 0.2037 - accuracy: 0.9258 - val_loss: 1.9414 - val_accuracy: 0.6268
# Epoch 278/500
# 11/11 [==============================] - 8s 728ms/step - loss: 0.2569 - accuracy: 0.9173 - val_loss: 2.0571 - val_accuracy: 0.5986
# Epoch 279/500
# 11/11 [==============================] - 8s 725ms/step - loss: 0.3840 - accuracy: 0.8631 - val_loss: 2.0639 - val_accuracy: 0.6127
# Epoch 280/500
# 11/11 [==============================] - 8s 719ms/step - loss: 0.3390 - accuracy: 0.8919 - val_loss: 1.5024 - val_accuracy: 0.6761
# Epoch 281/500
# 11/11 [==============================] - 8s 709ms/step - loss: 0.1934 - accuracy: 0.9336 - val_loss: 2.4071 - val_accuracy: 0.5845
# Epoch 282/500
# 11/11 [==============================] - 8s 720ms/step - loss: 0.2810 - accuracy: 0.8981 - val_loss: 1.6634 - val_accuracy: 0.6620
# Epoch 283/500
# 11/11 [==============================] - 8s 725ms/step - loss: 0.2322 - accuracy: 0.9255 - val_loss: 1.4270 - val_accuracy: 0.6901
# Epoch 284/500
# 11/11 [==============================] - 8s 717ms/step - loss: 0.2410 - accuracy: 0.9184 - val_loss: 1.6258 - val_accuracy: 0.6197
# Epoch 285/500
# 11/11 [==============================] - 8s 780ms/step - loss: 0.6047 - accuracy: 0.8249 - val_loss: 1.4242 - val_accuracy: 0.6408
# Epoch 286/500
# 11/11 [==============================] - 8s 711ms/step - loss: 0.3479 - accuracy: 0.8774 - val_loss: 1.2485 - val_accuracy: 0.7113
# Epoch 287/500
# 11/11 [==============================] - 8s 785ms/step - loss: 0.3324 - accuracy: 0.8778 - val_loss: 1.8098 - val_accuracy: 0.6056
# Epoch 288/500
# 11/11 [==============================] - 8s 734ms/step - loss: 0.2040 - accuracy: 0.9082 - val_loss: 1.4132 - val_accuracy: 0.6901
# Epoch 289/500
# 11/11 [==============================] - 8s 705ms/step - loss: 0.1920 - accuracy: 0.9354 - val_loss: 1.6265 - val_accuracy: 0.6620
# Epoch 290/500
# 11/11 [==============================] - 8s 720ms/step - loss: 0.3008 - accuracy: 0.8945 - val_loss: 1.5109 - val_accuracy: 0.6690
# Epoch 291/500
# 11/11 [==============================] - 8s 713ms/step - loss: 0.1971 - accuracy: 0.9273 - val_loss: 2.0824 - val_accuracy: 0.6479
# Epoch 292/500
# 11/11 [==============================] - 8s 710ms/step - loss: 0.4191 - accuracy: 0.8707 - val_loss: 1.2576 - val_accuracy: 0.6549
# Epoch 293/500
# 11/11 [==============================] - 8s 716ms/step - loss: 0.2114 - accuracy: 0.9296 - val_loss: 2.0816 - val_accuracy: 0.5986
# Epoch 294/500
# 11/11 [==============================] - 8s 717ms/step - loss: 0.3224 - accuracy: 0.8929 - val_loss: 1.5335 - val_accuracy: 0.6620
# Epoch 295/500
# 11/11 [==============================] - 8s 728ms/step - loss: 0.3663 - accuracy: 0.8887 - val_loss: 1.4522 - val_accuracy: 0.6831
# Epoch 296/500
# 11/11 [==============================] - 8s 727ms/step - loss: 0.2703 - accuracy: 0.9012 - val_loss: 1.8318 - val_accuracy: 0.6761
# Epoch 297/500
# 11/11 [==============================] - 8s 717ms/step - loss: 0.2234 - accuracy: 0.9291 - val_loss: 1.8186 - val_accuracy: 0.6268
# Epoch 298/500
# 11/11 [==============================] - 8s 722ms/step - loss: 0.2667 - accuracy: 0.8998 - val_loss: 1.9644 - val_accuracy: 0.6761
# Epoch 299/500
# 11/11 [==============================] - 8s 734ms/step - loss: 0.3761 - accuracy: 0.8752 - val_loss: 1.5242 - val_accuracy: 0.6479
# Epoch 300/500
# 11/11 [==============================] - 8s 726ms/step - loss: 0.2522 - accuracy: 0.9016 - val_loss: 1.4870 - val_accuracy: 0.6831
# Epoch 301/500
# 11/11 [==============================] - 8s 725ms/step - loss: 0.1763 - accuracy: 0.9404 - val_loss: 1.5593 - val_accuracy: 0.6831
# Epoch 302/500
# 11/11 [==============================] - 8s 716ms/step - loss: 0.1905 - accuracy: 0.9336 - val_loss: 1.6588 - val_accuracy: 0.6338
# Epoch 303/500
# 11/11 [==============================] - 8s 719ms/step - loss: 0.2222 - accuracy: 0.9355 - val_loss: 1.7446 - val_accuracy: 0.6338
# Epoch 304/500
# 11/11 [==============================] - 8s 726ms/step - loss: 0.3350 - accuracy: 0.8893 - val_loss: 1.5892 - val_accuracy: 0.6690
# Epoch 305/500
# 11/11 [==============================] - 8s 713ms/step - loss: 0.1949 - accuracy: 0.9292 - val_loss: 1.9701 - val_accuracy: 0.6127
# Epoch 306/500
# 11/11 [==============================] - 8s 720ms/step - loss: 0.1807 - accuracy: 0.9438 - val_loss: 1.8695 - val_accuracy: 0.6690
# Epoch 307/500
# 11/11 [==============================] - 8s 724ms/step - loss: 0.3255 - accuracy: 0.9070 - val_loss: 1.6041 - val_accuracy: 0.6690
# Epoch 308/500
# 11/11 [==============================] - 8s 729ms/step - loss: 0.1581 - accuracy: 0.9441 - val_loss: 1.6292 - val_accuracy: 0.6620
# Epoch 309/500
# 11/11 [==============================] - 8s 722ms/step - loss: 0.1817 - accuracy: 0.9512 - val_loss: 2.2527 - val_accuracy: 0.6056
# Epoch 310/500
# 11/11 [==============================] - 8s 717ms/step - loss: 0.3541 - accuracy: 0.8916 - val_loss: 1.7413 - val_accuracy: 0.6197
# Epoch 311/500
# 11/11 [==============================] - 8s 708ms/step - loss: 0.2286 - accuracy: 0.9271 - val_loss: 1.5879 - val_accuracy: 0.6479
# Epoch 312/500
# 11/11 [==============================] - 8s 718ms/step - loss: 0.2354 - accuracy: 0.9099 - val_loss: 1.7965 - val_accuracy: 0.6761
# Epoch 313/500
# 11/11 [==============================] - 8s 785ms/step - loss: 0.2160 - accuracy: 0.9280 - val_loss: 1.3708 - val_accuracy: 0.6690
# Epoch 314/500
# 11/11 [==============================] - 8s 720ms/step - loss: 0.1573 - accuracy: 0.9436 - val_loss: 1.7786 - val_accuracy: 0.6268
# Epoch 315/500
# 11/11 [==============================] - 8s 721ms/step - loss: 0.3172 - accuracy: 0.8940 - val_loss: 1.5846 - val_accuracy: 0.6549
# Epoch 316/500
# 11/11 [==============================] - 8s 727ms/step - loss: 0.2195 - accuracy: 0.9290 - val_loss: 2.2761 - val_accuracy: 0.6268
# Epoch 317/500
# 11/11 [==============================] - 8s 724ms/step - loss: 0.2564 - accuracy: 0.9090 - val_loss: 1.3958 - val_accuracy: 0.6761
# Epoch 318/500
# 11/11 [==============================] - 8s 717ms/step - loss: 0.2317 - accuracy: 0.9242 - val_loss: 1.6582 - val_accuracy: 0.6479
# Epoch 319/500
# 11/11 [==============================] - 8s 711ms/step - loss: 0.2482 - accuracy: 0.9180 - val_loss: 2.4328 - val_accuracy: 0.5352
# Epoch 320/500
# 11/11 [==============================] - 8s 730ms/step - loss: 0.4016 - accuracy: 0.8635 - val_loss: 1.9494 - val_accuracy: 0.6197
# Epoch 321/500
# 11/11 [==============================] - 8s 725ms/step - loss: 0.1627 - accuracy: 0.9440 - val_loss: 1.6213 - val_accuracy: 0.6901
# Epoch 322/500
# 11/11 [==============================] - 8s 713ms/step - loss: 0.3945 - accuracy: 0.8821 - val_loss: 1.6863 - val_accuracy: 0.6338
# Epoch 323/500
# 11/11 [==============================] - 8s 717ms/step - loss: 0.1476 - accuracy: 0.9583 - val_loss: 1.7143 - val_accuracy: 0.6761
# Epoch 324/500
# 11/11 [==============================] - 8s 714ms/step - loss: 0.1479 - accuracy: 0.9518 - val_loss: 1.4669 - val_accuracy: 0.6761
# Epoch 325/500
# 11/11 [==============================] - 8s 782ms/step - loss: 0.4817 - accuracy: 0.8566 - val_loss: 1.4968 - val_accuracy: 0.6761
# Epoch 326/500
# 11/11 [==============================] - 8s 786ms/step - loss: 0.1432 - accuracy: 0.9593 - val_loss: 2.9156 - val_accuracy: 0.5775
# Epoch 327/500
# 11/11 [==============================] - 8s 721ms/step - loss: 0.5353 - accuracy: 0.8599 - val_loss: 1.2930 - val_accuracy: 0.7042
# Epoch 328/500
# 11/11 [==============================] - 8s 717ms/step - loss: 0.1635 - accuracy: 0.9445 - val_loss: 1.7837 - val_accuracy: 0.6761
# Epoch 329/500
# 11/11 [==============================] - 8s 723ms/step - loss: 0.2471 - accuracy: 0.9202 - val_loss: 2.1804 - val_accuracy: 0.6056
# Epoch 330/500
# 11/11 [==============================] - 8s 717ms/step - loss: 0.1499 - accuracy: 0.9516 - val_loss: 2.0715 - val_accuracy: 0.6197
# Epoch 331/500
# 11/11 [==============================] - 8s 720ms/step - loss: 0.1388 - accuracy: 0.9544 - val_loss: 1.8963 - val_accuracy: 0.6127
# Epoch 332/500
# ...
# Epoch 391/500
# 11/11 [==============================] - 8s 720ms/step - loss: 0.2506 - accuracy: 0.9278 - val_loss: 1.4079 - val_accuracy: 0.6901
# Epoch 392/500
# 11/11 [==============================] - 8s 714ms/step - loss: 0.1816 - accuracy: 0.9419 - val_loss: 1.8162 - val_accuracy: 0.6620
# Epoch 393/500
# 11/11 [==============================] - 8s 725ms/step - loss: 0.0645 - accuracy: 0.9825 - val_loss: 1.6797 - val_accuracy: 0.6831
# Epoch 394/500
# 11/11 [==============================] - 8s 719ms/step - loss: 0.0939 - accuracy: 0.9702 - val_loss: 1.6483 - val_accuracy: 0.6408
# Epoch 395/500
# 11/11 [==============================] - 8s 715ms/step - loss: 0.1124 - accuracy: 0.9663 - val_loss: 1.2772 - val_accuracy: 0.7394
# Epoch 396/500
# 11/11 [==============================] - 8s 722ms/step - loss: 0.1680 - accuracy: 0.9455 - val_loss: 1.7480 - val_accuracy: 0.6338
# Epoch 397/500
# 11/11 [==============================] - 8s 726ms/step - loss: 0.2556 - accuracy: 0.9375 - val_loss: 1.4233 - val_accuracy: 0.7254
# Epoch 398/500
# 11/11 [==============================] - 8s 725ms/step - loss: 0.1331 - accuracy: 0.9658 - val_loss: 1.5939 - val_accuracy: 0.7113
# Epoch 399/500
# 11/11 [==============================] - 8s 723ms/step - loss: 0.1355 - accuracy: 0.9572 - val_loss: 2.0126 - val_accuracy: 0.6690
# Epoch 400/500
# 11/11 [==============================] - 8s 719ms/step - loss: 0.2566 - accuracy: 0.9192 - val_loss: 1.9271 - val_accuracy: 0.6408
# Epoch 401/500
# 11/11 [==============================] - 8s 717ms/step - loss: 0.1417 - accuracy: 0.9609 - val_loss: 2.3668 - val_accuracy: 0.6620
# Epoch 402/500
# 11/11 [==============================] - 8s 719ms/step - loss: 0.1828 - accuracy: 0.9330 - val_loss: 2.1087 - val_accuracy: 0.6338
# Epoch 403/500
# 11/11 [==============================] - 8s 729ms/step - loss: 0.1133 - accuracy: 0.9574 - val_loss: 1.8751 - val_accuracy: 0.6972
# Epoch 404/500
# 11/11 [==============================] - 8s 778ms/step - loss: 0.1882 - accuracy: 0.9509 - val_loss: 1.7007 - val_accuracy: 0.6408
# Epoch 405/500
# 11/11 [==============================] - 8s 713ms/step - loss: 0.0582 - accuracy: 0.9850 - val_loss: 2.5583 - val_accuracy: 0.5915
# Epoch 406/500
# 11/11 [==============================] - 8s 707ms/step - loss: 0.1833 - accuracy: 0.9348 - val_loss: 2.9821 - val_accuracy: 0.5915
# Epoch 407/500
# 11/11 [==============================] - 8s 717ms/step - loss: 0.3216 - accuracy: 0.9175 - val_loss: 1.7979 - val_accuracy: 0.6761
# Epoch 408/500
# 11/11 [==============================] - 8s 729ms/step - loss: 0.0666 - accuracy: 0.9889 - val_loss: 1.9064 - val_accuracy: 0.6549
# Epoch 409/500
# 11/11 [==============================] - 8s 725ms/step - loss: 0.0847 - accuracy: 0.9704 - val_loss: 1.6307 - val_accuracy: 0.6972
# Epoch 410/500
# 11/11 [==============================] - 8s 733ms/step - loss: 0.1949 - accuracy: 0.9413 - val_loss: 1.9936 - val_accuracy: 0.6127
# Epoch 411/500
# 11/11 [==============================] - 8s 721ms/step - loss: 0.0880 - accuracy: 0.9676 - val_loss: 1.9046 - val_accuracy: 0.6690
# Epoch 412/500
# 11/11 [==============================] - 8s 710ms/step - loss: 0.0914 - accuracy: 0.9750 - val_loss: 1.9745 - val_accuracy: 0.6901
# Epoch 413/500
# 11/11 [==============================] - 8s 744ms/step - loss: 0.2629 - accuracy: 0.9193 - val_loss: 1.2814 - val_accuracy: 0.7254
# Epoch 414/500
# 11/11 [==============================] - 8s 784ms/step - loss: 0.1735 - accuracy: 0.9536 - val_loss: 1.4491 - val_accuracy: 0.7113
# Epoch 415/500
# 11/11 [==============================] - 8s 733ms/step - loss: 0.0795 - accuracy: 0.9722 - val_loss: 2.2200 - val_accuracy: 0.6268
# Epoch 416/500
# 11/11 [==============================] - 8s 744ms/step - loss: 0.1594 - accuracy: 0.9525 - val_loss: 1.6112 - val_accuracy: 0.7183
# Epoch 417/500
# 11/11 [==============================] - 8s 745ms/step - loss: 0.1327 - accuracy: 0.9539 - val_loss: 2.0718 - val_accuracy: 0.6056
# Epoch 418/500
# 11/11 [==============================] - 8s 739ms/step - loss: 0.4235 - accuracy: 0.8763 - val_loss: 1.5191 - val_accuracy: 0.6761
# Epoch 419/500
# 11/11 [==============================] - 8s 752ms/step - loss: 0.0687 - accuracy: 0.9777 - val_loss: 1.4716 - val_accuracy: 0.6761
# Epoch 420/500
# 11/11 [==============================] - 8s 742ms/step - loss: 0.0662 - accuracy: 0.9825 - val_loss: 1.6883 - val_accuracy: 0.6056
# Epoch 421/500
# 11/11 [==============================] - 8s 748ms/step - loss: 0.1302 - accuracy: 0.9568 - val_loss: 2.2392 - val_accuracy: 0.6408
# Epoch 422/500
# 11/11 [==============================] - 8s 730ms/step - loss: 0.0997 - accuracy: 0.9757 - val_loss: 2.1929 - val_accuracy: 0.5845
# Epoch 423/500
# 11/11 [==============================] - 8s 720ms/step - loss: 0.2575 - accuracy: 0.9146 - val_loss: 1.8822 - val_accuracy: 0.6690
# Epoch 424/500
# 11/11 [==============================] - 8s 728ms/step - loss: 0.1772 - accuracy: 0.9445 - val_loss: 1.4858 - val_accuracy: 0.6972
# Epoch 425/500
# 11/11 [==============================] - 8s 726ms/step - loss: 0.0895 - accuracy: 0.9681 - val_loss: 1.4125 - val_accuracy: 0.6761
# Epoch 426/500
# 11/11 [==============================] - 8s 736ms/step - loss: 0.0792 - accuracy: 0.9684 - val_loss: 1.5207 - val_accuracy: 0.6901
# Epoch 427/500
# 11/11 [==============================] - 8s 738ms/step - loss: 0.1591 - accuracy: 0.9515 - val_loss: 1.5418 - val_accuracy: 0.7465
# Epoch 428/500
# 11/11 [==============================] - 8s 743ms/step - loss: 0.0861 - accuracy: 0.9759 - val_loss: 1.4208 - val_accuracy: 0.7254
# Epoch 429/500
# 11/11 [==============================] - 8s 739ms/step - loss: 0.2358 - accuracy: 0.9313 - val_loss: 1.8547 - val_accuracy: 0.6408
# Epoch 430/500
# 11/11 [==============================] - 8s 727ms/step - loss: 0.1624 - accuracy: 0.9343 - val_loss: 1.8958 - val_accuracy: 0.6831
# Epoch 431/500
# 11/11 [==============================] - 8s 756ms/step - loss: 0.3166 - accuracy: 0.8989 - val_loss: 1.6242 - val_accuracy: 0.6479
# Epoch 432/500
# 11/11 [==============================] - 9s 832ms/step - loss: 0.1688 - accuracy: 0.9506 - val_loss: 1.4640 - val_accuracy: 0.7113
# Epoch 433/500
# 11/11 [==============================] - 8s 748ms/step - loss: 0.1090 - accuracy: 0.9667 - val_loss: 1.6883 - val_accuracy: 0.6831
# Epoch 434/500
# 11/11 [==============================] - 9s 758ms/step - loss: 0.1672 - accuracy: 0.9322 - val_loss: 1.9865 - val_accuracy: 0.6690
# Epoch 435/500
# 11/11 [==============================] - 8s 822ms/step - loss: 0.3244 - accuracy: 0.9131 - val_loss: 1.7225 - val_accuracy: 0.6620
# Epoch 436/500
# 11/11 [==============================] - 8s 749ms/step - loss: 0.0708 - accuracy: 0.9792 - val_loss: 1.9427 - val_accuracy: 0.6479
# Epoch 437/500
# 11/11 [==============================] - 8s 760ms/step - loss: 0.4323 - accuracy: 0.8773 - val_loss: 1.8253 - val_accuracy: 0.6056
# Epoch 438/500
# 11/11 [==============================] - 8s 741ms/step - loss: 0.1350 - accuracy: 0.9544 - val_loss: 1.5576 - val_accuracy: 0.7254
# Epoch 439/500
# 11/11 [==============================] - 9s 759ms/step - loss: 0.0624 - accuracy: 0.9815 - val_loss: 1.7960 - val_accuracy: 0.6761
# Epoch 440/500
# 11/11 [==============================] - 8s 741ms/step - loss: 0.1353 - accuracy: 0.9667 - val_loss: 1.9175 - val_accuracy: 0.5634
# Epoch 441/500
# 11/11 [==============================] - 8s 752ms/step - loss: 0.0798 - accuracy: 0.9715 - val_loss: 1.9781 - val_accuracy: 0.6972
# Epoch 442/500
# 11/11 [==============================] - 8s 754ms/step - loss: 0.0781 - accuracy: 0.9796 - val_loss: 1.5520 - val_accuracy: 0.6972
# Epoch 443/500
# 11/11 [==============================] - 9s 767ms/step - loss: 0.0527 - accuracy: 0.9824 - val_loss: 1.8384 - val_accuracy: 0.6620
# Epoch 444/500
# 11/11 [==============================] - 8s 736ms/step - loss: 0.0831 - accuracy: 0.9766 - val_loss: 2.0157 - val_accuracy: 0.6197
# Epoch 445/500
# 11/11 [==============================] - 8s 740ms/step - loss: 0.1839 - accuracy: 0.9336 - val_loss: 1.6751 - val_accuracy: 0.6620
# Epoch 446/500
# 11/11 [==============================] - 8s 736ms/step - loss: 0.0927 - accuracy: 0.9710 - val_loss: 1.6703 - val_accuracy: 0.6549
# Epoch 447/500
# 11/11 [==============================] - 8s 747ms/step - loss: 0.0545 - accuracy: 0.9802 - val_loss: 1.6729 - val_accuracy: 0.7113
# Epoch 448/500
# 11/11 [==============================] - 8s 756ms/step - loss: 0.3463 - accuracy: 0.9162 - val_loss: 1.4183 - val_accuracy: 0.6831
# Epoch 449/500
# 11/11 [==============================] - 8s 818ms/step - loss: 0.0885 - accuracy: 0.9631 - val_loss: 1.7831 - val_accuracy: 0.6408
# Epoch 450/500
# 11/11 [==============================] - 8s 758ms/step - loss: 0.0714 - accuracy: 0.9787 - val_loss: 1.7532 - val_accuracy: 0.6901
# Epoch 451/500
# 11/11 [==============================] - 8s 759ms/step - loss: 0.1500 - accuracy: 0.9580 - val_loss: 1.8596 - val_accuracy: 0.6690
# Epoch 452/500
# 11/11 [==============================] - 8s 754ms/step - loss: 0.1187 - accuracy: 0.9633 - val_loss: 1.7099 - val_accuracy: 0.6831
# Epoch 453/500
# 11/11 [==============================] - 8s 748ms/step - loss: 0.1182 - accuracy: 0.9510 - val_loss: 1.7177 - val_accuracy: 0.7113
# Epoch 454/500
# 11/11 [==============================] - 8s 746ms/step - loss: 0.0497 - accuracy: 0.9809 - val_loss: 2.0738 - val_accuracy: 0.6901
# Epoch 455/500
# 11/11 [==============================] - 8s 740ms/step - loss: 0.0799 - accuracy: 0.9776 - val_loss: 2.2515 - val_accuracy: 0.5915
# Epoch 456/500
# 11/11 [==============================] - 8s 743ms/step - loss: 0.3892 - accuracy: 0.8802 - val_loss: 1.5886 - val_accuracy: 0.6479
# Epoch 457/500
# 11/11 [==============================] - 9s 794ms/step - loss: 0.0927 - accuracy: 0.9761 - val_loss: 2.0186 - val_accuracy: 0.7042
# Epoch 458/500
# 11/11 [==============================] - 8s 740ms/step - loss: 0.0392 - accuracy: 0.9857 - val_loss: 2.1159 - val_accuracy: 0.6268
# Epoch 459/500
# 11/11 [==============================] - 8s 765ms/step - loss: 0.1577 - accuracy: 0.9575 - val_loss: 2.3162 - val_accuracy: 0.5704
# Epoch 460/500
# 11/11 [==============================] - 9s 762ms/step - loss: 0.4781 - accuracy: 0.8797 - val_loss: 1.5782 - val_accuracy: 0.6901
# Epoch 461/500
# 11/11 [==============================] - 8s 763ms/step - loss: 0.0671 - accuracy: 0.9778 - val_loss: 1.5103 - val_accuracy: 0.7113
# Epoch 462/500
# 11/11 [==============================] - 8s 758ms/step - loss: 0.0679 - accuracy: 0.9847 - val_loss: 2.1630 - val_accuracy: 0.6620
# Epoch 463/500
# 11/11 [==============================] - 8s 762ms/step - loss: 0.0986 - accuracy: 0.9743 - val_loss: 1.7884 - val_accuracy: 0.6268
# Epoch 464/500
# 11/11 [==============================] - 8s 749ms/step - loss: 0.1113 - accuracy: 0.9680 - val_loss: 1.8624 - val_accuracy: 0.6901
# Epoch 465/500
# 11/11 [==============================] - 8s 756ms/step - loss: 0.1041 - accuracy: 0.9677 - val_loss: 1.5806 - val_accuracy: 0.6620
# Epoch 466/500
# 11/11 [==============================] - 8s 758ms/step - loss: 0.0971 - accuracy: 0.9633 - val_loss: 1.8779 - val_accuracy: 0.7113
# Epoch 467/500
# 11/11 [==============================] - 8s 746ms/step - loss: 0.1128 - accuracy: 0.9625 - val_loss: 1.5720 - val_accuracy: 0.6901
# Epoch 468/500
# 11/11 [==============================] - 8s 725ms/step - loss: 0.1723 - accuracy: 0.9479 - val_loss: 1.6099 - val_accuracy: 0.6338
# Epoch 469/500
# 11/11 [==============================] - 8s 721ms/step - loss: 0.1414 - accuracy: 0.9538 - val_loss: 1.5306 - val_accuracy: 0.6620
# Epoch 470/500
# 11/11 [==============================] - 8s 728ms/step - loss: 0.0936 - accuracy: 0.9731 - val_loss: 1.7228 - val_accuracy: 0.6901
# Epoch 471/500
# 11/11 [==============================] - 8s 731ms/step - loss: 0.0568 - accuracy: 0.9824 - val_loss: 2.4837 - val_accuracy: 0.6197
# Epoch 472/500
# 11/11 [==============================] - 8s 722ms/step - loss: 0.1694 - accuracy: 0.9508 - val_loss: 1.8490 - val_accuracy: 0.6549
# Epoch 473/500
# 11/11 [==============================] - 8s 724ms/step - loss: 0.0729 - accuracy: 0.9770 - val_loss: 1.7442 - val_accuracy: 0.6620
# Epoch 474/500
# 11/11 [==============================] - 8s 727ms/step - loss: 0.0374 - accuracy: 0.9918 - val_loss: 1.8653 - val_accuracy: 0.6761
# Epoch 475/500
# 11/11 [==============================] - 8s 747ms/step - loss: 0.2301 - accuracy: 0.9401 - val_loss: 2.6353 - val_accuracy: 0.5775
# Epoch 476/500
# 11/11 [==============================] - 8s 743ms/step - loss: 0.0857 - accuracy: 0.9694 - val_loss: 1.9104 - val_accuracy: 0.7042
# Epoch 477/500
# 11/11 [==============================] - 8s 738ms/step - loss: 0.1139 - accuracy: 0.9675 - val_loss: 2.2492 - val_accuracy: 0.6831
# Epoch 478/500
# 11/11 [==============================] - 8s 738ms/step - loss: 0.1094 - accuracy: 0.9701 - val_loss: 1.8272 - val_accuracy: 0.6972
# Epoch 479/500
# 11/11 [==============================] - 8s 804ms/step - loss: 0.1182 - accuracy: 0.9549 - val_loss: 1.9378 - val_accuracy: 0.7042
# Epoch 480/500
# 11/11 [==============================] - 8s 729ms/step - loss: 0.1449 - accuracy: 0.9485 - val_loss: 2.0053 - val_accuracy: 0.6831
# Epoch 481/500
# 11/11 [==============================] - 8s 751ms/step - loss: 0.0992 - accuracy: 0.9671 - val_loss: 2.1185 - val_accuracy: 0.6831
# Epoch 482/500
# 11/11 [==============================] - 9s 776ms/step - loss: 0.2326 - accuracy: 0.9403 - val_loss: 2.2336 - val_accuracy: 0.6127
# Epoch 483/500
# 11/11 [==============================] - 9s 769ms/step - loss: 0.2249 - accuracy: 0.9285 - val_loss: 1.8892 - val_accuracy: 0.6479
# Epoch 484/500
# 11/11 [==============================] - 9s 774ms/step - loss: 0.0512 - accuracy: 0.9861 - val_loss: 1.7992 - val_accuracy: 0.7042
# Epoch 485/500
# 11/11 [==============================] - 9s 789ms/step - loss: 0.0362 - accuracy: 0.9893 - val_loss: 1.7777 - val_accuracy: 0.6901
# Epoch 486/500
# 11/11 [==============================] - 9s 768ms/step - loss: 0.0894 - accuracy: 0.9737 - val_loss: 2.1561 - val_accuracy: 0.6338
# Epoch 487/500
# 11/11 [==============================] - 9s 765ms/step - loss: 0.1458 - accuracy: 0.9588 - val_loss: 1.7968 - val_accuracy: 0.6972
# Epoch 488/500
# 11/11 [==============================] - 8s 735ms/step - loss: 0.0995 - accuracy: 0.9781 - val_loss: 1.7204 - val_accuracy: 0.6690
# Epoch 489/500
# 11/11 [==============================] - 8s 736ms/step - loss: 0.0973 - accuracy: 0.9708 - val_loss: 1.9654 - val_accuracy: 0.5915
# Epoch 490/500
# 11/11 [==============================] - 8s 801ms/step - loss: 0.1608 - accuracy: 0.9494 - val_loss: 1.8479 - val_accuracy: 0.6901
# Epoch 491/500
# 11/11 [==============================] - 8s 728ms/step - loss: 0.0879 - accuracy: 0.9732 - val_loss: 1.8581 - val_accuracy: 0.6690
# Epoch 492/500
# 11/11 [==============================] - 8s 733ms/step - loss: 0.1286 - accuracy: 0.9708 - val_loss: 1.7428 - val_accuracy: 0.6831
# Epoch 493/500
# 11/11 [==============================] - 8s 725ms/step - loss: 0.0644 - accuracy: 0.9839 - val_loss: 1.8300 - val_accuracy: 0.6690
# Epoch 494/500
# 11/11 [==============================] - 8s 748ms/step - loss: 0.0700 - accuracy: 0.9773 - val_loss: 2.9064 - val_accuracy: 0.5634
# Epoch 495/500
# 11/11 [==============================] - 9s 765ms/step - loss: 0.1760 - accuracy: 0.9461 - val_loss: 1.7482 - val_accuracy: 0.7183
# Epoch 496/500
# 11/11 [==============================] - 8s 757ms/step - loss: 0.1063 - accuracy: 0.9756 - val_loss: 1.6996 - val_accuracy: 0.6972
# Epoch 497/500
# 11/11 [==============================] - 8s 759ms/step - loss: 0.2161 - accuracy: 0.9320 - val_loss: 1.9876 - val_accuracy: 0.7042
# Epoch 498/500
# 11/11 [==============================] - 8s 752ms/step - loss: 0.0657 - accuracy: 0.9851 - val_loss: 2.3383 - val_accuracy: 0.6620
# Epoch 499/500
# 11/11 [==============================] - 8s 750ms/step - loss: 0.0905 - accuracy: 0.9764 - val_loss: 1.9727 - val_accuracy: 0.6197
# Epoch 500/500
# 11/11 [==============================] - 8s 734ms/step - loss: 0.1251 - accuracy: 0.9678 - val_loss: 1.8495 - val_accuracy: 0.6901

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import random
import tensorflow_datasets as tfds

from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist

num_classes = 5 #metadata.features['label'].num_classes
print(num_classes)

#get_label_name = metadata.features['label'].int2str

image ,label = next(iter(train_generator))
print(label[1])
image=image[0, :, :, :, ]
_ = plt.imshow(image)
#_ = plt.title(get_label_name(label))
#print(image)

#IMG_SIZE = 180

#resize_and_rescale = tf.keras.Sequential([
#  layers.experimental.preprocessing.Resizing(IMG_SIZE, IMG_SIZE),
#  layers.experimental.preprocessing.Rescaling(1./255)

#])

#result = resize_and_rescale(image)
#_ = plt.imshow(result)
# Out:
# 5
# [0. 0. 0. 0. 1.]

# %%
#_ = plt.title(get_label_name(label))
#print(image)

IMG_SIZE = 180
resize_and_rescale = tf.keras.Sequential([
  layers.experimental.preprocessing.Resizing(IMG_SIZE, IMG_SIZE),
  #layers.experimental.preprocessing.Rescaling(1./255)

])

result = resize_and_rescale(image)
_ = plt.imshow(result)

# %%
data_augmentation =tf.keras.Sequential(
    [
        
        tf.keras.layers.experimental.preprocessing.Resizing(height=400,width=400),
        tf.keras.layers.experimental.preprocessing.RandomFlip(mode='horizontal'),
        tf.keras.layers.experimental.preprocessing.RandomRotation(factor=0.2),
        tf.keras.layers.experimental.preprocessing.RandomContrast(factor=0.4),
        tf.keras.layers.experimental.preprocessing.RandomZoom(height_factor=0.2,width_factor=0.2)
    ]
)
# Add the image to a batch
image = tf.expand_dims(image, 0)

plt.figure(figsize=(10, 10))
for i in range(9):
  augmented_image = data_augmentation(image)
  ax = plt.subplot(3, 3, i + 1)
  plt.imshow(augmented_image[0])
  plt.axis("off")
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
model.layers
# Out:
# [<tensorflow.python.keras.layers.preprocessing.image_preprocessing.Resizing at 0x7f3e908fd950>,
#  <tensorflow.python.keras.layers.preprocessing.image_preprocessing.RandomFlip at 0x7f3e80714e10>,
#  <tensorflow.python.keras.layers.preprocessing.image_preprocessing.RandomRotation at 0x7f3e8073c0d0>,
#  <tensorflow.python.keras.layers.preprocessing.image_preprocessing.RandomContrast at 0x7f3e8073c5d0>,
#  <tensorflow.python.keras.layers.preprocessing.image_preprocessing.RandomZoom at 0x7f3e8073c650>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3e8073cf10>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7f3e80745750>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3e80745c90>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7f3e806e82d0>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3e806e8710>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7f3e806e8cd0>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3e806eb190>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7f3e806eb790>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3e806ebc10>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7f3e806ef250>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3e806ef6d0>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7f3e806efcd0>,
#  <tensorflow.python.keras.layers.core.Flatten at 0x7f3e80748190>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f3e80748450>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f3e80748810>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f3e80748bd0>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f3e80748fd0>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f3e806f8410>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f3e806f8810>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f3e806f8c10>]

# %%
# Guardar el Modelo
#model.save('path_to_my_modelv1.h5')
model = tf.keras.models.load_model('path_to_my_modelv1.h5')
# Recrea exactamente el mismo modelo solo desde el archivo
#new_model = keras.models.load_model('path_to_my_model.h5')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-127-241b5ea67d60> in <module>()
#       1 # Guardar el Modelo
#       2 #model.save('path_to_my_modelv1.h5')
# ----> 3 model = tf.keras.models.load_model('path_to_my_modelv1.h5')
#       4 # Recrea exactamente el mismo modelo solo desde el archivo
#       5 #new_model = keras.models.load_model('path_to_my_model.h5')
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     209       filepath = path_to_string(filepath)
#     210       if isinstance(filepath, six.string_types):
# --> 211         loader_impl.parse_saved_model(filepath)
#     212         return saved_model_load.load(filepath, compile, options)
#     213
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/saved_model/loader_impl.py in parse_saved_model(export_dir)
#     112                   (export_dir,
#     113                    constants.SAVED_MODEL_FILENAME_PBTXT,
# --> 114                    constants.SAVED_MODEL_FILENAME_PB))
#     115
#     116
#
# OSError: SavedModel file does not exist at: path_to_my_modelv1.h5/{saved_model.pbtxt|saved_model.pb}

# %% [markdown]
# El siguiente codigo, nos permitira ingresar imagenes de nuestro computador para mostraselas a nuestra red nueronal y las clasifique entre linces y leopardos

# %%
import numpy as np
from google.colab import files
import random
from keras.preprocessing import image

uploaded = files.upload()

for fn in uploaded.keys():
 
  # predicting images
  path = fn
  img = image.load_img(path, target_size=(400, 400))
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size=10)
  print(fn)
  print(classes)
# Out:
#      <input type="file" id="files-8be81cb8-b500-456e-805e-5d639b8d0431" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8be81cb8-b500-456e-805e-5d639b8d0431">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving guepardo (1).jpg to guepardo (1) (2).jpg
# Saving guepardo (2).jpg to guepardo (2) (2).jpg
# Saving guepardo (19).jpg to guepardo (19) (2).jpg
# Saving leopardo (1).jpg to leopardo (1) (2).jpg
# Saving leopardo (2).jpg to leopardo (2) (2).jpg
# Saving leopardo.jpg to leopardo (4).jpg
# Saving lincei (1).jpg to lincei (1) (2).jpg
# Saving lincei (2).jpg to lincei (2) (2).jpg
# Saving lincei (3).jpg to lincei (3) (2).jpg
# Saving linci.jpg to linci (2).jpg
# Saving Ocelote (4).jpg to Ocelote (4) (2).jpg
# Saving Ocelote (19).jpg to Ocelote (19) (2).jpg
# Saving Ocelote (121).jpg to Ocelote (121) (2).jpg
# Saving Serval (1).jpg to Serval (1) (2).jpg
# Saving Serval (2).jpg to Serval (2) (2).jpg
# Saving Serval (3).jpg to Serval (3) (2).jpg
# guepardo (1).jpg
# [[1. 0. 0. 0. 0.]]
# guepardo (2).jpg
# [[1. 0. 0. 0. 0.]]
# guepardo (19).jpg
# [[0. 1. 0. 0. 0.]]
# leopardo (1).jpg
# [[0. 1. 0. 0. 0.]]
# leopardo (2).jpg
# [[0. 1. 0. 0. 0.]]
# leopardo.jpg
# [[1. 0. 0. 0. 0.]]
# lincei (1).jpg
# [[0.000000e+00 0.000000e+00 0.000000e+00 1.000000e+00 6.735475e-12]]
# lincei (2).jpg
# [[1.3464843e-22 1.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00]]
# lincei (3).jpg
# [[0. 1. 0. 0. 0.]]
# linci.jpg
# [[0. 1. 0. 0. 0.]]
# Ocelote (4).jpg
# [[0. 1. 0. 0. 0.]]
# Ocelote (19).jpg
# [[0.9119178  0.08808213 0.         0.         0.        ]]
# Ocelote (121).jpg
# [[1. 0. 0. 0. 0.]]
# Serval (1).jpg
# [[0. 1. 0. 0. 0.]]
# Serval (2).jpg
# [[1. 0. 0. 0. 0.]]
# Serval (3).jpg
# [[1.0000000e+00 2.9332623e-29 0.0000000e+00 0.0000000e+00 0.0000000e+00]]

# %%
import numpy as np

from google.colab import files
from keras.preprocessing import image

uploaded=files.upload()

for fn in uploaded.keys():
 
  # predicting images
  path='/content/' + fn
  img=image.load_img(path, target_size=(100, 100))
  
  x=image.img_to_array(img)
  x=np.expand_dims(x, axis=0)
  images = np.vstack([x])
  
  classes = model.predict(images, batch_size=10)
  
  print(classes[0])
  
  if classes[0]>0:
    print(fn + " es un Lince")
    
  else:
    print(fn + " es un leopardo")
# Out:
#      <input type="file" id="files-56591e83-b621-4766-bafd-660116d1bfa0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-56591e83-b621-4766-bafd-660116d1bfa0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving lince i.jpg to lince i (5).jpg
# Saving Lince-Ibérico-».jpg to Lince-Ibérico-» (5).jpg
# Saving LEo.jpg to LEo (6).jpg
# Saving leopardo.jpg to leopardo (6).jpg
# WARNING:tensorflow:11 out of the last 15 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fd2ddecac80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [0.]
# lince i.jpg es un leopardo
# [0.]
# Lince-Ibérico-».jpg es un leopardo
# [0.]
# LEo.jpg es un leopardo
# [0.]
# leopardo.jpg es un leopardo

# %% [markdown]
# Podmeos observar el recorrido de una imagen en nuestra red neuronal

# %%
import numpy as np
import random
from   tensorflow.keras.preprocessing.image import img_to_array, load_img

# Definamos un nuevo modelo que tomará una imagen como entrada y generará
# representaciones intermedias para todas las capas en el modelo anterior después de la primera.
successive_outputs = [layer.output for layer in model.layers[1:]]

#visualization_model = Model(img_input, successive_outputs)
visualization_model = tf.keras.models.Model(inputs = model.input, outputs = successive_outputs)

# Preparemos una imagen de entrada aleatoria de un leopardo o un lince del conjunto de entrenamiento.
leo_img_files = [os.path.join(train_leo_dir, f) for f in train_leo_fnames]
lince_img_files = [os.path.join(train_lince_dir, f) for f in train_lince_fnames]
ocelote_img_files = [os.path.join(train_ocelote_dir, f) for f in train_ocelote_fnames]
guepardo_img_files = [os.path.join(train_guepardo_dir, f) for f in train_guepardo_fnames]
serval_img_files = [os.path.join(train_serval_dir, f) for f in train_serval_fnames]

img_path1 = random.choice(leo_img_files + lince_img_files+ocelote_img_files+guepardo_img_files+serval_img_files)
img_path2 = random.choice(leo_img_files + lince_img_files+ocelote_img_files+guepardo_img_files+serval_img_files)
img_path3 = random.choice(leo_img_files + lince_img_files+ocelote_img_files+guepardo_img_files+serval_img_files)

img1 = load_img(img_path1, target_size=(400, 150))  # esta es uan imagen de tipo PIL
img2 = load_img(img_path2, target_size=(150, 150))
img3 = load_img(img_path3, target_size=(150, 150))

x1   = img_to_array(img1)
x2   = img_to_array(img2)
x3   = img_to_array(img3)                           # Numpy array con la forma (150, 150, 3)

x1   = x1.reshape((1,) + x1.shape)                   # Numpy array con la forma (1, 150, 150, 3)
x2   = x2.reshape((1,) + x2.shape)                   # Numpy array con la forma (1, 150, 150, 3)
x3   = x3.reshape((1,) + x3.shape)                   # Numpy array con la forma (1, 150, 150, 3)

# Rescale by 1/255
#x /= 255.0

# Ejecutamos nuestra imagen a través de nuestra red, obteniendo así todas las representaciones intermedias para esta imagen.
successive_feature_maps = visualization_model.predict(x1+x2+x3,batch_size=10)

# Estos son los nombres de las capas, por lo que podemos tenerlos como parte de nuestra trama.
layer_names = [layer.name for layer in model.layers]

# -----------------------------------------------------------------------
# ahora vamos a mostrar nuestras representaciones 
# -----------------------------------------------------------------------
for layer_name, feature_map in zip(layer_names, successive_feature_maps):
  
  if len(feature_map.shape) == 4:
    
    #-------------------------------------------
    n_features = feature_map.shape[-1]  # numero caracteristicas en el mapa de caracteristicas
    size       = feature_map.shape[ 1]  # forma del mapa de caracteristicas (1, tamaño, tmaño, n_caracteristicas)
    
    # se colaca las imágenes en mosaico en esta matriz.
    display_grid = np.zeros((size, size * n_features))
    
    #-------------------------------------------------
    # Procesamiento de la funcion
    #-------------------------------------------------
    for i in range(n_features):
      x  = feature_map[0, :, :, i]
      x -= x.mean()
      x /= x.std ()
      x *=  64
      x += 128
      x  = np.clip(x, 0, 255).astype('uint8')
      display_grid[:, i * size : (i + 1) * size] = x # Coloca en mosaico cada filtro en una cuadrícula horizontal

    #-----------------
    # mostrar la figura
    #-----------------

    scale = 20. / n_features
    plt.figure( figsize=(scale * n_features, scale) )
    plt.axis( 'off' )
    plt.title ( layer_name )
    plt.grid  ( False )
    plt.imshow( display_grid, aspect='auto',cmap='viridis')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-131-eac396309866> in <module>()
#      37
#      38 # Ejecutamos nuestra imagen a través de nuestra red, obteniendo así todas las representaciones intermedias para esta imagen.
# ---> 39 successive_feature_maps = visualization_model.predict(x1+x2+x3,batch_size=10)
#      40
#      41 # Estos son los nombres de las capas, por lo que podemos tenerlos como parte de nuestra trama.
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1627           for step in data_handler.steps():
#    1628             callbacks.on_predict_batch_begin(step)
# -> 1629             tmp_batch_outputs = self.predict_function(iterator)
#    1630             if data_handler.should_sync:
#    1631               context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     869       # This is the first call of __call__, so we have to initialize.
#     870       initializers = []
# --> 871       self._initialize(args, kwds, add_initializers_to=initializers)
#     872     finally:
#     873       # At this point we know that the initialization is complete (or less
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     724     self._concrete_stateful_fn = (
#     725         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
# --> 726             *args, **kwds))
#     727
#     728     def invalid_creator_scope(*unused_args, **unused_kwds):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    2967       args, kwargs = None, None
#    2968     with self._lock:
# -> 2969       graph_function, _ = self._maybe_define_function(args, kwargs)
#    2970     return graph_function
#    2971
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3359
#    3360           self._function_cache.missed.add(call_context_key)
# -> 3361           graph_function = self._create_graph_function(args, kwargs)
#    3362           self._function_cache.primary[cache_key] = graph_function
#    3363
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3204             arg_names=arg_names,
#    3205             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3206             capture_by_value=self._capture_by_value),
#    3207         self._function_attributes,
#    3208         function_spec=self.function_spec,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     988         _, original_func = tf_decorator.unwrap(python_func)
#     989
# --> 990       func_outputs = python_func(*func_args, **func_kwargs)
#     991
#     992       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     632             xla_context.Exit()
#     633         else:
# --> 634           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     635         return out
#     636
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     975           except Exception as e:  # pylint:disable=broad-except
#     976             if hasattr(e, "ag_error_metadata"):
# --> 977               raise e.ag_error_metadata.to_exception(e)
#     978             else:
#     979               raise
#
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1478 predict_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1468 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/distribute/distribute_lib.py:1259 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/distribute/distribute_lib.py:2730 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/distribute/distribute_lib.py:3417 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1461 run_step  **
#         outputs = model.predict_step(data)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1434 predict_step
#         return self(x, training=False)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/base_layer.py:998 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/input_spec.py:274 assert_input_compatibility
#         ', found shape=' + display_shape(x.shape))
#
#     ValueError: Input 0 is incompatible with layer model: expected shape=(None, 400, 400, 3), found shape=(None, 150, 150, 3)

# %% [markdown]
# Se puede observa la perdida y la exactitud, tanto en los datos de entreanmiento y los de perdida.

# %%
acc      = history.history[     'accuracy' ]
val_acc  = history.history[ 'val_accuracy' ]
loss     = history.history[    'loss' ]
val_loss = history.history['val_loss' ]

epochs   = range(len(acc)) # Get number of epochs

#------------------------------------------------
# Pplotear precicios del entranamiento y al valuidacion por epoca
#------------------------------------------------
parameters = {'xtick.labelsize': 23,
          'ytick.labelsize': 23}
plt.rcParams.update(parameters)
plt.figure(figsize=(13,7))
plt.plot  ( epochs,     acc, label='entrenamiento')
plt.plot  ( epochs, val_acc, label='Validacion' )
plt.title ('Training and validation accuracy (sin tecnicas)',fontsize=20)
plt.xlabel("Epoca",fontsize=16)                       # Configuramos la etiqueta del eje X
plt.ylabel("Exactitud",fontsize=16) 
plt.grid()
plt.legend(loc=2,fontsize=13)
plt.show()
#------------------------------------------------
# plotear perdida en el entranamiento y la validacion por epoca 
#------------------------------------------------
fig2=plt.figure(figsize=(13,7))
plt.plot  ( epochs,     loss, label='Entrenamiento' )
plt.plot  ( epochs, val_loss,label=  'validacion')
plt.title ('Training and validation loss '  ,fontsize=30 )
plt.title ('Training and validation loss '  ,fontsize=30 )
plt.xlabel("Epoca", fontsize=16)                       # Configuramos la etiqueta del eje X
plt.ylabel("Perdida",fontsize=16) 
plt.grid()
plt.legend(loc=2,fontsize=13)

# %%
acc      = history.history[     'accuracy' ]
val_acc  = history.history[ 'val_accuracy' ]
loss     = history.history[    'loss' ]
val_loss = history.history['val_loss' ]

epochs   = range(len(acc)) # Get number of epochs

#------------------------------------------------
# Pplotear precicios del entranamiento y al valuidacion por epoca
#------------------------------------------------
parameters = {'xtick.labelsize': 23,
          'ytick.labelsize': 23}
plt.rcParams.update(parameters)
plt.figure(figsize=(13,7))
plt.plot  ( epochs,     acc, label='entrenamiento')
plt.plot  ( epochs, val_acc, label='Validacion' )
plt.title ('Training and validation accuracy (sin tecnicas)',fontsize=20)
plt.xlabel("Epoca",fontsize=16)                       # Configuramos la etiqueta del eje X
plt.ylabel("Exactitud",fontsize=16) 
plt.grid()
plt.legend(loc=2,fontsize=13)
plt.show()
#------------------------------------------------
# plotear perdida en el entranamiento y la validacion por epoca 
#------------------------------------------------
fig2=plt.figure(figsize=(13,7))
plt.plot  ( epochs,     loss, label='Entrenamiento' )
plt.plot  ( epochs, val_loss,label=  'validacion')
plt.title ('Training and validation loss '  ,fontsize=30 )
plt.title ('Training and validation loss '  ,fontsize=30 )
plt.xlabel("Epoca", fontsize=16)                       # Configuramos la etiqueta del eje X
plt.ylabel("Perdida",fontsize=16) 
plt.grid()
plt.legend(loc=2,fontsize=13)

# %%
acc      = history.history[     'accuracy' ]
val_acc  = history.history[ 'val_accuracy' ]
loss     = history.history[    'loss' ]
val_loss = history.history['val_loss' ]

epochs   = range(len(acc)) # Get number of epochs

#------------------------------------------------
# Pplotear precicios del entranamiento y al valuidacion por epoca
#------------------------------------------------
parameters = {'xtick.labelsize': 23,
          'ytick.labelsize': 23}
plt.rcParams.update(parameters)
plt.figure(figsize=(13,7))
plt.plot  ( epochs,     acc, label='entrenamiento')
plt.plot  ( epochs, val_acc, label='Validacion' )
plt.title ('Training and validation accuracy (sin tecnicas)',fontsize=20)
plt.xlabel("Epoca",fontsize=16)                       # Configuramos la etiqueta del eje X
plt.ylabel("Exactitud",fontsize=16) 
plt.grid()
plt.legend(loc=2,fontsize=13)
plt.show()
#------------------------------------------------
# plotear perdida en el entranamiento y la validacion por epoca 
#------------------------------------------------
fig2=plt.figure(figsize=(13,7))
plt.plot  ( epochs,     loss, label='Entrenamiento' )
plt.plot  ( epochs, val_loss,label=  'validacion')
plt.title ('Training and validation loss '  ,fontsize=30 )
plt.title ('Training and validation loss '  ,fontsize=30 )
plt.xlabel("Epoca", fontsize=16)                       # Configuramos la etiqueta del eje X
plt.ylabel("Perdida",fontsize=16) 
plt.grid()
plt.legend(loc=2,fontsize=13)

# %%
from numpy import exp
 
# softmax activation function
def softmax(x):
	return exp(x) / exp(x).sum()
 
# define input data
inputs = [1.0, 3.0, 2.0]
print(exp(inputs))
print(exp(inputs).sum())
# calculate outputs
outputs = softmax(inputs)
# report the probabilities
print(outputs)
# report the sum of the probabilities
print(outputs.sum())
# Out:
# [ 2.71828183 20.08553692  7.3890561 ]
# 30.19287485057736
# [0.09003057 0.66524096 0.24472847]
# 1.0

# %% [markdown]
# Referencia:
#
# Auotores de Tensorflow: Course_2_Part_2_Lesson_2_Notebook
