# %% [markdown]
# Se importar los datos en formato .zip, y se extraen en la maquina virtual

# %%
import os
import zipfile

local_zip = 'Data_T2.zip'

zip_ref = zipfile.ZipFile(local_zip, 'r')

zip_ref.extractall('/tmp')
zip_ref.close()

# %% [markdown]
# Aqui se define, los directorios de donde se sacara la data de la imagen.

# %%
base_dir = '/tmp/Data_T2'


train_leo_dir = os.path.join(base_dir, 'Leopardo2')
train_lince_dir = os.path.join(base_dir, 'Lince iberico')
train_ocelote_dir = os.path.join(base_dir, 'Ocelote')
train_guepardo_dir = os.path.join(base_dir, 'Guepardo')
train_serval_dir = os.path.join(base_dir, 'Serval')

# %% [markdown]
# # Sección nueva

# %% [markdown]
# Aqui no mas se muestran el nombre de los archivos,

# %%
train_leo_fnames = os.listdir( train_leo_dir )
train_lince_fnames = os.listdir( train_lince_dir )
train_ocelote_fnames = os.listdir(train_ocelote_dir)
train_guepardo_fnames = os.listdir(train_guepardo_dir)
train_serval_fnames = os.listdir(train_serval_dir)

print(train_leo_fnames[:10])
print(train_lince_fnames[:10])
print(train_ocelote_fnames[:10])
print(train_guepardo_fnames[:10])
print(train_serval_fnames[:10])
# Out:
# ['leopardo (102).jpg', 'leopardo (18).jpg', 'leopardo (104).jpg', 'leopardo (128).jpg', 'leopardo (158).jpg', 'leopardo (161).jpg', 'leopardo (89).jpg', 'leopardo (79).jpg', 'leopardo (111).jpg', 'leopardo (43).jpg']
# ['lince1 (109).jpg', 'lince1 (70).jpg', 'lince1 (50).jpg', 'lince1 (2).jpg', 'lince1 (16).jpg', 'lince1 (9).jpg', 'lince1 (46).jpg', 'lince1 (77).jpg', 'lince1 (65).jpg', 'lince.jpg']
# ['Ocelote (66).jpg', 'Ocelote (79).jpg', 'Ocelote (155).jpg', 'Ocelote (153).jpg', 'Ocelote (7).jpg', 'Ocelote (73).jpg', 'Ocelote (154).jpg', 'Ocelote (56).jpg', 'Ocelote (147).jpg', 'Ocelote (43).jpg']
# ['Guepardo (172).jpg', 'Guepardo (193).jpg', 'guepardo (104).jpg', 'guepardo (35).jpg', 'guepardo (105).jpg', 'guepardo (82).jpg', 'guepardo (75).jpg', 'Guepardo (167).jpg', 'guepardo (74).jpg', 'Guepardo (189).jpg']
# ['serval (33).jpg', 'serval (127).jpg', 'serval (83).jpg', 'serval (98).jpg', 'serval (29).jpg', 'serval (24).jpg', 'serval (23).jpg', 'serval (117).jpg', 'serval (32).jpg', 'serval (93).jpg']

# %% [markdown]
# Aqui vemos el total de imagenes en que hay en los directorios de leopardos y linces.

# %%
print('total training leo images :', len(os.listdir(train_leo_dir ) ))
print('total training lince images :', len(os.listdir( train_lince_dir ) ))
print('total training ocelote images :', len(os.listdir( train_ocelote_dir ) ))
print('total training guepardo images :', len(os.listdir( train_guepardo_dir ) ))
print('total training serval images :', len(os.listdir( train_serval_dir ) ))
# Out:
# total training leo images : 189
# total training lince images : 188
# total training ocelote images : 192
# total training guepardo images : 194
# total training serval images : 195

# %% [markdown]
# las siguientes lineas de codigo son para enseñar una pequeña muestra de loas imagenes en los directorios.

# %%
# %matplotlib inline

import matplotlib.image as mpimg
import matplotlib.pyplot as plt


nrows = 20
ncols = 4

pic_index = 0

# %%
fig = plt.gcf()
fig.set_size_inches(ncols*4, nrows*4)

pic_index+=8

next_leo_pix = [os.path.join(train_leo_dir, fname) 
                for fname in train_leo_fnames[ pic_index-8:pic_index] 
               ]

next_lince_pix = [os.path.join(train_lince_dir, fname) 
                for fname in train_lince_fnames[ pic_index-8:pic_index]
               ]
next_ocelote_pix = [os.path.join(train_ocelote_dir, fname) 
                for fname in train_ocelote_fnames[ pic_index-8:pic_index]
               ]
next_guepardo_pix = [os.path.join(train_guepardo_dir, fname) 
                for fname in train_guepardo_fnames[ pic_index-8:pic_index]
               ]
next_serval_pix = [os.path.join(train_serval_dir, fname) 
                for fname in train_serval_fnames[ pic_index-8:pic_index]
               ]


for i, img_path in enumerate(next_leo_pix+next_lince_pix+next_ocelote_pix+next_guepardo_pix+next_serval_pix ):

  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') 

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Construyendo el Modelo

# %%
import tensorflow as tf

# %% [markdown]
# La siguiente secuencia de codigo es el "core" de nuestra red nueronal, donde estan definidas, las capas de convulucion, la densidad de la red entre otros parametros.

# %%
data_augmentation =tf.keras.Sequential(
    [
        
        tf.keras.layers.experimental.preprocessing.Resizing(height=400,width=400),
        tf.keras.layers.experimental.preprocessing.RandomFlip(mode='horizontal'),
        #tf.keras.layers.experimental.preprocessing.RandomRotation(factor=0.4),
        tf.keras.layers.experimental.preprocessing.RandomContrast(factor=0.8),
        #tf.keras.layers.experimental.preprocessing.RandomZoom(height_factor=0.4,width_factor=0.4)
    ]
)
initializer=tf.keras.initializers.RandomNormal(mean=0.3, stddev=1.)
model = tf.keras.models.Sequential([
    tf.keras.Input((400, 400, 3)),
    data_augmentation,
    tf.keras.layers.Conv2D(16, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2), 
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'), 
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(128,(3,3),activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(256,(3,3),activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(512,(3,3),activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(16,kernel_initializer=initializer,activation='relu'),
    tf.keras.layers.Dense(32,activation='relu'),
    #tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Dense(128,activation='relu'),
    #tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(256,activation='relu'),
    #tf.keras.layers.Dropout(0.6),
    tf.keras.layers.Dense(1024, activation='relu'), 
    tf.keras.layers.Dense(5, activation='softmax')  
])

# %% [markdown]
# aqui podemos ver la constidad de parametros en cada, "capa de la red",  y tambien se evidenca el decrecimiento de la imagen en cada cada capa

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_2 (Sequential)    (None, 400, 400, 3)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 398, 398, 16)      448
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 199, 199, 16)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 197, 197, 32)      4640
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 98, 98, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 96, 96, 64)        18496
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 48, 48, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 46, 46, 128)       73856
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 23, 23, 128)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 21, 21, 256)       295168
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 10, 10, 256)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 8, 8, 512)         1180160
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 16)                131088
# _________________________________________________________________
# dense_7 (Dense)              (None, 32)                544
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               4224
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_10 (Dense)             (None, 1024)              263168
# _________________________________________________________________
# dense_11 (Dense)             (None, 5)                 5125
# =================================================================
# Total params: 2,009,941
# Trainable params: 2,009,941
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Aqui se va definen las funciones de perdida y el optimizador, que ayudaran al modelo a aprender.

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import RMSprop

model.compile(optimizer=RMSprop(lr=0.0003,rho=0.92),
              loss='categorical_crossentropy',
              metrics = ['accuracy'])

# %% [markdown]
# Aqui se rescalan las imagenes, para que la red trabaje con valores entre 0 y 1, tambien crearemos un "split", que nos servira para la validacion de datos.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

#todas las imagenes sera resscaldad a 1/255
train_datagen = ImageDataGenerator( rescale = 1.0/255. ,validation_split=0.15)
# --------------------
# Imágenes de entrenamiento en lotes de 20 usando el generador train_datagen
# --------------------
train_generator = train_datagen.flow_from_directory(base_dir,
                                                    batch_size=80,
                                                    class_mode='categorical',
                                                    target_size=(400,400),
                                                    subset='training')     

# --------------------
# imagenes de validadcion en lotes de 5 usando el generador test_datagen generator
# --------------------

test_generator = train_datagen.flow_from_directory(base_dir,
                                                    batch_size=5,
                                                    class_mode='categorical',
                                                    target_size=(400, 400),
                                                    subset='validation')
# Out:
# Found 816 images belonging to 5 classes.
# Found 142 images belonging to 5 classes.

# %% [markdown]
# Por ultimo para entrenar la red, se le dieron 5 epocas, y se le especifico cuales era los datos de validacion y de entrenamiento.

# %%
#augmentation=data_augmetntation.compile(train_generator)
history = model.fit(train_generator,
                            validation_data=test_generator,
                            epochs=300,
                            verbose=1)
# Out:
# Epoch 1/300
# 11/11 [==============================] - 9s 717ms/step - loss: 2.1384 - accuracy: 0.1934 - val_loss: 1.6099 - val_accuracy: 0.2183
# Epoch 2/300
# 11/11 [==============================] - 8s 698ms/step - loss: 1.6093 - accuracy: 0.2284 - val_loss: 1.6074 - val_accuracy: 0.2042
# Epoch 3/300
# 11/11 [==============================] - 8s 706ms/step - loss: 1.6006 - accuracy: 0.2133 - val_loss: 1.5740 - val_accuracy: 0.3380
# Epoch 4/300
# 11/11 [==============================] - 8s 698ms/step - loss: 1.6112 - accuracy: 0.2491 - val_loss: 1.5805 - val_accuracy: 0.2535
# Epoch 5/300
# 11/11 [==============================] - 8s 700ms/step - loss: 1.5762 - accuracy: 0.2716 - val_loss: 2.0611 - val_accuracy: 0.2042
# Epoch 6/300
# 11/11 [==============================] - 8s 697ms/step - loss: 1.7565 - accuracy: 0.2778 - val_loss: 1.5757 - val_accuracy: 0.2324
# Epoch 7/300
# 11/11 [==============================] - 8s 698ms/step - loss: 1.5102 - accuracy: 0.3642 - val_loss: 1.5206 - val_accuracy: 0.2958
# Epoch 8/300
# 11/11 [==============================] - 8s 757ms/step - loss: 1.5438 - accuracy: 0.3193 - val_loss: 1.5579 - val_accuracy: 0.2535
# Epoch 9/300
# 11/11 [==============================] - 8s 698ms/step - loss: 1.5153 - accuracy: 0.3207 - val_loss: 1.5518 - val_accuracy: 0.3239
# Epoch 10/300
# 11/11 [==============================] - 8s 689ms/step - loss: 1.5490 - accuracy: 0.3402 - val_loss: 1.5211 - val_accuracy: 0.3028
# Epoch 11/300
# 11/11 [==============================] - 8s 692ms/step - loss: 1.5037 - accuracy: 0.3376 - val_loss: 1.5150 - val_accuracy: 0.3099
# Epoch 12/300
# 11/11 [==============================] - 8s 684ms/step - loss: 1.3846 - accuracy: 0.4122 - val_loss: 1.4626 - val_accuracy: 0.3380
# Epoch 13/300
# 11/11 [==============================] - 8s 689ms/step - loss: 1.4311 - accuracy: 0.3886 - val_loss: 1.4542 - val_accuracy: 0.3592
# Epoch 14/300
# 11/11 [==============================] - 8s 722ms/step - loss: 1.4463 - accuracy: 0.4133 - val_loss: 1.5147 - val_accuracy: 0.3521
# Epoch 15/300
# 11/11 [==============================] - 8s 699ms/step - loss: 1.3533 - accuracy: 0.4415 - val_loss: 1.4912 - val_accuracy: 0.3662
# Epoch 16/300
# 11/11 [==============================] - 8s 699ms/step - loss: 1.3351 - accuracy: 0.4461 - val_loss: 1.5533 - val_accuracy: 0.3662
# Epoch 17/300
# 11/11 [==============================] - 8s 698ms/step - loss: 1.5707 - accuracy: 0.3814 - val_loss: 1.4436 - val_accuracy: 0.4155
# Epoch 18/300
# 11/11 [==============================] - 8s 698ms/step - loss: 1.2972 - accuracy: 0.4730 - val_loss: 1.4259 - val_accuracy: 0.4155
# Epoch 19/300
# 11/11 [==============================] - 8s 711ms/step - loss: 1.2233 - accuracy: 0.4949 - val_loss: 2.0338 - val_accuracy: 0.2746
# Epoch 20/300
# 11/11 [==============================] - 8s 702ms/step - loss: 1.3416 - accuracy: 0.4429 - val_loss: 1.5024 - val_accuracy: 0.4014
# Epoch 21/300
# 11/11 [==============================] - 8s 703ms/step - loss: 1.3232 - accuracy: 0.4660 - val_loss: 1.3890 - val_accuracy: 0.4225
# Epoch 22/300
# 11/11 [==============================] - 8s 704ms/step - loss: 1.2160 - accuracy: 0.4920 - val_loss: 1.6322 - val_accuracy: 0.3380
# Epoch 23/300
# 11/11 [==============================] - 8s 705ms/step - loss: 1.4313 - accuracy: 0.3825 - val_loss: 1.4405 - val_accuracy: 0.3239
# Epoch 24/300
# 11/11 [==============================] - 8s 703ms/step - loss: 1.2672 - accuracy: 0.5104 - val_loss: 1.3331 - val_accuracy: 0.4577
# Epoch 25/300
# 11/11 [==============================] - 8s 761ms/step - loss: 1.3518 - accuracy: 0.4469 - val_loss: 1.3815 - val_accuracy: 0.4648
# Epoch 26/300
# 11/11 [==============================] - 8s 701ms/step - loss: 1.1697 - accuracy: 0.5292 - val_loss: 3.2017 - val_accuracy: 0.2042
# Epoch 27/300
# 11/11 [==============================] - 8s 714ms/step - loss: 1.8116 - accuracy: 0.3582 - val_loss: 1.3268 - val_accuracy: 0.4718
# Epoch 28/300
# 11/11 [==============================] - 8s 711ms/step - loss: 1.1285 - accuracy: 0.5618 - val_loss: 1.2898 - val_accuracy: 0.4930
# Epoch 29/300
# 11/11 [==============================] - 8s 711ms/step - loss: 1.1802 - accuracy: 0.5280 - val_loss: 1.6412 - val_accuracy: 0.3521
# Epoch 30/300
# 11/11 [==============================] - 8s 695ms/step - loss: 1.3424 - accuracy: 0.4476 - val_loss: 1.5896 - val_accuracy: 0.3169
# Epoch 31/300
# 11/11 [==============================] - 8s 713ms/step - loss: 1.2807 - accuracy: 0.5028 - val_loss: 1.5261 - val_accuracy: 0.3732
# Epoch 32/300
# 11/11 [==============================] - 8s 705ms/step - loss: 1.1515 - accuracy: 0.5269 - val_loss: 1.3231 - val_accuracy: 0.4366
# Epoch 33/300
# 11/11 [==============================] - 8s 709ms/step - loss: 1.0913 - accuracy: 0.5917 - val_loss: 1.2689 - val_accuracy: 0.5000
# Epoch 34/300
# 11/11 [==============================] - 8s 701ms/step - loss: 1.1195 - accuracy: 0.5487 - val_loss: 1.3346 - val_accuracy: 0.4577
# Epoch 35/300
# 11/11 [==============================] - 8s 701ms/step - loss: 1.1845 - accuracy: 0.5261 - val_loss: 1.8867 - val_accuracy: 0.3310
# Epoch 36/300
# 11/11 [==============================] - 8s 691ms/step - loss: 1.1698 - accuracy: 0.5586 - val_loss: 1.2874 - val_accuracy: 0.5000
# Epoch 37/300
# 11/11 [==============================] - 8s 708ms/step - loss: 1.0834 - accuracy: 0.5864 - val_loss: 1.3537 - val_accuracy: 0.5070
# Epoch 38/300
# 11/11 [==============================] - 8s 766ms/step - loss: 1.3629 - accuracy: 0.4356 - val_loss: 1.3174 - val_accuracy: 0.4789
# Epoch 39/300
# 11/11 [==============================] - 8s 697ms/step - loss: 0.9747 - accuracy: 0.6410 - val_loss: 1.3616 - val_accuracy: 0.4789
# Epoch 40/300
# 11/11 [==============================] - 8s 698ms/step - loss: 1.1015 - accuracy: 0.5612 - val_loss: 1.2969 - val_accuracy: 0.5282
# Epoch 41/300
# 11/11 [==============================] - 8s 704ms/step - loss: 0.9615 - accuracy: 0.6627 - val_loss: 1.5237 - val_accuracy: 0.4085
# Epoch 42/300
# 11/11 [==============================] - 8s 765ms/step - loss: 1.0827 - accuracy: 0.6039 - val_loss: 1.3266 - val_accuracy: 0.4507
# Epoch 43/300
# 11/11 [==============================] - 8s 706ms/step - loss: 0.9984 - accuracy: 0.6113 - val_loss: 1.3946 - val_accuracy: 0.4789
# Epoch 44/300
# 11/11 [==============================] - 8s 769ms/step - loss: 0.8735 - accuracy: 0.6690 - val_loss: 1.8957 - val_accuracy: 0.3451
# Epoch 45/300
# 11/11 [==============================] - 8s 708ms/step - loss: 1.0510 - accuracy: 0.6022 - val_loss: 1.5086 - val_accuracy: 0.5070
# Epoch 46/300
# 11/11 [==============================] - 8s 715ms/step - loss: 0.8973 - accuracy: 0.6707 - val_loss: 1.2954 - val_accuracy: 0.5352
# Epoch 47/300
# 11/11 [==============================] - 8s 703ms/step - loss: 0.8904 - accuracy: 0.7029 - val_loss: 1.5611 - val_accuracy: 0.3803
# Epoch 48/300
# 11/11 [==============================] - 8s 707ms/step - loss: 0.9965 - accuracy: 0.6031 - val_loss: 1.4947 - val_accuracy: 0.5563
# Epoch 49/300
# 11/11 [==============================] - 8s 706ms/step - loss: 0.9722 - accuracy: 0.6617 - val_loss: 1.3051 - val_accuracy: 0.5423
# Epoch 50/300
# 11/11 [==============================] - 8s 715ms/step - loss: 0.7608 - accuracy: 0.7320 - val_loss: 1.5601 - val_accuracy: 0.4225
# Epoch 51/300
# 11/11 [==============================] - 8s 703ms/step - loss: 0.7246 - accuracy: 0.7474 - val_loss: 1.3003 - val_accuracy: 0.5845
# Epoch 52/300
# 11/11 [==============================] - 8s 692ms/step - loss: 0.6634 - accuracy: 0.7489 - val_loss: 2.2038 - val_accuracy: 0.3521
# Epoch 53/300
# 11/11 [==============================] - 8s 706ms/step - loss: 1.1555 - accuracy: 0.5508 - val_loss: 1.5596 - val_accuracy: 0.4366
# Epoch 54/300
# 11/11 [==============================] - 8s 715ms/step - loss: 0.8289 - accuracy: 0.7116 - val_loss: 1.4254 - val_accuracy: 0.5423
# Epoch 55/300
# 11/11 [==============================] - 8s 788ms/step - loss: 0.9280 - accuracy: 0.6734 - val_loss: 1.3417 - val_accuracy: 0.5634
# Epoch 56/300
# 11/11 [==============================] - 8s 708ms/step - loss: 0.4593 - accuracy: 0.8503 - val_loss: 1.3575 - val_accuracy: 0.5423
# Epoch 57/300
# 11/11 [==============================] - 8s 698ms/step - loss: 0.7221 - accuracy: 0.7366 - val_loss: 1.3409 - val_accuracy: 0.5775
# Epoch 58/300
# 11/11 [==============================] - 8s 699ms/step - loss: 0.8043 - accuracy: 0.7368 - val_loss: 1.5900 - val_accuracy: 0.4296
# Epoch 59/300
# 11/11 [==============================] - 8s 710ms/step - loss: 0.8143 - accuracy: 0.7466 - val_loss: 1.2967 - val_accuracy: 0.6338
# Epoch 60/300
# 11/11 [==============================] - 8s 706ms/step - loss: 0.7121 - accuracy: 0.7398 - val_loss: 1.4094 - val_accuracy: 0.5845
# Epoch 61/300
# 11/11 [==============================] - 8s 714ms/step - loss: 0.4770 - accuracy: 0.8193 - val_loss: 1.6325 - val_accuracy: 0.5000
# Epoch 62/300
# 11/11 [==============================] - 8s 761ms/step - loss: 0.7904 - accuracy: 0.6912 - val_loss: 1.3444 - val_accuracy: 0.5423
# Epoch 63/300
# 11/11 [==============================] - 8s 698ms/step - loss: 0.6479 - accuracy: 0.7710 - val_loss: 1.5551 - val_accuracy: 0.5634
# Epoch 64/300
# 11/11 [==============================] - 8s 725ms/step - loss: 0.5343 - accuracy: 0.8311 - val_loss: 1.3435 - val_accuracy: 0.5423
# Epoch 65/300
# 11/11 [==============================] - 8s 707ms/step - loss: 0.3978 - accuracy: 0.8686 - val_loss: 1.6626 - val_accuracy: 0.5563
# Epoch 66/300
# 11/11 [==============================] - 8s 705ms/step - loss: 0.5466 - accuracy: 0.8075 - val_loss: 1.6193 - val_accuracy: 0.5704
# Epoch 67/300
# 11/11 [==============================] - 8s 704ms/step - loss: 0.3886 - accuracy: 0.8568 - val_loss: 1.6001 - val_accuracy: 0.5423
# Epoch 68/300
# 11/11 [==============================] - 8s 703ms/step - loss: 0.5942 - accuracy: 0.7876 - val_loss: 2.0678 - val_accuracy: 0.4225
# Epoch 69/300
# 11/11 [==============================] - 8s 699ms/step - loss: 0.4881 - accuracy: 0.8076 - val_loss: 1.6782 - val_accuracy: 0.5915
# Epoch 70/300
# 11/11 [==============================] - 8s 702ms/step - loss: 0.5328 - accuracy: 0.8111 - val_loss: 1.6796 - val_accuracy: 0.5634
# Epoch 71/300
# 11/11 [==============================] - 8s 706ms/step - loss: 0.5742 - accuracy: 0.8284 - val_loss: 1.4532 - val_accuracy: 0.5704
# Epoch 72/300
# 11/11 [==============================] - 8s 696ms/step - loss: 0.3593 - accuracy: 0.8782 - val_loss: 1.6391 - val_accuracy: 0.4930
# Epoch 73/300
# 11/11 [==============================] - 8s 702ms/step - loss: 0.4882 - accuracy: 0.8302 - val_loss: 2.1071 - val_accuracy: 0.5000
# Epoch 74/300
# 11/11 [==============================] - 8s 701ms/step - loss: 0.7285 - accuracy: 0.7900 - val_loss: 1.4590 - val_accuracy: 0.5704
# Epoch 75/300
# 11/11 [==============================] - 8s 709ms/step - loss: 0.2646 - accuracy: 0.9088 - val_loss: 1.7586 - val_accuracy: 0.5704
# Epoch 76/300
# 11/11 [==============================] - 8s 688ms/step - loss: 0.4337 - accuracy: 0.8436 - val_loss: 1.7435 - val_accuracy: 0.5634
# Epoch 77/300
# 11/11 [==============================] - 8s 706ms/step - loss: 0.2877 - accuracy: 0.9029 - val_loss: 3.2525 - val_accuracy: 0.4577
# Epoch 78/300
# 11/11 [==============================] - 8s 694ms/step - loss: 1.0383 - accuracy: 0.7318 - val_loss: 1.5134 - val_accuracy: 0.6268
# Epoch 79/300
# 11/11 [==============================] - 8s 705ms/step - loss: 0.1425 - accuracy: 0.9615 - val_loss: 1.7200 - val_accuracy: 0.5986
# Epoch 80/300
# 11/11 [==============================] - 8s 691ms/step - loss: 0.1167 - accuracy: 0.9637 - val_loss: 1.9151 - val_accuracy: 0.5986
# Epoch 81/300
# 11/11 [==============================] - 8s 703ms/step - loss: 1.0834 - accuracy: 0.7524 - val_loss: 1.3932 - val_accuracy: 0.6268
# Epoch 82/300
# 11/11 [==============================] - 8s 691ms/step - loss: 0.2934 - accuracy: 0.9089 - val_loss: 1.4993 - val_accuracy: 0.6408
# Epoch 83/300
# 11/11 [==============================] - 8s 685ms/step - loss: 0.1348 - accuracy: 0.9560 - val_loss: 2.5271 - val_accuracy: 0.4859
# Epoch 84/300
# 11/11 [==============================] - 8s 694ms/step - loss: 1.1018 - accuracy: 0.7651 - val_loss: 1.4560 - val_accuracy: 0.5775
# Epoch 85/300
# 11/11 [==============================] - 8s 762ms/step - loss: 0.1942 - accuracy: 0.9262 - val_loss: 1.6042 - val_accuracy: 0.6197
# Epoch 86/300
# 11/11 [==============================] - 8s 703ms/step - loss: 0.3282 - accuracy: 0.8837 - val_loss: 1.8901 - val_accuracy: 0.5845
# Epoch 87/300
# 11/11 [==============================] - 8s 706ms/step - loss: 0.2538 - accuracy: 0.9307 - val_loss: 2.8341 - val_accuracy: 0.4014
# Epoch 88/300
# 11/11 [==============================] - 8s 701ms/step - loss: 0.3542 - accuracy: 0.8979 - val_loss: 1.4809 - val_accuracy: 0.6056
# Epoch 89/300
# 11/11 [==============================] - 8s 702ms/step - loss: 0.1406 - accuracy: 0.9685 - val_loss: 1.8380 - val_accuracy: 0.5915
# Epoch 90/300
# 11/11 [==============================] - 8s 700ms/step - loss: 0.0450 - accuracy: 0.9870 - val_loss: 2.5890 - val_accuracy: 0.5915
# Epoch 91/300
# 11/11 [==============================] - 8s 699ms/step - loss: 0.3655 - accuracy: 0.8995 - val_loss: 2.5282 - val_accuracy: 0.5141
# Epoch 92/300
# 11/11 [==============================] - 8s 707ms/step - loss: 0.5361 - accuracy: 0.8651 - val_loss: 1.6645 - val_accuracy: 0.6056
# Epoch 93/300
# 11/11 [==============================] - 8s 700ms/step - loss: 0.0237 - accuracy: 0.9986 - val_loss: 2.1030 - val_accuracy: 0.5986
# Epoch 94/300
# 11/11 [==============================] - 8s 704ms/step - loss: 0.5555 - accuracy: 0.8257 - val_loss: 2.0022 - val_accuracy: 0.5563
# Epoch 95/300
# 11/11 [==============================] - 8s 698ms/step - loss: 0.1792 - accuracy: 0.9431 - val_loss: 1.8712 - val_accuracy: 0.6056
# Epoch 96/300
# 11/11 [==============================] - 8s 704ms/step - loss: 0.1798 - accuracy: 0.9479 - val_loss: 2.1318 - val_accuracy: 0.6056
# Epoch 97/300
# 11/11 [==============================] - 8s 695ms/step - loss: 0.1716 - accuracy: 0.9486 - val_loss: 3.2161 - val_accuracy: 0.4437
# Epoch 98/300
# 11/11 [==============================] - 8s 691ms/step - loss: 0.6950 - accuracy: 0.7690 - val_loss: 1.8573 - val_accuracy: 0.6338
# Epoch 99/300
# 11/11 [==============================] - 8s 703ms/step - loss: 0.0437 - accuracy: 0.9882 - val_loss: 1.9373 - val_accuracy: 0.6056
# Epoch 100/300
# 11/11 [==============================] - 8s 687ms/step - loss: 0.0072 - accuracy: 0.9995 - val_loss: 3.1263 - val_accuracy: 0.5070
# Epoch 101/300
# 11/11 [==============================] - 8s 700ms/step - loss: 1.1301 - accuracy: 0.7833 - val_loss: 2.0091 - val_accuracy: 0.5775
# Epoch 102/300
# 11/11 [==============================] - 8s 705ms/step - loss: 0.1762 - accuracy: 0.9461 - val_loss: 1.9888 - val_accuracy: 0.5704
# Epoch 103/300
# 11/11 [==============================] - 8s 762ms/step - loss: 0.0851 - accuracy: 0.9826 - val_loss: 2.0668 - val_accuracy: 0.6197
# Epoch 104/300
# 11/11 [==============================] - 8s 704ms/step - loss: 0.2186 - accuracy: 0.9430 - val_loss: 2.4711 - val_accuracy: 0.4507
# Epoch 105/300
# 11/11 [==============================] - 8s 699ms/step - loss: 0.3672 - accuracy: 0.9275 - val_loss: 1.8265 - val_accuracy: 0.5775
# Epoch 106/300
# 11/11 [==============================] - 8s 696ms/step - loss: 0.0723 - accuracy: 0.9809 - val_loss: 1.9231 - val_accuracy: 0.6056
# Epoch 107/300
# 11/11 [==============================] - 8s 701ms/step - loss: 0.0255 - accuracy: 0.9937 - val_loss: 3.3970 - val_accuracy: 0.4789
# Epoch 108/300
# 11/11 [==============================] - 8s 696ms/step - loss: 1.1429 - accuracy: 0.8327 - val_loss: 1.7014 - val_accuracy: 0.6620
# Epoch 109/300
# 11/11 [==============================] - 8s 698ms/step - loss: 0.2370 - accuracy: 0.9280 - val_loss: 2.0156 - val_accuracy: 0.6127
# Epoch 110/300
# 11/11 [==============================] - 8s 759ms/step - loss: 0.1214 - accuracy: 0.9556 - val_loss: 2.0237 - val_accuracy: 0.6127
# Epoch 111/300
# 11/11 [==============================] - 8s 767ms/step - loss: 0.0170 - accuracy: 0.9959 - val_loss: 3.1635 - val_accuracy: 0.5352
# Epoch 112/300
# 11/11 [==============================] - 8s 694ms/step - loss: 0.6031 - accuracy: 0.9240 - val_loss: 2.0344 - val_accuracy: 0.6127
# Epoch 113/300
# 11/11 [==============================] - 8s 690ms/step - loss: 0.0500 - accuracy: 0.9785 - val_loss: 2.3155 - val_accuracy: 0.5423
# Epoch 114/300
# 11/11 [==============================] - 8s 754ms/step - loss: 0.0366 - accuracy: 0.9907 - val_loss: 4.2066 - val_accuracy: 0.4437
# Epoch 115/300
# 11/11 [==============================] - 8s 683ms/step - loss: 0.8620 - accuracy: 0.7526 - val_loss: 2.7225 - val_accuracy: 0.4718
# Epoch 116/300
# 11/11 [==============================] - 8s 699ms/step - loss: 0.2118 - accuracy: 0.9514 - val_loss: 2.0664 - val_accuracy: 0.5845
# Epoch 117/300
# 11/11 [==============================] - 8s 703ms/step - loss: 0.0946 - accuracy: 0.9800 - val_loss: 5.3161 - val_accuracy: 0.3592
# Epoch 118/300
# 11/11 [==============================] - 8s 689ms/step - loss: 0.5604 - accuracy: 0.8436 - val_loss: 1.7543 - val_accuracy: 0.5986
# Epoch 119/300
# 11/11 [==============================] - 8s 754ms/step - loss: 0.0539 - accuracy: 0.9822 - val_loss: 1.9249 - val_accuracy: 0.6268
# Epoch 120/300
# 11/11 [==============================] - 8s 691ms/step - loss: 0.1138 - accuracy: 0.9708 - val_loss: 1.7824 - val_accuracy: 0.6549
# Epoch 121/300
# 11/11 [==============================] - 8s 693ms/step - loss: 0.1523 - accuracy: 0.9628 - val_loss: 4.2711 - val_accuracy: 0.3732
# Epoch 122/300
# 11/11 [==============================] - 8s 694ms/step - loss: 0.5163 - accuracy: 0.8805 - val_loss: 1.6601 - val_accuracy: 0.6338
# Epoch 123/300
# 11/11 [==============================] - 8s 693ms/step - loss: 0.0336 - accuracy: 0.9932 - val_loss: 2.6898 - val_accuracy: 0.4507
# Epoch 124/300
# 11/11 [==============================] - 8s 763ms/step - loss: 0.4691 - accuracy: 0.9067 - val_loss: 1.4112 - val_accuracy: 0.6268
# Epoch 125/300
# 11/11 [==============================] - 8s 691ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 1.4327 - val_accuracy: 0.6690
# Epoch 126/300
# 11/11 [==============================] - 8s 697ms/step - loss: 0.0126 - accuracy: 0.9990 - val_loss: 1.7139 - val_accuracy: 0.6549
# Epoch 127/300
# 11/11 [==============================] - 8s 696ms/step - loss: 0.0036 - accuracy: 0.9996 - val_loss: 2.2214 - val_accuracy: 0.5352
# Epoch 128/300
# 11/11 [==============================] - 8s 701ms/step - loss: 0.3753 - accuracy: 0.9505 - val_loss: 1.3934 - val_accuracy: 0.6056
# Epoch 129/300
# 11/11 [==============================] - 8s 699ms/step - loss: 0.0912 - accuracy: 0.9842 - val_loss: 1.5716 - val_accuracy: 0.6549
# Epoch 130/300
# 11/11 [==============================] - 8s 700ms/step - loss: 0.0803 - accuracy: 0.9879 - val_loss: 2.4932 - val_accuracy: 0.4507
# Epoch 131/300
# 11/11 [==============================] - 8s 674ms/step - loss: 0.2791 - accuracy: 0.9121 - val_loss: 2.0756 - val_accuracy: 0.5986
# Epoch 132/300
# 11/11 [==============================] - 8s 709ms/step - loss: 0.2850 - accuracy: 0.9012 - val_loss: 2.0215 - val_accuracy: 0.6197
# Epoch 133/300
# 11/11 [==============================] - 8s 699ms/step - loss: 0.0705 - accuracy: 0.9744 - val_loss: 4.4755 - val_accuracy: 0.4437
# Epoch 134/300
# 11/11 [==============================] - 8s 699ms/step - loss: 0.7412 - accuracy: 0.7954 - val_loss: 1.6278 - val_accuracy: 0.6338
# Epoch 135/300
# 11/11 [==============================] - 8s 694ms/step - loss: 0.1409 - accuracy: 0.9560 - val_loss: 1.6211 - val_accuracy: 0.6197
# Epoch 136/300
# 11/11 [==============================] - 8s 702ms/step - loss: 0.0073 - accuracy: 0.9965 - val_loss: 1.6453 - val_accuracy: 0.6408
# Epoch 137/300
# 11/11 [==============================] - 8s 707ms/step - loss: 0.1629 - accuracy: 0.9690 - val_loss: 2.9723 - val_accuracy: 0.4648
# Epoch 138/300
# 11/11 [==============================] - 8s 702ms/step - loss: 0.5104 - accuracy: 0.8960 - val_loss: 1.6069 - val_accuracy: 0.6408
# Epoch 139/300
# 11/11 [==============================] - 8s 697ms/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 1.6568 - val_accuracy: 0.6268
# Epoch 140/300
# 11/11 [==============================] - 8s 700ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 1.7296 - val_accuracy: 0.6268
# Epoch 141/300
# 11/11 [==============================] - 8s 704ms/step - loss: 0.0340 - accuracy: 0.9864 - val_loss: 1.7078 - val_accuracy: 0.6479
# Epoch 142/300
# 11/11 [==============================] - 8s 699ms/step - loss: 0.4835 - accuracy: 0.8917 - val_loss: 1.4389 - val_accuracy: 0.6761
# Epoch 143/300
# 11/11 [==============================] - 8s 753ms/step - loss: 0.1526 - accuracy: 0.9519 - val_loss: 1.5728 - val_accuracy: 0.6620
# Epoch 144/300
# 11/11 [==============================] - 8s 694ms/step - loss: 0.0233 - accuracy: 0.9965 - val_loss: 2.0824 - val_accuracy: 0.5845
# Epoch 145/300
# 11/11 [==============================] - 8s 702ms/step - loss: 0.0184 - accuracy: 0.9930 - val_loss: 1.9823 - val_accuracy: 0.6479
# Epoch 146/300
# 11/11 [==============================] - 8s 708ms/step - loss: 0.6010 - accuracy: 0.9135 - val_loss: 1.4631 - val_accuracy: 0.5986
# Epoch 147/300
# 11/11 [==============================] - 8s 706ms/step - loss: 0.1851 - accuracy: 0.9441 - val_loss: 1.5275 - val_accuracy: 0.6761
# Epoch 148/300
# 11/11 [==============================] - 8s 706ms/step - loss: 0.0589 - accuracy: 0.9842 - val_loss: 1.8368 - val_accuracy: 0.6338
# Epoch 149/300
# 11/11 [==============================] - 8s 707ms/step - loss: 0.0884 - accuracy: 0.9719 - val_loss: 2.5203 - val_accuracy: 0.5986
# Epoch 150/300
# 11/11 [==============================] - 8s 700ms/step - loss: 0.1538 - accuracy: 0.9511 - val_loss: 2.6651 - val_accuracy: 0.5423
# Epoch 151/300
# 11/11 [==============================] - 8s 702ms/step - loss: 0.1611 - accuracy: 0.9415 - val_loss: 2.2490 - val_accuracy: 0.6268
# Epoch 152/300
# 11/11 [==============================] - 8s 698ms/step - loss: 0.1945 - accuracy: 0.9490 - val_loss: 2.1613 - val_accuracy: 0.5845
# Epoch 153/300
# 11/11 [==============================] - 8s 699ms/step - loss: 0.1117 - accuracy: 0.9734 - val_loss: 2.1420 - val_accuracy: 0.6338
# Epoch 154/300
# 11/11 [==============================] - 8s 691ms/step - loss: 0.0878 - accuracy: 0.9613 - val_loss: 2.1722 - val_accuracy: 0.6338
# Epoch 155/300
# 11/11 [==============================] - 8s 692ms/step - loss: 0.0044 - accuracy: 0.9991 - val_loss: 2.3752 - val_accuracy: 0.6338
# Epoch 156/300
# 11/11 [==============================] - 8s 712ms/step - loss: 0.0018 - accuracy: 0.9992 - val_loss: 2.6190 - val_accuracy: 0.6268
# Epoch 157/300
# 11/11 [==============================] - 8s 705ms/step - loss: 0.6534 - accuracy: 0.9056 - val_loss: 1.6744 - val_accuracy: 0.5986
# Epoch 158/300
# 11/11 [==============================] - 8s 705ms/step - loss: 0.0609 - accuracy: 0.9850 - val_loss: 1.8191 - val_accuracy: 0.6479
# Epoch 159/300
# 11/11 [==============================] - 8s 706ms/step - loss: 0.0867 - accuracy: 0.9696 - val_loss: 1.9890 - val_accuracy: 0.6620
# Epoch 160/300
# 11/11 [==============================] - 8s 708ms/step - loss: 0.0427 - accuracy: 0.9929 - val_loss: 2.2104 - val_accuracy: 0.6479
# Epoch 161/300
# 11/11 [==============================] - 8s 767ms/step - loss: 0.0576 - accuracy: 0.9814 - val_loss: 2.6815 - val_accuracy: 0.5845
# Epoch 162/300
# 11/11 [==============================] - 8s 718ms/step - loss: 0.0759 - accuracy: 0.9751 - val_loss: 2.1408 - val_accuracy: 0.6479
# Epoch 163/300
# 11/11 [==============================] - 8s 715ms/step - loss: 0.0836 - accuracy: 0.9715 - val_loss: 2.3041 - val_accuracy: 0.6197
# Epoch 164/300
# 11/11 [==============================] - 8s 708ms/step - loss: 0.2909 - accuracy: 0.9214 - val_loss: 2.1519 - val_accuracy: 0.6127
# Epoch 165/300
# 11/11 [==============================] - 8s 692ms/step - loss: 0.0249 - accuracy: 0.9927 - val_loss: 1.9388 - val_accuracy: 0.6620
# Epoch 166/300
# 11/11 [==============================] - 8s 701ms/step - loss: 0.3629 - accuracy: 0.8975 - val_loss: 2.1398 - val_accuracy: 0.6338
# Epoch 167/300
# 11/11 [==============================] - 8s 696ms/step - loss: 0.0092 - accuracy: 0.9989 - val_loss: 2.3682 - val_accuracy: 0.6338
# Epoch 168/300
# 11/11 [==============================] - 8s 761ms/step - loss: 0.0145 - accuracy: 0.9969 - val_loss: 4.1551 - val_accuracy: 0.5211
# Epoch 169/300
# 11/11 [==============================] - 8s 768ms/step - loss: 0.5629 - accuracy: 0.8732 - val_loss: 1.6649 - val_accuracy: 0.6620
# Epoch 170/300
# 11/11 [==============================] - 8s 698ms/step - loss: 0.0710 - accuracy: 0.9790 - val_loss: 2.3949 - val_accuracy: 0.6408
# Epoch 171/300
# 11/11 [==============================] - 8s 698ms/step - loss: 0.0875 - accuracy: 0.9668 - val_loss: 2.5278 - val_accuracy: 0.6408
# Epoch 172/300
# 11/11 [==============================] - 8s 691ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 2.5033 - val_accuracy: 0.6549
# Epoch 173/300
# 11/11 [==============================] - 8s 757ms/step - loss: 0.1089 - accuracy: 0.9873 - val_loss: 6.0273 - val_accuracy: 0.4085
# Epoch 174/300
# 11/11 [==============================] - 8s 701ms/step - loss: 1.1941 - accuracy: 0.8040 - val_loss: 2.1040 - val_accuracy: 0.5634
# Epoch 175/300
# 11/11 [==============================] - 8s 701ms/step - loss: 0.0248 - accuracy: 0.9956 - val_loss: 2.1445 - val_accuracy: 0.5986
# Epoch 176/300
# 11/11 [==============================] - 8s 700ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 2.5540 - val_accuracy: 0.5704
# Epoch 177/300
# 11/11 [==============================] - 8s 694ms/step - loss: 0.0072 - accuracy: 0.9974 - val_loss: 3.2465 - val_accuracy: 0.5282
# Epoch 178/300
# 11/11 [==============================] - 8s 701ms/step - loss: 0.4041 - accuracy: 0.9018 - val_loss: 2.8053 - val_accuracy: 0.4225
# Epoch 179/300
# 11/11 [==============================] - 8s 706ms/step - loss: 0.3121 - accuracy: 0.8986 - val_loss: 1.5620 - val_accuracy: 0.6268
# Epoch 180/300
# 11/11 [==============================] - 8s 761ms/step - loss: 0.0446 - accuracy: 0.9951 - val_loss: 1.8163 - val_accuracy: 0.6127
# Epoch 181/300
# 11/11 [==============================] - 8s 685ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 2.4633 - val_accuracy: 0.6268
# Epoch 182/300
# 11/11 [==============================] - 8s 698ms/step - loss: 0.0653 - accuracy: 0.9858 - val_loss: 2.2029 - val_accuracy: 0.5845
# Epoch 183/300
# 11/11 [==============================] - 8s 700ms/step - loss: 0.2816 - accuracy: 0.9137 - val_loss: 1.8867 - val_accuracy: 0.5845
# Epoch 184/300
# 11/11 [==============================] - 8s 711ms/step - loss: 0.0472 - accuracy: 0.9818 - val_loss: 1.9884 - val_accuracy: 0.6338
# Epoch 185/300
# 11/11 [==============================] - 8s 703ms/step - loss: 0.0327 - accuracy: 0.9948 - val_loss: 4.5249 - val_accuracy: 0.4437
# Epoch 186/300
# 11/11 [==============================] - 8s 696ms/step - loss: 0.4109 - accuracy: 0.9079 - val_loss: 2.0392 - val_accuracy: 0.6338
# Epoch 187/300
# 11/11 [==============================] - 8s 702ms/step - loss: 0.0324 - accuracy: 0.9927 - val_loss: 2.0218 - val_accuracy: 0.6338
# Epoch 188/300
# 11/11 [==============================] - 8s 698ms/step - loss: 0.0054 - accuracy: 0.9983 - val_loss: 2.5500 - val_accuracy: 0.6056
# Epoch 189/300
# 11/11 [==============================] - 8s 709ms/step - loss: 8.4609e-04 - accuracy: 1.0000 - val_loss: 2.4725 - val_accuracy: 0.6338
# Epoch 190/300
# 11/11 [==============================] - 8s 706ms/step - loss: 0.5087 - accuracy: 0.9269 - val_loss: 1.6481 - val_accuracy: 0.5775
# Epoch 191/300
# 11/11 [==============================] - 8s 699ms/step - loss: 0.0517 - accuracy: 0.9814 - val_loss: 1.7483 - val_accuracy: 0.6197
# Epoch 192/300
# 11/11 [==============================] - 8s 705ms/step - loss: 0.0183 - accuracy: 0.9937 - val_loss: 2.3419 - val_accuracy: 0.6408
# Epoch 193/300
# 11/11 [==============================] - 8s 702ms/step - loss: 0.0105 - accuracy: 0.9973 - val_loss: 2.3524 - val_accuracy: 0.5986
# Epoch 194/300
# 11/11 [==============================] - 8s 715ms/step - loss: 0.6838 - accuracy: 0.8088 - val_loss: 1.7982 - val_accuracy: 0.5775
# Epoch 195/300
# 11/11 [==============================] - 8s 715ms/step - loss: 0.0271 - accuracy: 0.9973 - val_loss: 2.0876 - val_accuracy: 0.5986
# Epoch 196/300
# 11/11 [==============================] - 8s 704ms/step - loss: 0.0072 - accuracy: 0.9982 - val_loss: 2.2072 - val_accuracy: 0.5986
# Epoch 197/300
# 11/11 [==============================] - 8s 770ms/step - loss: 0.0148 - accuracy: 0.9971 - val_loss: 2.4704 - val_accuracy: 0.6127
# Epoch 198/300
# 11/11 [==============================] - 8s 711ms/step - loss: 8.0110e-04 - accuracy: 1.0000 - val_loss: 2.4530 - val_accuracy: 0.6127
# Epoch 199/300
# 11/11 [==============================] - 8s 764ms/step - loss: 0.0103 - accuracy: 0.9992 - val_loss: 3.9974 - val_accuracy: 0.4648
# Epoch 200/300
# 11/11 [==============================] - 8s 706ms/step - loss: 1.6348 - accuracy: 0.7506 - val_loss: 1.8558 - val_accuracy: 0.5563
# Epoch 201/300
# 11/11 [==============================] - 8s 702ms/step - loss: 0.0123 - accuracy: 0.9989 - val_loss: 1.8846 - val_accuracy: 0.6056
# Epoch 202/300
# 11/11 [==============================] - 8s 713ms/step - loss: 0.0322 - accuracy: 0.9965 - val_loss: 1.9845 - val_accuracy: 0.6127
# Epoch 203/300
# 11/11 [==============================] - 8s 697ms/step - loss: 0.0218 - accuracy: 0.9962 - val_loss: 2.5261 - val_accuracy: 0.6127
# Epoch 204/300
# 11/11 [==============================] - 8s 701ms/step - loss: 0.0230 - accuracy: 0.9966 - val_loss: 2.8023 - val_accuracy: 0.5845
# Epoch 205/300
# 11/11 [==============================] - 8s 712ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 2.7162 - val_accuracy: 0.6268
# Epoch 206/300
# 11/11 [==============================] - 8s 704ms/step - loss: 0.6792 - accuracy: 0.8458 - val_loss: 1.7556 - val_accuracy: 0.6056
# Epoch 207/300
# 11/11 [==============================] - 8s 705ms/step - loss: 0.0867 - accuracy: 0.9758 - val_loss: 1.9108 - val_accuracy: 0.6056
# Epoch 208/300
# 11/11 [==============================] - 8s 713ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 1.9430 - val_accuracy: 0.6197
# Epoch 209/300
# 11/11 [==============================] - 8s 733ms/step - loss: 0.0055 - accuracy: 0.9996 - val_loss: 2.1497 - val_accuracy: 0.5775
# Epoch 210/300
# 11/11 [==============================] - 8s 715ms/step - loss: 0.0836 - accuracy: 0.9824 - val_loss: 2.9769 - val_accuracy: 0.4718
# Epoch 211/300
# 11/11 [==============================] - 8s 698ms/step - loss: 0.1095 - accuracy: 0.9679 - val_loss: 1.9321 - val_accuracy: 0.5986
# Epoch 212/300
# 11/11 [==============================] - 8s 710ms/step - loss: 0.0062 - accuracy: 0.9991 - val_loss: 2.0821 - val_accuracy: 0.6268
# Epoch 213/300
# 11/11 [==============================] - 8s 702ms/step - loss: 0.0028 - accuracy: 0.9990 - val_loss: 3.9476 - val_accuracy: 0.5000
# Epoch 214/300
# 11/11 [==============================] - 8s 704ms/step - loss: 0.2109 - accuracy: 0.9430 - val_loss: 3.6243 - val_accuracy: 0.4155
# Epoch 215/300
# 11/11 [==============================] - 8s 700ms/step - loss: 0.2747 - accuracy: 0.9005 - val_loss: 1.6699 - val_accuracy: 0.6268
# Epoch 216/300
# 11/11 [==============================] - 8s 707ms/step - loss: 0.0389 - accuracy: 0.9876 - val_loss: 2.2659 - val_accuracy: 0.6127
# Epoch 217/300
# 11/11 [==============================] - 8s 701ms/step - loss: 0.0119 - accuracy: 0.9959 - val_loss: 2.3333 - val_accuracy: 0.6479
# Epoch 218/300
# 11/11 [==============================] - 8s 709ms/step - loss: 0.0343 - accuracy: 0.9885 - val_loss: 5.0034 - val_accuracy: 0.5000
# Epoch 219/300
# 11/11 [==============================] - 8s 702ms/step - loss: 0.2496 - accuracy: 0.9293 - val_loss: 2.1128 - val_accuracy: 0.6690
# Epoch 220/300
# 11/11 [==============================] - 8s 708ms/step - loss: 0.0028 - accuracy: 0.9994 - val_loss: 3.8895 - val_accuracy: 0.5211
# Epoch 221/300
# 11/11 [==============================] - 8s 700ms/step - loss: 0.3134 - accuracy: 0.9112 - val_loss: 1.8995 - val_accuracy: 0.6549
# Epoch 222/300
# 11/11 [==============================] - 8s 709ms/step - loss: 0.0391 - accuracy: 0.9941 - val_loss: 2.5508 - val_accuracy: 0.5704
# Epoch 223/300
# 11/11 [==============================] - 8s 712ms/step - loss: 0.0535 - accuracy: 0.9842 - val_loss: 2.1759 - val_accuracy: 0.6127
# Epoch 224/300
# 11/11 [==============================] - 8s 710ms/step - loss: 0.0760 - accuracy: 0.9831 - val_loss: 2.8500 - val_accuracy: 0.5915
# Epoch 225/300
# 11/11 [==============================] - 8s 707ms/step - loss: 0.0297 - accuracy: 0.9912 - val_loss: 2.4059 - val_accuracy: 0.6056
# Epoch 226/300
# 11/11 [==============================] - 8s 707ms/step - loss: 0.0074 - accuracy: 0.9969 - val_loss: 2.8952 - val_accuracy: 0.5915
# Epoch 227/300
# 11/11 [==============================] - 8s 714ms/step - loss: 0.0442 - accuracy: 0.9858 - val_loss: 4.1615 - val_accuracy: 0.5493
# Epoch 228/300
# 11/11 [==============================] - 8s 715ms/step - loss: 0.0576 - accuracy: 0.9810 - val_loss: 4.1342 - val_accuracy: 0.5704
# Epoch 229/300
# 11/11 [==============================] - 8s 711ms/step - loss: 0.1709 - accuracy: 0.9484 - val_loss: 2.2982 - val_accuracy: 0.6268
# Epoch 230/300
# 11/11 [==============================] - 8s 694ms/step - loss: 0.0206 - accuracy: 0.9974 - val_loss: 2.6807 - val_accuracy: 0.6197
# Epoch 231/300
# 11/11 [==============================] - 8s 694ms/step - loss: 0.0523 - accuracy: 0.9895 - val_loss: 2.0585 - val_accuracy: 0.6831
# Epoch 232/300
# 11/11 [==============================] - 8s 702ms/step - loss: 0.0090 - accuracy: 0.9982 - val_loss: 2.1345 - val_accuracy: 0.6408
# Epoch 233/300
# 11/11 [==============================] - 8s 701ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 2.3103 - val_accuracy: 0.6408
# Epoch 234/300
# 11/11 [==============================] - 8s 700ms/step - loss: 0.1409 - accuracy: 0.9747 - val_loss: 2.2336 - val_accuracy: 0.4789
# Epoch 235/300
# 11/11 [==============================] - 8s 712ms/step - loss: 0.0480 - accuracy: 0.9874 - val_loss: 1.7339 - val_accuracy: 0.5915
# Epoch 236/300
# 11/11 [==============================] - 8s 778ms/step - loss: 0.0038 - accuracy: 0.9997 - val_loss: 2.0551 - val_accuracy: 0.6338
# Epoch 237/300
# 11/11 [==============================] - 8s 765ms/step - loss: 0.0318 - accuracy: 0.9927 - val_loss: 2.6372 - val_accuracy: 0.6761
# Epoch 238/300
# 11/11 [==============================] - 8s 709ms/step - loss: 0.6970 - accuracy: 0.9019 - val_loss: 2.0334 - val_accuracy: 0.6127
# Epoch 239/300
# 11/11 [==============================] - 8s 710ms/step - loss: 0.0038 - accuracy: 0.9992 - val_loss: 2.0047 - val_accuracy: 0.6127
# Epoch 240/300
# 11/11 [==============================] - 8s 705ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 2.1067 - val_accuracy: 0.6549
# Epoch 241/300
# 11/11 [==============================] - 8s 701ms/step - loss: 0.0508 - accuracy: 0.9854 - val_loss: 2.6655 - val_accuracy: 0.5915
# Epoch 242/300
# 11/11 [==============================] - 8s 765ms/step - loss: 0.0475 - accuracy: 0.9837 - val_loss: 2.3041 - val_accuracy: 0.6338
# Epoch 243/300
# 11/11 [==============================] - 8s 695ms/step - loss: 0.0053 - accuracy: 0.9981 - val_loss: 3.3833 - val_accuracy: 0.5493
# Epoch 244/300
# 11/11 [==============================] - 8s 700ms/step - loss: 0.2320 - accuracy: 0.9344 - val_loss: 3.3072 - val_accuracy: 0.4930
# Epoch 245/300
# 11/11 [==============================] - 8s 705ms/step - loss: 0.0640 - accuracy: 0.9761 - val_loss: 2.2639 - val_accuracy: 0.6268
# Epoch 246/300
# 11/11 [==============================] - 8s 718ms/step - loss: 0.0030 - accuracy: 0.9980 - val_loss: 2.3291 - val_accuracy: 0.5915
# Epoch 247/300
# 11/11 [==============================] - 8s 701ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 2.6971 - val_accuracy: 0.6268
# Epoch 248/300
# 11/11 [==============================] - 8s 766ms/step - loss: 0.4019 - accuracy: 0.9270 - val_loss: 1.9489 - val_accuracy: 0.5915
# Epoch 249/300
# 11/11 [==============================] - 8s 702ms/step - loss: 0.0265 - accuracy: 0.9962 - val_loss: 2.0634 - val_accuracy: 0.6197
# Epoch 250/300
# 11/11 [==============================] - 8s 698ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 2.2541 - val_accuracy: 0.6056
# Epoch 251/300
# 11/11 [==============================] - 8s 710ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 2.6302 - val_accuracy: 0.6197
# Epoch 252/300
# 11/11 [==============================] - 8s 700ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 3.4027 - val_accuracy: 0.5493
# Epoch 253/300
# 11/11 [==============================] - 8s 708ms/step - loss: 0.6708 - accuracy: 0.8199 - val_loss: 1.9361 - val_accuracy: 0.6408
# Epoch 254/300
# 11/11 [==============================] - 8s 715ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 2.2400 - val_accuracy: 0.5986
# Epoch 255/300
# 11/11 [==============================] - 8s 700ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 2.1465 - val_accuracy: 0.6549
# Epoch 256/300
# 11/11 [==============================] - 8s 713ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 2.6067 - val_accuracy: 0.6408
# Epoch 257/300
# 11/11 [==============================] - 8s 703ms/step - loss: 0.6423 - accuracy: 0.9068 - val_loss: 2.0199 - val_accuracy: 0.5775
# Epoch 258/300
# 11/11 [==============================] - 8s 708ms/step - loss: 0.0218 - accuracy: 0.9901 - val_loss: 1.7825 - val_accuracy: 0.6197
# Epoch 259/300
# 11/11 [==============================] - 8s 711ms/step - loss: 0.0233 - accuracy: 0.9949 - val_loss: 2.3434 - val_accuracy: 0.6127
# Epoch 260/300
# 11/11 [==============================] - 8s 717ms/step - loss: 0.0053 - accuracy: 0.9987 - val_loss: 2.3704 - val_accuracy: 0.6197
# Epoch 261/300
# 11/11 [==============================] - 8s 715ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 2.7610 - val_accuracy: 0.6197
# Epoch 262/300
# 11/11 [==============================] - 8s 707ms/step - loss: 2.2462e-05 - accuracy: 1.0000 - val_loss: 2.7807 - val_accuracy: 0.6268
# Epoch 263/300
# 11/11 [==============================] - 8s 768ms/step - loss: 8.9738e-04 - accuracy: 1.0000 - val_loss: 3.4127 - val_accuracy: 0.6268
# Epoch 264/300
# 11/11 [==============================] - 8s 697ms/step - loss: 2.6370e-04 - accuracy: 1.0000 - val_loss: 3.5438 - val_accuracy: 0.6056
# Epoch 265/300
# 11/11 [==============================] - 8s 701ms/step - loss: 9.6183e-05 - accuracy: 1.0000 - val_loss: 3.4808 - val_accuracy: 0.6197
# Epoch 266/300
# 11/11 [==============================] - 8s 702ms/step - loss: 3.6151e-05 - accuracy: 1.0000 - val_loss: 5.1293 - val_accuracy: 0.5915
# Epoch 267/300
# 11/11 [==============================] - 8s 708ms/step - loss: 0.7120 - accuracy: 0.8988 - val_loss: 1.8964 - val_accuracy: 0.6761
# Epoch 268/300
# 11/11 [==============================] - 8s 707ms/step - loss: 0.0041 - accuracy: 0.9998 - val_loss: 1.8872 - val_accuracy: 0.6620
# Epoch 269/300
# 11/11 [==============================] - 8s 711ms/step - loss: 9.0779e-04 - accuracy: 1.0000 - val_loss: 1.9564 - val_accuracy: 0.6620
# Epoch 270/300
# 11/11 [==============================] - 8s 705ms/step - loss: 9.4451e-04 - accuracy: 1.0000 - val_loss: 2.1797 - val_accuracy: 0.6549
# Epoch 271/300
# 11/11 [==============================] - 8s 703ms/step - loss: 0.6353 - accuracy: 0.8766 - val_loss: 1.8425 - val_accuracy: 0.6620
# Epoch 272/300
# 11/11 [==============================] - 8s 701ms/step - loss: 0.0227 - accuracy: 0.9935 - val_loss: 2.3362 - val_accuracy: 0.6338
# Epoch 273/300
# 11/11 [==============================] - 8s 693ms/step - loss: 0.0661 - accuracy: 0.9840 - val_loss: 3.6733 - val_accuracy: 0.5211
# Epoch 274/300
# 11/11 [==============================] - 8s 716ms/step - loss: 0.1119 - accuracy: 0.9727 - val_loss: 2.0427 - val_accuracy: 0.6197
# Epoch 275/300
# 11/11 [==============================] - 8s 711ms/step - loss: 0.0188 - accuracy: 0.9927 - val_loss: 2.1248 - val_accuracy: 0.6056
# Epoch 276/300
# 11/11 [==============================] - 8s 718ms/step - loss: 0.0051 - accuracy: 0.9992 - val_loss: 2.6253 - val_accuracy: 0.5986
# Epoch 277/300
# 11/11 [==============================] - 8s 715ms/step - loss: 0.1220 - accuracy: 0.9682 - val_loss: 2.4414 - val_accuracy: 0.6268
# Epoch 278/300
# 11/11 [==============================] - 8s 773ms/step - loss: 0.0643 - accuracy: 0.9832 - val_loss: 2.2069 - val_accuracy: 0.6690
# Epoch 279/300
# 11/11 [==============================] - 8s 699ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 2.4462 - val_accuracy: 0.6197
# Epoch 280/300
# 11/11 [==============================] - 8s 694ms/step - loss: 0.0780 - accuracy: 0.9807 - val_loss: 5.9989 - val_accuracy: 0.4085
# Epoch 281/300
# 11/11 [==============================] - 8s 699ms/step - loss: 0.8947 - accuracy: 0.8283 - val_loss: 2.0650 - val_accuracy: 0.5845
# Epoch 282/300
# 11/11 [==============================] - 8s 712ms/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 2.3418 - val_accuracy: 0.5845
# Epoch 283/300
# 11/11 [==============================] - 8s 702ms/step - loss: 0.0079 - accuracy: 0.9958 - val_loss: 2.5968 - val_accuracy: 0.6268
# Epoch 284/300
# 11/11 [==============================] - 8s 692ms/step - loss: 0.1576 - accuracy: 0.9431 - val_loss: 2.6335 - val_accuracy: 0.5563
# Epoch 285/300
# 11/11 [==============================] - 8s 709ms/step - loss: 0.0160 - accuracy: 0.9972 - val_loss: 2.3715 - val_accuracy: 0.6127
# Epoch 286/300
# 11/11 [==============================] - 8s 717ms/step - loss: 0.0245 - accuracy: 0.9936 - val_loss: 2.9026 - val_accuracy: 0.6056
# Epoch 287/300
# 11/11 [==============================] - 8s 717ms/step - loss: 0.0317 - accuracy: 0.9889 - val_loss: 2.7920 - val_accuracy: 0.6549
# Epoch 288/300
# 11/11 [==============================] - 8s 776ms/step - loss: 0.0039 - accuracy: 0.9980 - val_loss: 3.0086 - val_accuracy: 0.6549
# Epoch 289/300
# 11/11 [==============================] - 8s 715ms/step - loss: 1.0112 - accuracy: 0.9170 - val_loss: 1.7363 - val_accuracy: 0.5986
# Epoch 290/300
# 11/11 [==============================] - 8s 702ms/step - loss: 0.0252 - accuracy: 0.9962 - val_loss: 1.9911 - val_accuracy: 0.5845
# Epoch 291/300
# 11/11 [==============================] - 8s 703ms/step - loss: 0.0075 - accuracy: 0.9992 - val_loss: 2.0435 - val_accuracy: 0.6056
# Epoch 292/300
# 11/11 [==============================] - 8s 705ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 2.0772 - val_accuracy: 0.6127
# Epoch 293/300
# 11/11 [==============================] - 8s 706ms/step - loss: 0.0649 - accuracy: 0.9833 - val_loss: 4.5569 - val_accuracy: 0.4014
# Epoch 294/300
# 11/11 [==============================] - 8s 710ms/step - loss: 0.3821 - accuracy: 0.8953 - val_loss: 1.8682 - val_accuracy: 0.6268
# Epoch 295/300
# 11/11 [==============================] - 8s 695ms/step - loss: 0.0395 - accuracy: 0.9925 - val_loss: 2.2567 - val_accuracy: 0.6268
# Epoch 296/300
# 11/11 [==============================] - 8s 706ms/step - loss: 0.0195 - accuracy: 0.9934 - val_loss: 3.0307 - val_accuracy: 0.6479
# Epoch 297/300
# 11/11 [==============================] - 8s 714ms/step - loss: 0.0130 - accuracy: 0.9938 - val_loss: 3.0246 - val_accuracy: 0.6197
# Epoch 298/300
# 11/11 [==============================] - 8s 696ms/step - loss: 0.0295 - accuracy: 0.9886 - val_loss: 2.5557 - val_accuracy: 0.6620
# Epoch 299/300
# 11/11 [==============================] - 8s 705ms/step - loss: 0.0035 - accuracy: 0.9996 - val_loss: 4.3529 - val_accuracy: 0.4648
# Epoch 300/300
# 11/11 [==============================] - 8s 703ms/step - loss: 1.1044 - accuracy: 0.8284 - val_loss: 2.1905 - val_accuracy: 0.5704

# %%
train_datagen.flow_from_directory?

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import random
import tensorflow_datasets as tfds
import matplotlib.image as img
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist
import numpy as np
num_classes = 5 #metadata.features['label'].num_classes
print(num_classes)

#get_label_name = metadata.features['label'].int2str

image  =img.imread( '/tmp/Data_T2/Serval/serval (138).jpg')
#print(label[0])
image=image[:, :,: ]
_ = plt.imshow(image)
#_ = plt.title(get_label_name(label))
#print(image)

#IMG_SIZE = 180

#resize_and_rescale = tf.keras.Sequential([
#  layers.experimental.preprocessing.Resizing(IMG_SIZE, IMG_SIZE),
#  layers.experimental.preprocessing.Rescaling(1./255)

#])
#guepardo, leo2, lince,ocelote, serval
#result = resize_and_rescale(image)
#_ = plt.imshow(result))
# Out:
# 5

# %%
#_ = plt.title(get_label_name(label))
#print(image)

IMG_SIZE = 400
resize_and_rescale = tf.keras.Sequential([
  layers.experimental.preprocessing.Resizing(IMG_SIZE, IMG_SIZE),
  layers.experimental.preprocessing.Rescaling(1./255)

])

result = resize_and_rescale(image)
_ = plt.imshow(result)

# %%
data_augmentation =tf.keras.Sequential(
    [
        #tf.keras.Input((400, 400, 3)),
        tf.keras.layers.experimental.preprocessing.Resizing(height=400,width=400),
        #tf.keras.layers.experimental.preprocessing.Rescaling(1./255),
        tf.keras.layers.experimental.preprocessing.RandomFlip(mode='horizontal'),
        #tf.keras.layers.experimental.preprocessing.RandomRotation(factor=0.8),
        #tf.keras.layers.experimental.preprocessing.RandomContrast(factor=0.4),
        #tf.keras.layers.experimental.preprocessing.RandomZoom(height_factor=0.8,width_factor=0.8)
    ]
)
#image  =img.imread( '/tmp/Data_T2/Serval/serval (103).jpg')
#image=image[:, :,: ]
plt.imshow(result)


#get_label_name = metadata.features['label'].int2str


#print(label[0])

# Add the image to a batch
image = tf.expand_dims(result,0)

plt.figure(figsize=(10, 10))
for i in range(1):
  augmented_image = data_augmentation(image)
  ax = plt.subplot(1, 2, i + 1)
  plt.imshow(augmented_image[0])
  plt.axis("off")

# %%
model.layers
# Out:
# [<tensorflow.python.keras.layers.preprocessing.image_preprocessing.Resizing at 0x7f3e908fd950>,
#  <tensorflow.python.keras.layers.preprocessing.image_preprocessing.RandomFlip at 0x7f3e80714e10>,
#  <tensorflow.python.keras.layers.preprocessing.image_preprocessing.RandomRotation at 0x7f3e8073c0d0>,
#  <tensorflow.python.keras.layers.preprocessing.image_preprocessing.RandomContrast at 0x7f3e8073c5d0>,
#  <tensorflow.python.keras.layers.preprocessing.image_preprocessing.RandomZoom at 0x7f3e8073c650>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3e8073cf10>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7f3e80745750>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3e80745c90>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7f3e806e82d0>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3e806e8710>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7f3e806e8cd0>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3e806eb190>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7f3e806eb790>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3e806ebc10>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7f3e806ef250>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f3e806ef6d0>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7f3e806efcd0>,
#  <tensorflow.python.keras.layers.core.Flatten at 0x7f3e80748190>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f3e80748450>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f3e80748810>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f3e80748bd0>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f3e80748fd0>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f3e806f8410>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f3e806f8810>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f3e806f8c10>]

# %%
# Guardar el Modelo
#model.save('path_to_my_modelv1.h5')
model = tf.keras.models.load_model('path_to_my_modelv1.h5')
# Recrea exactamente el mismo modelo solo desde el archivo
#new_model = keras.models.load_model('path_to_my_model.h5')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-127-241b5ea67d60> in <module>()
#       1 # Guardar el Modelo
#       2 #model.save('path_to_my_modelv1.h5')
# ----> 3 model = tf.keras.models.load_model('path_to_my_modelv1.h5')
#       4 # Recrea exactamente el mismo modelo solo desde el archivo
#       5 #new_model = keras.models.load_model('path_to_my_model.h5')
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     209       filepath = path_to_string(filepath)
#     210       if isinstance(filepath, six.string_types):
# --> 211         loader_impl.parse_saved_model(filepath)
#     212         return saved_model_load.load(filepath, compile, options)
#     213
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/saved_model/loader_impl.py in parse_saved_model(export_dir)
#     112                   (export_dir,
#     113                    constants.SAVED_MODEL_FILENAME_PBTXT,
# --> 114                    constants.SAVED_MODEL_FILENAME_PB))
#     115
#     116
#
# OSError: SavedModel file does not exist at: path_to_my_modelv1.h5/{saved_model.pbtxt|saved_model.pb}

# %% [markdown]
# El siguiente codigo, nos permitira ingresar imagenes de nuestro computador para mostraselas a nuestra red nueronal y las clasifique entre linces y leopardos

# %%
import numpy as np
from google.colab import files
import random
from keras.preprocessing import image

uploaded = files.upload()

for fn in uploaded.keys():
 
  # predicting images
  path = fn
  img = image.load_img(path, target_size=(400, 400))
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size=10)
  print(fn)
  print(classes)
# Out:
#      <input type="file" id="files-06307f58-a8d6-4126-bc28-66430f79e64c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-06307f58-a8d6-4126-bc28-66430f79e64c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving guepardo (1).jpg to guepardo (1).jpg
# Saving guepardo (2).jpg to guepardo (2).jpg
# Saving guepardo (19).jpg to guepardo (19).jpg
# Saving leopardo (1).jpg to leopardo (1).jpg
# Saving leopardo (2).jpg to leopardo (2).jpg
# Saving leopardo.jpg to leopardo.jpg
# Saving lincei (1).jpg to lincei (1).jpg
# Saving lincei (2).jpg to lincei (2).jpg
# Saving lincei (3).jpg to lincei (3).jpg
# Saving linci.jpg to linci.jpg
# Saving Ocelote (4).jpg to Ocelote (4).jpg
# Saving Ocelote (19).jpg to Ocelote (19).jpg
# Saving Ocelote (121).jpg to Ocelote (121).jpg
# Saving Serval (1).jpg to Serval (1).jpg
# Saving Serval (2).jpg to Serval (2).jpg
# Saving Serval (3).jpg to Serval (3).jpg
# guepardo (1).jpg
# [[1. 0. 0. 0. 0.]]
# guepardo (2).jpg
# [[1. 0. 0. 0. 0.]]
# guepardo (19).jpg
# [[0. 0. 0. 0. 1.]]
# leopardo (1).jpg
# [[1. 0. 0. 0. 0.]]
# leopardo (2).jpg
# [[0. 1. 0. 0. 0.]]
# leopardo.jpg
# [[0. 1. 0. 0. 0.]]
# lincei (1).jpg
# [[1. 0. 0. 0. 0.]]
# lincei (2).jpg
# [[0. 1. 0. 0. 0.]]
# lincei (3).jpg
# [[0. 1. 0. 0. 0.]]
# linci.jpg
# [[1. 0. 0. 0. 0.]]
# Ocelote (4).jpg
# [[0. 0. 0. 0. 1.]]
# Ocelote (19).jpg
# [[1. 0. 0. 0. 0.]]
# Ocelote (121).jpg
# [[0. 1. 0. 0. 0.]]
# Serval (1).jpg
# [[0.000000e+00 1.000000e+00 8.668275e-19 0.000000e+00 0.000000e+00]]
# Serval (2).jpg
# [[0. 0. 0. 0. 1.]]
# Serval (3).jpg
# [[0. 1. 0. 0. 0.]]

# %%
import numpy as np

from google.colab import files
from keras.preprocessing import image

uploaded=files.upload()

for fn in uploaded.keys():
 
  # predicting images
  path='/content/' + fn
  img=image.load_img(path, target_size=(100, 100))
  
  x=image.img_to_array(img)
  x=np.expand_dims(x, axis=0)
  images = np.vstack([x])
  
  classes = model.predict(images, batch_size=10)
  
  print(classes[0])
  
  if classes[0]>0:
    print(fn + " es un Lince")
    
  else:
    print(fn + " es un leopardo")
# Out:
#      <input type="file" id="files-56591e83-b621-4766-bafd-660116d1bfa0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-56591e83-b621-4766-bafd-660116d1bfa0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving lince i.jpg to lince i (5).jpg
# Saving Lince-Ibérico-».jpg to Lince-Ibérico-» (5).jpg
# Saving LEo.jpg to LEo (6).jpg
# Saving leopardo.jpg to leopardo (6).jpg
# WARNING:tensorflow:11 out of the last 15 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fd2ddecac80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [0.]
# lince i.jpg es un leopardo
# [0.]
# Lince-Ibérico-».jpg es un leopardo
# [0.]
# LEo.jpg es un leopardo
# [0.]
# leopardo.jpg es un leopardo

# %% [markdown]
# Podmeos observar el recorrido de una imagen en nuestra red neuronal

# %%
import numpy as np
import random
from   tensorflow.keras.preprocessing.image import img_to_array, load_img

# Definamos un nuevo modelo que tomará una imagen como entrada y generará
# representaciones intermedias para todas las capas en el modelo anterior después de la primera.
successive_outputs = [layer.output for layer in model.layers[1:]]

#visualization_model = Model(img_input, successive_outputs)
visualization_model = tf.keras.models.Model(inputs = model.input, outputs = successive_outputs)

# Preparemos una imagen de entrada aleatoria de un leopardo o un lince del conjunto de entrenamiento.
leo_img_files = [os.path.join(train_leo_dir, f) for f in train_leo_fnames]
lince_img_files = [os.path.join(train_lince_dir, f) for f in train_lince_fnames]
ocelote_img_files = [os.path.join(train_ocelote_dir, f) for f in train_ocelote_fnames]
guepardo_img_files = [os.path.join(train_guepardo_dir, f) for f in train_guepardo_fnames]
serval_img_files = [os.path.join(train_serval_dir, f) for f in train_serval_fnames]

img_path1 = random.choice(leo_img_files + lince_img_files+ocelote_img_files+guepardo_img_files+serval_img_files)
img_path2 = random.choice(leo_img_files + lince_img_files+ocelote_img_files+guepardo_img_files+serval_img_files)
img_path3 = random.choice(leo_img_files + lince_img_files+ocelote_img_files+guepardo_img_files+serval_img_files)

img1 = load_img(img_path1, target_size=(400, 150))  # esta es uan imagen de tipo PIL
img2 = load_img(img_path2, target_size=(150, 150))
img3 = load_img(img_path3, target_size=(150, 150))

x1   = img_to_array(img1)
x2   = img_to_array(img2)
x3   = img_to_array(img3)                           # Numpy array con la forma (150, 150, 3)

x1   = x1.reshape((1,) + x1.shape)                   # Numpy array con la forma (1, 150, 150, 3)
x2   = x2.reshape((1,) + x2.shape)                   # Numpy array con la forma (1, 150, 150, 3)
x3   = x3.reshape((1,) + x3.shape)                   # Numpy array con la forma (1, 150, 150, 3)

# Rescale by 1/255
#x /= 255.0

# Ejecutamos nuestra imagen a través de nuestra red, obteniendo así todas las representaciones intermedias para esta imagen.
successive_feature_maps = visualization_model.predict(x1+x2+x3,batch_size=10)

# Estos son los nombres de las capas, por lo que podemos tenerlos como parte de nuestra trama.
layer_names = [layer.name for layer in model.layers]

# -----------------------------------------------------------------------
# ahora vamos a mostrar nuestras representaciones 
# -----------------------------------------------------------------------
for layer_name, feature_map in zip(layer_names, successive_feature_maps):
  
  if len(feature_map.shape) == 4:
    
    #-------------------------------------------
    n_features = feature_map.shape[-1]  # numero caracteristicas en el mapa de caracteristicas
    size       = feature_map.shape[ 1]  # forma del mapa de caracteristicas (1, tamaño, tmaño, n_caracteristicas)
    
    # se colaca las imágenes en mosaico en esta matriz.
    display_grid = np.zeros((size, size * n_features))
    
    #-------------------------------------------------
    # Procesamiento de la funcion
    #-------------------------------------------------
    for i in range(n_features):
      x  = feature_map[0, :, :, i]
      x -= x.mean()
      x /= x.std ()
      x *=  64
      x += 128
      x  = np.clip(x, 0, 255).astype('uint8')
      display_grid[:, i * size : (i + 1) * size] = x # Coloca en mosaico cada filtro en una cuadrícula horizontal

    #-----------------
    # mostrar la figura
    #-----------------

    scale = 20. / n_features
    plt.figure( figsize=(scale * n_features, scale) )
    plt.axis( 'off' )
    plt.title ( layer_name )
    plt.grid  ( False )
    plt.imshow( display_grid, aspect='auto',cmap='viridis')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-131-eac396309866> in <module>()
#      37
#      38 # Ejecutamos nuestra imagen a través de nuestra red, obteniendo así todas las representaciones intermedias para esta imagen.
# ---> 39 successive_feature_maps = visualization_model.predict(x1+x2+x3,batch_size=10)
#      40
#      41 # Estos son los nombres de las capas, por lo que podemos tenerlos como parte de nuestra trama.
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1627           for step in data_handler.steps():
#    1628             callbacks.on_predict_batch_begin(step)
# -> 1629             tmp_batch_outputs = self.predict_function(iterator)
#    1630             if data_handler.should_sync:
#    1631               context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     869       # This is the first call of __call__, so we have to initialize.
#     870       initializers = []
# --> 871       self._initialize(args, kwds, add_initializers_to=initializers)
#     872     finally:
#     873       # At this point we know that the initialization is complete (or less
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     724     self._concrete_stateful_fn = (
#     725         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
# --> 726             *args, **kwds))
#     727
#     728     def invalid_creator_scope(*unused_args, **unused_kwds):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    2967       args, kwargs = None, None
#    2968     with self._lock:
# -> 2969       graph_function, _ = self._maybe_define_function(args, kwargs)
#    2970     return graph_function
#    2971
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3359
#    3360           self._function_cache.missed.add(call_context_key)
# -> 3361           graph_function = self._create_graph_function(args, kwargs)
#    3362           self._function_cache.primary[cache_key] = graph_function
#    3363
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3204             arg_names=arg_names,
#    3205             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3206             capture_by_value=self._capture_by_value),
#    3207         self._function_attributes,
#    3208         function_spec=self.function_spec,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     988         _, original_func = tf_decorator.unwrap(python_func)
#     989
# --> 990       func_outputs = python_func(*func_args, **func_kwargs)
#     991
#     992       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     632             xla_context.Exit()
#     633         else:
# --> 634           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     635         return out
#     636
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     975           except Exception as e:  # pylint:disable=broad-except
#     976             if hasattr(e, "ag_error_metadata"):
# --> 977               raise e.ag_error_metadata.to_exception(e)
#     978             else:
#     979               raise
#
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1478 predict_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1468 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/distribute/distribute_lib.py:1259 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/distribute/distribute_lib.py:2730 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/distribute/distribute_lib.py:3417 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1461 run_step  **
#         outputs = model.predict_step(data)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1434 predict_step
#         return self(x, training=False)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/base_layer.py:998 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/input_spec.py:274 assert_input_compatibility
#         ', found shape=' + display_shape(x.shape))
#
#     ValueError: Input 0 is incompatible with layer model: expected shape=(None, 400, 400, 3), found shape=(None, 150, 150, 3)

# %% [markdown]
# Se puede observa la perdida y la exactitud, tanto en los datos de entreanmiento y los de perdida.

# %%
acc      = history.history[     'accuracy' ]
val_acc  = history.history[ 'val_accuracy' ]
loss     = history.history[    'loss' ]
val_loss = history.history['val_loss' ]

epochs   = range(len(acc)) # Get number of epochs

#------------------------------------------------
# Pplotear precicios del entranamiento y al valuidacion por epoca
#------------------------------------------------
parameters = {'xtick.labelsize': 23,
          'ytick.labelsize': 23}
plt.rcParams.update(parameters)
plt.figure(figsize=(13,7))
plt.plot  ( epochs,     acc, label='entrenamiento')
plt.plot  ( epochs, val_acc, label='Validacion' )
plt.title ('Training and validation accuracy (sin tecnicas)',fontsize=20)
plt.xlabel("Epoca",fontsize=16)                       # Configuramos la etiqueta del eje X
plt.ylabel("Exactitud",fontsize=16) 
plt.grid()
plt.legend(loc=2,fontsize=13)
plt.show()
#------------------------------------------------
# plotear perdida en el entranamiento y la validacion por epoca 
#------------------------------------------------
fig2=plt.figure(figsize=(13,7))
plt.plot  ( epochs,     loss, label='Entrenamiento' )
plt.plot  ( epochs, val_loss,label=  'validacion')
plt.title ('Training and validation loss '  ,fontsize=30 )
plt.title ('Training and validation loss '  ,fontsize=30 )
plt.xlabel("Epoca", fontsize=16)                       # Configuramos la etiqueta del eje X
plt.ylabel("Perdida",fontsize=16) 
plt.grid()
plt.legend(loc=2,fontsize=13)

# %%
acc      = history.history[     'accuracy' ]
val_acc  = history.history[ 'val_accuracy' ]
loss     = history.history[    'loss' ]
val_loss = history.history['val_loss' ]

epochs   = range(len(acc)) # Get number of epochs

#------------------------------------------------
# Pplotear precicios del entranamiento y al valuidacion por epoca
#------------------------------------------------
parameters = {'xtick.labelsize': 23,
          'ytick.labelsize': 23}
plt.rcParams.update(parameters)
plt.figure(figsize=(13,7))
plt.plot  ( epochs,     acc, label='entrenamiento')
plt.plot  ( epochs, val_acc, label='Validacion' )
plt.title ('Training and validation accuracy (sin tecnicas)',fontsize=20)
plt.xlabel("Epoca",fontsize=16)                       # Configuramos la etiqueta del eje X
plt.ylabel("Exactitud",fontsize=16) 
plt.grid()
plt.legend(loc=2,fontsize=13)
plt.show()
#------------------------------------------------
# plotear perdida en el entranamiento y la validacion por epoca 
#------------------------------------------------
fig2=plt.figure(figsize=(13,7))
plt.plot  ( epochs,     loss, label='Entrenamiento' )
plt.plot  ( epochs, val_loss,label=  'validacion')
plt.title ('Training and validation loss '  ,fontsize=30 )
plt.title ('Training and validation loss '  ,fontsize=30 )
plt.xlabel("Epoca", fontsize=16)                       # Configuramos la etiqueta del eje X
plt.ylabel("Perdida",fontsize=16) 
plt.grid()
plt.legend(loc=2,fontsize=13)

# %%
acc      = history.history[     'accuracy' ]
val_acc  = history.history[ 'val_accuracy' ]
loss     = history.history[    'loss' ]
val_loss = history.history['val_loss' ]

epochs   = range(len(acc)) # Get number of epochs

#------------------------------------------------
# Pplotear precicios del entranamiento y al valuidacion por epoca
#------------------------------------------------
parameters = {'xtick.labelsize': 23,
          'ytick.labelsize': 23}
plt.rcParams.update(parameters)
plt.figure(figsize=(13,7))
plt.plot  ( epochs,     acc, label='entrenamiento')
plt.plot  ( epochs, val_acc, label='Validacion' )
plt.title ('Training and validation accuracy (sin tecnicas)',fontsize=20)
plt.xlabel("Epoca",fontsize=16)                       # Configuramos la etiqueta del eje X
plt.ylabel("Exactitud",fontsize=16) 
plt.grid()
plt.legend(loc=2,fontsize=13)
plt.show()
#------------------------------------------------
# plotear perdida en el entranamiento y la validacion por epoca 
#------------------------------------------------
fig2=plt.figure(figsize=(13,7))
plt.plot  ( epochs,     loss, label='Entrenamiento' )
plt.plot  ( epochs, val_loss,label=  'validacion')
plt.title ('Training and validation loss '  ,fontsize=30 )
plt.title ('Training and validation loss '  ,fontsize=30 )
plt.xlabel("Epoca", fontsize=16)                       # Configuramos la etiqueta del eje X
plt.ylabel("Perdida",fontsize=16) 
plt.grid()
plt.legend(loc=2,fontsize=13)

# %%
acc      = history.history[     'accuracy' ]
val_acc  = history.history[ 'val_accuracy' ]
loss     = history.history[    'loss' ]
val_loss = history.history['val_loss' ]

epochs   = range(len(acc)) # Get number of epochs

#------------------------------------------------
# Pplotear precicios del entranamiento y al valuidacion por epoca
#------------------------------------------------
parameters = {'xtick.labelsize': 23,
          'ytick.labelsize': 23}
plt.rcParams.update(parameters)
plt.figure(figsize=(13,7))
plt.plot  ( epochs,     acc, label='entrenamiento')
plt.plot  ( epochs, val_acc, label='Validacion' )
plt.title ('Training and validation accuracy (sin tecnicas)',fontsize=20)
plt.xlabel("Epoca",fontsize=16)                       # Configuramos la etiqueta del eje X
plt.ylabel("Exactitud",fontsize=16) 
plt.grid()
plt.legend(loc=2,fontsize=13)
plt.show()
#------------------------------------------------
# plotear perdida en el entranamiento y la validacion por epoca 
#------------------------------------------------
fig2=plt.figure(figsize=(13,7))
plt.plot  ( epochs,     loss, label='Entrenamiento' )
plt.plot  ( epochs, val_loss,label=  'validacion')
plt.title ('Training and validation loss '  ,fontsize=30 )
plt.title ('Training and validation loss '  ,fontsize=30 )
plt.xlabel("Epoca", fontsize=16)                       # Configuramos la etiqueta del eje X
plt.ylabel("Perdida",fontsize=16) 
plt.grid()
plt.legend(loc=2,fontsize=13)

# %%
from numpy import exp
 
# softmax activation function
def softmax(x):
	return exp(x) / exp(x).sum()
 
# define input data
inputs = [1.0, 3.0, 2.0]
print(exp(inputs))
print(exp(inputs).sum())
# calculate outputs
outputs = softmax(inputs)
# report the probabilities
print(outputs)
# report the sum of the probabilities
print(outputs.sum())
# Out:
# [ 2.71828183 20.08553692  7.3890561 ]
# 30.19287485057736
# [0.09003057 0.66524096 0.24472847]
# 1.0

# %%
acc      = history.history[     'accuracy' ]
val_acc  = history.history[ 'val_accuracy' ]
loss     = history.history[    'loss' ]
val_loss = history.history['val_loss' ]

epochs   = range(len(acc)) # Get number of epochs

#------------------------------------------------
# Pplotear precicios del entranamiento y al valuidacion por epoca
#------------------------------------------------
parameters = {'xtick.labelsize': 23,
          'ytick.labelsize': 23}
plt.rcParams.update(parameters)
plt.figure(figsize=(13,7))
plt.plot  ( epochs,     acc, label='entrenamiento')
plt.plot  ( epochs, val_acc, label='Validacion' )
plt.title ('Training and validation accuracy ',fontsize=20)
plt.xlabel("Epoca",fontsize=16)                       # Configuramos la etiqueta del eje X
plt.ylabel("Exactitud",fontsize=16) 
plt.grid()
plt.legend(loc=2,fontsize=13)
plt.show()
#------------------------------------------------
# plotear perdida en el entranamiento y la validacion por epoca 
#------------------------------------------------
fig2=plt.figure(figsize=(13,7))
plt.plot  ( epochs,     loss, label='Entrenamiento' )
plt.plot  ( epochs, val_loss,label=  'validacion')
plt.title ('Training and validation loss '  ,fontsize=30 )
plt.title ('Training and validation loss '  ,fontsize=30 )
plt.xlabel("Epoca", fontsize=16)                       # Configuramos la etiqueta del eje X
plt.ylabel("Perdida",fontsize=16) 
plt.grid()
plt.legend(loc=2,fontsize=13)

# %% [markdown]
# Referencia:
#
# Auotores de Tensorflow: Course_2_Part_2_Lesson_2_Notebook
